# %% [markdown]
# # Identify H-bearing reactions that should have deuterated analogues

# %% [markdown]
# This notebook is used to find which reaction rates are most important for producing H-bearing species, for the purpose of producing a deuterated network.

# %%
using Revise
photochemistry_source_dir = "$(@__DIR__)/Photochemistry/src/"
push!(LOAD_PATH, photochemistry_source_dir)
using Photochemistry  # custom module
using DataFrames

# %%
include("CONSTANTS.jl");
include("CUSTOMIZATIONS.jl");

# %%
basic_case_folder = "/home/emc/OneDrive-CU/Research/UpperAtmoDH/Results/DGearI+iNT_bXwiopqk_smean_v13/"
ncur = get_ncurrent(basic_case_folder*"final_atmosphere.h5");

vardict = load_from_paramlog(basic_case_folder);

reaction_network, hhn, hdn, hh2n, hhdn = load_reaction_network(vardict["rxn_spreadsheet"]; get_hot_rxns=true, ions_on=true, all_species=vardict["all_species"]);

# %% [markdown]
# # Function to print dominant reactions

# %%
function get_column_rates_NEW(sp::Symbol, atmdict::Dict{Symbol, Vector{ftype_ncur}}; which="all", role="both", startalt_i=1, globvars...)
    #=
    Input:
        sp: species for which to search for reactions
        atmdict: the present atmospheric state to calculate on
        Tn, Ti, Te: Arrays of the temperature profiles including boundary layers
        bcdict: Boundary conditions dictionary specified in parameters file
        which: whether to do photochemistry, or just bimolecular reactions. "all", "Jrates" or "krates"
        sp2: optional second species to include, i.e. usually sp's ion.
        role: "product" or "reactant" only.
        startalt_i: Index of the altitude at which to start. This lets you only calculate column rate down to a certain altitude, which is
                    useful, for example, for water, which is fixed at 80 km so we don't care what produces/consumes it.
    Output:
        sorted: Total column rates for all reactions of species sp. Sorted, in order of largest rate to smallest. NOT a dictionary.
                sorted[1] is the top production mechanism, e.g.
    =#
    GV = values(globvars)
    @assert all(x->x in keys(GV), [:Tn, :Ti, :Te, :all_species, :ion_species, :reaction_network, :num_layers, :dz])
    
    # println("Column rates will be collected for reaction type = $(which) and species role = $(role)")
    rxd, coefs = get_volume_rates(sp, atmdict, n_horiz; species_role=role, which=which, globvars...)

    
    # rxd comes out as a dictionary; convert it to a dataframe
    df = DataFrame(rxd)
    
    # Now sum each reaction over altitudes and multiply by dz to get the column rate
    dfsum = dfsum = mapcols(sum, df) .* GV.dz
    # Now transpose and sort 
    df_transposed = DataFrame([[names(dfsum)]; collect.(eachrow(dfsum))], [:Rxn; :Value])
    df_sorted = sort(df_transposed, [:Value], rev=true)
    
    return df_sorted
end

# thecoldf = get_column_rates_NEW(:H, ncur; which="all", sp2=nothing, Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
#                                    all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
#                                    num_layers, dz)
# Out:
# get_column_rates_NEW (generic function with 1 method)

# %%
function get_p_pct_of_column(col_rate_df, p; sp=nothing, globvars...)
    #=
    This will calculate the column rate for the top p% of reactions, and
    return the subset of col_rate_df for that number of reactions, starting from the highest column rate.
    
    col_rate_df: a dataframe containing various chemical reactions and their column rate.
    p: we wish to get the top x reactions that contribute to p% of the total column rate.
    =#
    
    GV = values(globvars)
    @assert all(x->x in keys(GV), [:Tn, :Ti, :Te, :all_species, :ion_species, :reaction_network, :num_layers, :dz])
    
    if p > 1
        throw("Please enter percent as a decimal, i.e. 1 = 100%, 0.01 = 1%.")
    end
    
    total_col_rate_all_rxns = sum(col_rate_df."Value")
    
    # Figure out what percent of total column rate the top x% reactions are.
    if nrow(col_rate_df) <= 25
        if sp != nothing
            x = nrow(col_rate_df) # set total num of reactions to all of them
            println("$(sp) has a small number of reactions ($(x)). Recommended to create a deuterated analogue for all of them.")
            p = 1 # 100% of column rate is represented.
        else
            # if we didn't specify a species, we can still go ahead and calculate what x we require for p% to be represented.
            x = Int(floor(nrow(col_rate_df) * p))
            
        end
    else
        x = Int(floor(nrow(col_rate_df) * p))
    end

    # Handle case where we might round down too hard
    if x < 1
        x = 1
        println("Error: $(p*100)% of reactions is 0, resetting to print out only one reaction.")
        
        p = x / nrow(col_rate_df)
        println("Printing 1 reaction ($(round(p*100, digits=2))% of reactions).")
    else
        println("$(p*100)% of reactions is $(x)/$(nrow(col_rate_df))")
    end
    
    col_rate_of_top_p_rxns = sum(col_rate_df."Value"[1:x])
    println("The column rate of top $(round(p*100, digits=2))% of reactions is $(col_rate_of_top_p_rxns)")
    println("Which equates to $(100*col_rate_of_top_p_rxns / total_col_rate_all_rxns)% of the total column rate ($(total_col_rate_all_rxns)).")
    println()
    println(col_rate_df[1:x, :])
    
    return col_rate_df[1:x, :]
end

function rxns_comprising_p_pct_colrate(col_rate_df, p; sp=nothing, globvars...)
    #=
    This will return the subset of col_rate_df which comprises 99% of the column rate total for the whole df.
    
    col_rate_df: a dataframe containing various chemical reactions and their column rate.
    p: we wish to get the top x reactions that contribute to p% of the total column rate.
    =#
    
    GV = values(globvars)
    @assert all(x->x in keys(GV), [:Tn, :Ti, :Te, :all_species, :ion_species, :reaction_network, :num_layers, :dz])
    
    if p > 1
        throw("Please enter percent as a decimal, i.e. 1 = 100%, 0.01 = 1%.")
    end
    
    total_col_rate_all_rxns = sum(col_rate_df."Value")
    
    p_times_total_columnrate = p * total_col_rate_all_rxns

    this_pct = 1
    i = nrow(col_rate_df)+1
    while this_pct > p
        i -= 1
        this_pct = sum(col_rate_df[1:i, :]."Value") / total_col_rate_all_rxns
        println("$(i) is $(100*this_pct)%")
        
        if this_pct < 0.999
            i += 1
        elseif this_pct == 0.999
            continue
        end
    end
    
    println("$(i) reactions needed to make up $(100*p)% of col rate")

    return col_rate_df[1:i, :]
end
# Out:
# rxns_comprising_p_pct_colrate (generic function with 1 method)

# %% [markdown]
# # H-bearing species list

# %%
H_bearing_species = [s for s in vardict["all_species"] if occursin('H', string(s))];

# %% [markdown]
# # Get 100% of reactions for all H-bearing species, to get all H-bearing reactions

# %%
bigdf_Hrxns = DataFrame(Rxn=[], Value=[])

# Retrieve 100% of reactions for all species
for Hsp in H_bearing_species
    # Get the basic df
    println("For $(Hsp): ")
    col_rate_df = get_column_rates_NEW(Hsp, ncur; which="all", Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
    
    thisdf = get_p_pct_of_column(col_rate_df, 1; Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
    bigdf_Hrxns = vcat(bigdf_Hrxns, thisdf)
    println()
end
# Out:
# For ArHpl:
# 100% of reactions is 16/16
# The column rate of top 100.0% of reactions is 10012.687993655469
# Which equates to 100.0% of the total column rate (10012.687993655469).
#
# 16×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────────
#    1 │ H2pl + Ar --> ArHpl + H      4987.98
#    2 │ ArHpl + CO2 --> HCO2pl + Ar  3882.06
#    3 │ ArHpl + O --> OHpl + Ar       513.096
#    4 │ ArHpl + N2 --> N2Hpl + Ar     314.979
#    5 │ ArHpl + CO --> HCOpl + Ar     261.359
#    6 │ ArHpl + H2 --> H3pl + Ar       20.952
#    7 │ ArHpl + O2 --> HO2pl + Ar      13.225
#    8 │ H3pl + Ar --> ArHpl + H2        8.72566
#    9 │ HDpl + Ar --> ArHpl + D         8.03077
#   10 │ Arpl + H2 --> ArHpl + H         1.58559
#   11 │ ArHpl + C --> CHpl + Ar         0.327474
#   12 │ ArHpl + E --> Ar + H            0.305297
#   13 │ ArHpl + HD --> H2Dpl + Ar       0.0382802
#   14 │ ArDpl + H2 --> ArHpl + HD       0.0214036
#   15 │ Arpl + HD --> ArHpl + D         0.000934821
#   16 │ Arpl + H2O --> ArHpl + OH       3.61403e-5
#
# For CHpl:
# 100% of reactions is 24/24
# The column rate of top 100.0% of reactions is 552427.5607978381
# Which equates to 100.0% of the total column rate (552427.5607978381).
#
# 24×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼────────────────────────────────────────────
#    1 │ CHpl + CO2 --> HCOpl + CO      2.67614e5
#    2 │ HCOpl + C --> CHpl + CO        2.62679e5
#    3 │ HCO2pl + C --> CHpl + CO2  13221.6
#    4 │ CHpl + O --> COpl + H       6845.02
#    5 │ CHpl + O2 --> HCOpl + O      795.594
#    6 │ CHpl + E --> C + H           755.335
#    7 │ CHpl + H --> Cpl + H2        196.222
#    8 │ OHpl + C --> CHpl + O        186.522
#    9 │ N2Hpl + C --> CHpl + N2       64.4965
#   10 │ H2Opl + C --> CHpl + OH       34.7721
#   11 │ H2pl + C --> CHpl + H         25.9179
#   12 │ Cpl + H2 --> CHpl + H          4.35272
#   13 │ CHpl + CO --> HCOpl + C        2.51542
#   14 │ NHpl + C --> CHpl + N          1.62017
#   15 │ H3pl + C --> CHpl + H2         0.493831
#   16 │ ArHpl + C --> CHpl + Ar        0.327474
#   17 │ HNOpl + C --> CHpl + NO        0.264502
#   18 │ HO2pl + C --> CHpl + O2        0.124144
#   19 │ CHpl + H2O --> HCOpl + H2      0.0557309
#   20 │ CHpl + H2O --> H3Opl + C       0.030422
#   21 │ CHpl + OH --> COpl + H2        0.0291679
#   22 │ Cpl + HCO --> CHpl + CO        0.000827448
#   23 │ Cpl + H --> CHpl               0.000710565
#   24 │ Cpl + HD --> CHpl + D          2.973e-6
#
# For H:
# 100% of reactions is 160/160
# The column rate of top 100.0% of reactions is 3.2004036837153823e12
# Which equates to 100.0% of the total column rate (3.2004036837153823e12).
#
# 160×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼──────────────────────────────────────────────
#    1 │ H + O2 --> HO2                   1.4822e12
#    2 │ CO + OH --> CO2 + H              1.344e12
#    3 │ OH + O --> O2 + H                2.05675e11
#    4 │ O3 + H --> O2 + OH               8.61523e10
#    5 │ HO2 + H --> OH + OH              4.35459e10
#    6 │ H2O --> H + OH                   3.24901e10
#    7 │ HO2 + H --> O2 + H2              2.08658e9
#    8 │ OH + H2 --> H2O + H              1.61533e9
#    9 │ H2O2 --> HO2 + H                 1.07813e9
#   10 │ HO2 + H --> H2O + O1D            9.67687e8
#   11 │ HCOpl + E --> CO + H             1.42594e8
#   12 │ O1D + H2 --> OH + H              1.32058e8
#   13 │ CO2pl + H2 --> HCO2pl + H        1.27302e8
#   14 │ CO + H --> HCO                   2.61704e7
#   15 │ D + HO2 --> DO2 + H              2.61155e7
#   16 │ CO2pl + H --> HCOpl + O          2.19129e7
#   17 │ OH + D --> OD + H                2.00481e7
#   18 │ O + H --> OH                     1.91269e7
#   19 │ H2 + O --> OH + H                1.87528e7
#   20 │ H + DO2 --> OH + OD              1.57421e7
#   21 │ HDO --> H + OD                   8.49736e6
#   22 │ HCO2pl + E --> CO + O + H        5.32587e6
#   23 │ H + H + M --> H2 + M             4.65615e6
#   24 │ OH + H + CO2 --> H2O + CO2       3.69939e6
#   25 │ CO2pl + H --> Hpl + CO2          2.69285e6
#   26 │ Opl + H2 --> OHpl + H            1.75584e6
#   27 │ H + H2O2 --> H2O + OH            1.42154e6
#   28 │ H2O2 + H --> H2O + OH            1.42154e6
#   29 │ OH --> O + H                     1.39357e6
#   30 │ OH + HD --> HDO + H              7.62911e5
#   31 │ H + DO2 --> HD + O2         754308.0
#   32 │ OD + H2 --> HDO + H              4.26944e5
#   33 │ HCO2pl + E --> CO2 + H           3.91608e5
#   34 │ H + DO2 --> HDO + O1D       349824.0
#   35 │ HCO + O --> CO2 + H              3.41079e5
#   36 │ OD + H --> OH + D                3.14005e5
#   37 │ Opl + H --> Hpl + O              2.97234e5
#   38 │ N2pl + H2 --> N2Hpl + H          2.96692e5
#   39 │ OHpl + O --> O2pl + H            2.76386e5
#   40 │ H + DO2 --> HO2 + D         228670.0
#   41 │ H2pl + CO2 --> HCO2pl + H        1.9573e5
#   42 │ COpl + H2 --> HCOpl + H          1.94077e5
#   43 │ COpl + H2 --> HOCpl + H          1.94077e5
#   44 │ H2 --> H + H                     1.8797e5
#   45 │ OH + N --> NO + H                1.59357e5
#   46 │ H --> Hpl                        1.49971e5
#   47 │ HDO2 --> DO2 + H                 1.49586e5
#   48 │ H + H2O2 --> HO2 + H2            1.48487e5
#   49 │ H2O2 + H --> HO2 + H2            1.47959e5
#   50 │ O1D + HD --> H + OD          67540.7
#   51 │ COpl + H --> Hpl + CO        43545.9
#   52 │ H2pl + O --> OHpl + H        40705.8
#   53 │ H3Opl + E --> OH + H + H     37518.2
#   54 │ Hpl + O --> Opl + H          36879.9
#   55 │ H2 --> Hpl + H               31867.5
#   56 │ H2pl + N2 --> N2Hpl + H      20752.5
#   57 │ CO2pl + HD --> DCO2pl + H    19192.6
#   58 │ OHpl + H2 --> H2Opl + H      18653.6
#   59 │ H2pl + CO --> HCOpl + H      15991.5
#   60 │ H3Opl + E --> H2O + H        15611.6
#   61 │ HCO + H --> CO + H2          14080.3
#   62 │ H + HD --> H2 + D            10001.6
#   63 │ Npl + H2 --> NHpl + H         8746.9
#   64 │ H2Opl + E --> O + H + H       7021.99
#   65 │ CHpl + O --> COpl + H         6845.02
#   66 │ H2pl + Ar --> ArHpl + H       4987.98
#   67 │ Hpl + O2 --> O2pl + H         4762.93
#   68 │ N2Hpl + E --> N2 + H          4470.32
#   69 │ OHpl + E --> O + H            2843.25
#   70 │ OH + C --> CO + H             2821.32
#   71 │ H2pl + H2 --> H3pl + H        2723.02
#   72 │ Hpl + H --> H + Hpl           2641.17
#   73 │ H2Opl + H2 --> H3Opl + H      2378.58
#   74 │ H2Opl + E --> OH + H          1978.31
#   75 │ H + D + M --> HD + M          1860.98
#   76 │ D + H2 --> HD + H             1566.65
#   77 │ H + OD + CO2 --> HDO + CO2    1518.84
#   78 │ H2pl + O2 --> HO2pl + H       1273.19
#   79 │ HD + O --> OD + H             1004.58
#   80 │ HCOpl + OH --> HCO2pl + H      952.004
#   81 │ Opl + HD --> ODpl + H          886.639
#   82 │ H3Opl + E --> H2 + O + H       812.475
#   83 │ CHpl + E --> C + H             755.335
#   84 │ HCOpl + D --> DCOpl + H        415.847
#   85 │ H2pl + H --> Hpl + H2          401.013
#   86 │ OHpl + N --> NOpl + H          337.164
#   87 │ HD --> H + D                   271.271
#   88 │ CHpl + H --> Cpl + H2          196.222
#   89 │ H3pl + O --> H2Opl + H         183.62
#   90 │ N2pl + HD --> N2Dpl + H        172.373
#   91 │ HOCpl + E --> CO + H           166.437
#   92 │ HDpl + CO2 --> DCO2pl + H      145.314
#   93 │ H2pl + E --> H + H              92.4611
#   94 │ COpl + HD --> DCOpl + H         57.3194
#   95 │ COpl + HD --> DOCpl + H         57.3194
#   96 │ OH --> O1D + H                  52.9651
#   97 │ H2pl + N --> NHpl + H           50.1047
#   98 │ HD --> Dpl + H                  45.3492
#   99 │ HNOpl + E --> NO + H            42.9243
#  100 │ H2DOpl + E --> OD + H + H       39.719
#  101 │ H2DOpl + E --> OH + D + H       39.719
#  102 │ DCOpl + H --> HCOpl + D         34.1463
#  103 │ H2O --> OHpl + H                31.6029
#  104 │ Cpl + H2O --> HOCpl + H         30.8976
#  105 │ OH + H --> H2 + O               30.301
#  106 │ H + HDO2 --> H2O + OD           28.4459
#  107 │ H + HDO2 --> HDO + OH           28.4459
#  108 │ H2pl + C --> CHpl + H           25.9179
#  109 │ HDpl + O --> ODpl + H           25.759
#  110 │ Opl + OH --> O2pl + H           25.4526
#  111 │ HDOpl + E --> O + D + H         24.3932
#  112 │ NHpl + E --> N + H              20.4365
#  113 │ OHpl + HD --> HDOpl + H         20.0046
#  114 │ HO2pl + E --> O2 + H            19.6742
#  115 │ H2DOpl + E --> HDO + H          16.5274
#  116 │ Cpl + H2O --> HCOpl + H         15.0817
#  117 │ HDpl + N2 --> N2Dpl + H         14.2168
#  118 │ H2Opl + N --> HNOpl + H         11.8444
#  119 │ HDpl + CO --> DCOpl + H         10.9446
#  120 │ Hpl + NO --> NOpl + H            9.26618
#  121 │ DCO + H --> CO + HD              8.01274
#  122 │ HDpl + Ar --> ArDpl + H          6.57063
#  123 │ Cpl + OH --> COpl + H            4.92356
#  124 │ ODpl + H2 --> HDOpl + H          4.5858
#  125 │ H3pl + E --> H + H + H           4.41689
#  126 │ Cpl + H2 --> CHpl + H            4.35272
#  127 │ HDOpl + E --> OD + H             3.43616
#  128 │ NHpl + N --> N2pl + H            3.1762
#  129 │ H3pl + E --> H2 + H              2.3703
#  130 │ Arpl + H2 --> ArHpl + H          1.58559
#  131 │ HDOpl + H2 --> H2DOpl + H        1.22527
#  132 │ Dpl + H --> D + Hpl              1.19811
#  133 │ H2pl + NO --> HNOpl + H          1.04259
#  134 │ H2DOpl + E --> HD + O + H        0.860133
#  135 │ Hpl + H2O --> H2Opl + H          0.848848
#  136 │ O2 + H --> OH + O                0.825526
#  137 │ H2Opl + HD --> H2DOpl + H        0.662357
#  138 │ Hpl + OH --> OHpl + H            0.425851
#  139 │ ArHpl + E --> Ar + H             0.305297
#  140 │ N2Hpl + D --> N2Dpl + H          0.249515
#  141 │ Hpl + E --> H                    0.236417
#  142 │ N2Dpl + H --> N2Hpl + D          0.183649
#  143 │ HDpl + E --> H + D               0.170984
#  144 │ H2pl + H2O --> H3Opl + H         0.0913989
#  145 │ HDO --> ODpl + H                 0.0586517
#  146 │ H2pl + OH --> H2Opl + H          0.0485939
#  147 │ Cpl + HDO --> DOCpl + H          0.0142392
#  148 │ Cpl + HDO --> DCOpl + H          0.00700875
#  149 │ Arpl + HD --> ArDpl + H          0.000975465
#  150 │ Cpl + H --> CHpl                 0.000710565
#  151 │ Hpl + HDO --> HDOpl + H          0.000702098
#  152 │ Dpl + H2O --> HDOpl + H          0.000121877
#  153 │ Hpl + HCO --> HCOpl + H          6.24305e-5
#  154 │ H2O + H --> OH + H2              3.84817e-6
#  155 │ Hpl + H --> H2pl                 2.91294e-6
#  156 │ CO2 + H --> CO + OH              1.06592e-7
#  157 │ HO2 + H2 --> H2O2 + H            4.37853e-10
#  158 │ O2 + H2 --> HO2 + H              1.96851e-32
#  159 │ H2O --> H + H + O                0.0
#  160 │ HDO --> H + D + O                0.0
#
# For H2:
# 100% of reactions is 86/86
# The column rate of top 100.0% of reactions is 3.9885013878256326e9
# Which equates to 100.0% of the total column rate (3.9885013878256326e9).
#
# 86×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼─────────────────────────────────────────────
#    1 │ HO2 + H --> O2 + H2             2.08658e9
#    2 │ OH + H2 --> H2O + H             1.61533e9
#    3 │ O1D + H2 --> OH + H             1.32058e8
#    4 │ CO2pl + H2 --> HCO2pl + H       1.27302e8
#    5 │ H2 + O --> OH + H               1.87528e7
#    6 │ H + H + M --> H2 + M            4.65615e6
#    7 │ Opl + H2 --> OHpl + H           1.75584e6
#    8 │ OD + H2 --> HDO + H             4.26944e5
#    9 │ N2pl + H2 --> N2Hpl + H         2.96692e5
#   10 │ H2 --> H2pl                     2.86808e5
#   11 │ COpl + H2 --> HCOpl + H         1.94077e5
#   12 │ COpl + H2 --> HOCpl + H         1.94077e5
#   13 │ H2 --> H + H                    1.8797e5
#   14 │ H + H2O2 --> HO2 + H2           1.48487e5
#   15 │ H2O2 + H --> HO2 + H2           1.47959e5
#   16 │ H2O --> H2 + O1D            77580.8
#   17 │ H2 --> Hpl + H              31867.5
#   18 │ OHpl + H2 --> H2Opl + H     18653.6
#   19 │ HCO + H --> CO + H2         14080.3
#   20 │ H + HD --> H2 + D           10001.6
#   21 │ Npl + H2 --> NHpl + H        8746.9
#   22 │ H3Opl + E --> OH + H2        8729.07
#   23 │ H2Opl + O --> O2pl + H2      5514.01
#   24 │ H2pl + CO --> COpl + H2      3551.23
#   25 │ H2pl + H2 --> H3pl + H       2723.02
#   26 │ H2Opl + H2 --> H3Opl + H     2378.58
#   27 │ H3pl + CO2 --> HCO2pl + H2   1737.11
#   28 │ D + H2 --> HD + H            1566.65
#   29 │ H2Opl + E --> H2 + O          891.252
#   30 │ H3Opl + E --> H2 + O + H      812.475
#   31 │ H2pl + O2 --> O2pl + H2       519.224
#   32 │ H3pl + O --> OHpl + H2        427.638
#   33 │ H2pl + H --> Hpl + H2         401.013
#   34 │ H3pl + N2 --> N2Hpl + H2      277.577
#   35 │ CHpl + H --> Cpl + H2         196.222
#   36 │ H3pl + CO --> HCOpl + H2      117.363
#   37 │ HOCpl + H2 --> HCOpl + H2     105.09
#   38 │ H3pl + CO --> HOCpl + H2       78.6945
#   39 │ HOCpl + H2 --> H3pl + CO       74.116
#   40 │ Nup2D + H2O --> NO + H2        33.1079
#   41 │ OH + H --> H2 + O              30.301
#   42 │ NHpl + H2 --> H3pl + N         23.5771
#   43 │ ArHpl + H2 --> H3pl + Ar       20.952
#   44 │ H2DOpl + E --> OD + H2          9.2411
#   45 │ H3pl + Ar --> ArHpl + H2        8.72566
#   46 │ H3pl + O2 --> HO2pl + H2        6.40355
#   47 │ ODpl + H2 --> H2Opl + D         4.5858
#   48 │ ODpl + H2 --> HDOpl + H         4.5858
#   49 │ HO2pl + H2 --> H3pl + O2        4.58091
#   50 │ Dpl + H2 --> Hpl + HD           4.46848
#   51 │ Cpl + H2 --> CHpl + H           4.35272
#   52 │ H2Opl + N --> NOpl + H2         2.96111
#   53 │ H2O --> Opl + H2                2.69162
#   54 │ H3pl + E --> H2 + H             2.3703
#   55 │ Arpl + H2 --> ArHpl + H         1.58559
#   56 │ HDOpl + H2 --> H2DOpl + H       1.22527
#   57 │ HDOpl + H2 --> H3Opl + D        1.22527
#   58 │ H2pl + NO --> NOpl + H2         1.04259
#   59 │ H2DOpl + E --> H2 + O + D       0.860133
#   60 │ Hpl + HD --> Dpl + H2           0.580254
#   61 │ H3pl + C --> CHpl + H2          0.493831
#   62 │ H3pl + N --> NHpl + H2          0.151493
#   63 │ H3Opl + C --> HCOpl + H2        0.145331
#   64 │ H2pl + H2O --> H2Opl + H2       0.103124
#   65 │ CHpl + H2O --> HCOpl + H2       0.0557309
#   66 │ H2pl + OH --> OHpl + H2         0.0485939
#   67 │ DOCpl + H2 --> H2Dpl + CO       0.0477414
#   68 │ ArDpl + H2 --> H2Dpl + Ar       0.0418559
#   69 │ H2Dpl + CO --> DCOpl + H2       0.041759
#   70 │ DOCpl + H2 --> HCOpl + HD       0.0360155
#   71 │ Arpl + H2 --> H2pl + Ar         0.0323665
#   72 │ CHpl + OH --> COpl + H2         0.0291679
#   73 │ H3pl + NO --> HNOpl + H2        0.0290538
#   74 │ ArDpl + H2 --> ArHpl + HD       0.0214036
#   75 │ H2Dpl + H2 --> H3pl + HD        0.00562174
#   76 │ H3pl + H2O --> H3Opl + H2       0.00291609
#   77 │ H3pl + OH --> H2Opl + H2        0.00185583
#   78 │ NHpl + H2O --> HNOpl + H2       0.000844481
#   79 │ Hpl + HCO --> COpl + H2         6.24305e-5
#   80 │ N2Hpl + H2 --> H3pl + N2        3.62304e-5
#   81 │ H2pl + HCO --> HCOpl + H2       2.08199e-5
#   82 │ H2O + H --> OH + H2             3.84817e-6
#   83 │ HCO + HCO --> CO + CO + H2      1.14913e-6
#   84 │ HO2 + H2 --> H2O2 + H           4.37853e-10
#   85 │ O2 + H2 --> OH + OH             1.21192e-19
#   86 │ O2 + H2 --> HO2 + H             1.96851e-32
#
# For H2DOpl:
# 100% of reactions is 14/14
# The column rate of top 100.0% of reactions is 267.1541552960093
# Which equates to 100.0% of the total column rate (267.1541552960093).
#
# 14×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼────────────────────────────────────────────
#    1 │ HCOpl + HDO --> H2DOpl + CO    119.246
#    2 │ H2DOpl + E --> OD + H + H       39.719
#    3 │ H2DOpl + E --> OH + D + H       39.719
#    4 │ H2DOpl + E --> H2O + D          16.5274
#    5 │ H2DOpl + E --> HDO + H          16.5274
#    6 │ DCOpl + H2O --> H2DOpl + CO     12.463
#    7 │ H2DOpl + E --> OD + H2           9.2411
#    8 │ H2DOpl + E --> OH + HD           9.2411
#    9 │ HDOpl + H2 --> H2DOpl + H        1.22527
#   10 │ H2DOpl + E --> H2 + O + D        0.860133
#   11 │ H2DOpl + E --> HD + O + H        0.860133
#   12 │ HCO2pl + HDO --> H2DOpl + CO2    0.803133
#   13 │ H2Opl + HD --> H2DOpl + H        0.662357
#   14 │ DCO2pl + H2O --> H2DOpl + CO2    0.0588014
#
# For H2Dpl:
# 100% of reactions is 7/7
# The column rate of top 100.0% of reactions is 0.26432856873893157
# Which equates to 100.0% of the total column rate (0.26432856873893157).
#
# 7×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼───────────────────────────────────────
#    1 │ H2Dpl + CO --> HCOpl + HD  0.0847835
#    2 │ DOCpl + H2 --> H2Dpl + CO  0.0477414
#    3 │ ArDpl + H2 --> H2Dpl + Ar  0.0418559
#    4 │ H2Dpl + CO --> DCOpl + H2  0.041759
#    5 │ ArHpl + HD --> H2Dpl + Ar  0.0382802
#    6 │ H2Dpl + H2 --> H3pl + HD   0.00562174
#    7 │ HDpl + HD --> H2Dpl + D    0.0042868
#
# For H2O:
# 100% of reactions is 65/65
# The column rate of top 100.0% of reactions is 6.848409222845484e10
# Which equates to 100.0% of the total column rate (6.848409222845484e10).
#
# 65×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼─────────────────────────────────────────────────
#    1 │ H2O --> H + OH                      3.24901e10
#    2 │ HO2 + OH --> H2O + O2               3.06452e10
#    3 │ O1D + H2O --> OH + OH               1.62693e9
#    4 │ OH + H2 --> H2O + H                 1.61533e9
#    5 │ OH + H2O2 --> H2O + HO2             1.09603e9
#    6 │ HO2 + H --> H2O + O1D               9.67687e8
#    7 │ OH + OH --> H2O + O                 3.56231e7
#    8 │ OH + H + CO2 --> H2O + CO2          3.69939e6
#    9 │ H + H2O2 --> H2O + OH               1.42154e6
#   10 │ H2O2 + H --> H2O + OH               1.42154e6
#   11 │ OH + HD --> H2O + D            300805.0
#   12 │ OH + HDO2 --> H2O + DO2             1.48677e5
#   13 │ H2O --> H2 + O1D                77580.8
#   14 │ HCOpl + H2O --> H3Opl + CO      60708.7
#   15 │ CO2pl + H2O --> H2Opl + CO2     31542.2
#   16 │ CO2pl + H2O --> HCO2pl + OH     23211.5
#   17 │ H3Opl + E --> H2O + H           15611.6
#   18 │ H2Opl + O2 --> O2pl + H2O        4391.36
#   19 │ HOCO + OH --> CO2 + H2O           553.155
#   20 │ HCO2pl + H2O --> H3Opl + CO2      433.383
#   21 │ Opl + H2O --> H2Opl + O           290.967
#   22 │ H2O --> H2Opl                     162.661
#   23 │ HCO + OH --> H2O + CO             132.454
#   24 │ COpl + H2O --> H2Opl + CO          51.0511
#   25 │ D + H2O2 --> H2O + OD              37.4567
#   26 │ Nup2D + H2O --> NO + H2            33.1079
#   27 │ H2O --> OHpl + H                   31.6029
#   28 │ Cpl + H2O --> HOCpl + H            30.8976
#   29 │ H + HDO2 --> H2O + OD              28.4459
#   30 │ COpl + H2O --> HCOpl + OH          27.489
#   31 │ N2pl + H2O --> H2Opl + N2          20.1849
#   32 │ H2O --> Hpl + OH                   17.0067
#   33 │ H2DOpl + E --> H2O + D             16.5274
#   34 │ Cpl + H2O --> HCOpl + H            15.0817
#   35 │ DCOpl + H2O --> H2DOpl + CO        12.463
#   36 │ N2pl + H2O --> N2Hpl + OH           5.35431
#   37 │ H2Opl + NO --> NOpl + H2O           4.5727
#   38 │ Npl + H2O --> H2Opl + N             3.58096
#   39 │ Cpl + H2O --> H2Opl + C             3.43306
#   40 │ H2O --> Opl + H2                    2.69162
#   41 │ Hpl + H2O --> H2Opl + H             0.848848
#   42 │ OHpl + H2O --> H2Opl + OH           0.606347
#   43 │ OHpl + H2O --> H3Opl + O            0.495756
#   44 │ N2Hpl + H2O --> H3Opl + N2          0.368836
#   45 │ H2Opl + H2O --> H3Opl + OH          0.347821
#   46 │ H2O + O --> OH + OH                 0.347638
#   47 │ H2pl + H2O --> H2Opl + H2           0.103124
#   48 │ H2pl + H2O --> H3Opl + H            0.0913989
#   49 │ DCO2pl + H2O --> H2DOpl + CO2       0.0588014
#   50 │ CHpl + H2O --> HCOpl + H2           0.0557309
#   51 │ CHpl + H2O --> H3Opl + C            0.030422
#   52 │ H3pl + H2O --> H3Opl + H2           0.00291609
#   53 │ NHpl + H2O --> H3Opl + N            0.00253344
#   54 │ HNOpl + H2O --> H3Opl + NO          0.00158595
#   55 │ NHpl + H2O --> HNOpl + H2           0.000844481
#   56 │ Dpl + H2O --> H2Opl + D             0.000218603
#   57 │ HO2pl + H2O --> H3Opl + O2          0.000217933
#   58 │ Arpl + H2O --> H2Opl + Ar           0.000145007
#   59 │ Dpl + H2O --> HDOpl + H             0.000121877
#   60 │ Arpl + H2O --> ArHpl + OH           3.61403e-5
#   61 │ H2Opl + HCO --> HCOpl + H2O         1.93204e-5
#   62 │ H2O + H --> OH + H2                 3.84817e-6
#   63 │ HO2 + H2O --> H2O2 + OH             8.88464e-16
#   64 │ H2O --> H + H + O                   0.0
#   65 │ H2O2 --> H2O + O1D                  0.0
#
# For H2O2:
# 100% of reactions is 19/19
# The column rate of top 100.0% of reactions is 4.531188710295528e10
# Which equates to 100.0% of the total column rate (4.531188710295528e10).
#
# 19×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼───────────────────────────────────────────────────
#    1 │ HO2 + HO2 --> H2O2 + O2               2.27018e10
#    2 │ H2O2 --> OH + OH                      2.01288e10
#    3 │ OH + H2O2 --> H2O + HO2               1.09603e9
#    4 │ H2O2 --> HO2 + H                      1.07813e9
#    5 │ HO2 + HO2 + M --> H2O2 + O2 + M       2.81728e8
#    6 │ H2O2 + O --> HO2 + OH                 1.07641e7
#    7 │ O + H2O2 --> OH + HO2                 1.07641e7
#    8 │ H + H2O2 --> H2O + OH                 1.42154e6
#    9 │ H2O2 + H --> H2O + OH                 1.42154e6
#   10 │ OH + OH --> H2O2                      3.00472e5
#   11 │ OD + H2O2 --> HDO + HO2               2.88412e5
#   12 │ O1D + H2O2 --> H2O2 + O          151025.0
#   13 │ H + H2O2 --> HO2 + H2                 1.48487e5
#   14 │ H2O2 + H --> HO2 + H2                 1.47959e5
#   15 │ D + H2O2 --> H2O + OD                37.4567
#   16 │ D + H2O2 --> HDO + OH                37.4567
#   17 │ HO2 + H2 --> H2O2 + H                 4.37853e-10
#   18 │ HO2 + H2O --> H2O2 + OH               8.88464e-16
#   19 │ H2O2 --> H2O + O1D                    0.0
#
# For H2Opl:
# 100% of reactions is 43/43
# The column rate of top 100.0% of reactions is 102955.94745668059
# Which equates to 100.0% of the total column rate (102955.94745668059).
#
# 43×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼──────────────────────────────────────────────
#    1 │ CO2pl + H2O --> H2Opl + CO2  31542.2
#    2 │ H2Opl + CO --> HCOpl + OH    29197.4
#    3 │ OHpl + H2 --> H2Opl + H      18653.6
#    4 │ H2Opl + E --> O + H + H       7021.99
#    5 │ H2Opl + O --> O2pl + H2       5514.01
#    6 │ H2Opl + O2 --> O2pl + H2O     4391.36
#    7 │ H2Opl + H2 --> H3Opl + H      2378.58
#    8 │ H2Opl + E --> OH + H          1978.31
#    9 │ H2Opl + E --> H2 + O           891.252
#   10 │ HCOpl + OH --> H2Opl + CO      588.811
#   11 │ Opl + H2O --> H2Opl + O        290.967
#   12 │ H3pl + O --> H2Opl + H         183.62
#   13 │ H2O --> H2Opl                  162.661
#   14 │ COpl + H2O --> H2Opl + CO       51.0511
#   15 │ H2Opl + C --> CHpl + OH         34.7721
#   16 │ N2pl + H2O --> H2Opl + N2       20.1849
#   17 │ OHpl + HD --> H2Opl + D         20.0046
#   18 │ H2Opl + N --> HNOpl + H         11.8444
#   19 │ ODpl + H2 --> H2Opl + D          4.5858
#   20 │ H2Opl + NO --> NOpl + H2O        4.5727
#   21 │ Npl + H2O --> H2Opl + N          3.58096
#   22 │ Cpl + H2O --> H2Opl + C          3.43306
#   23 │ H2Opl + N --> NOpl + H2          2.96111
#   24 │ Hpl + H2O --> H2Opl + H          0.848848
#   25 │ H2Opl + HD --> H2DOpl + H        0.662357
#   26 │ H2Opl + HD --> H3Opl + D         0.662357
#   27 │ OHpl + OH --> H2Opl + O          0.651195
#   28 │ OHpl + H2O --> H2Opl + OH        0.606347
#   29 │ H2Opl + H2O --> H3Opl + OH       0.347821
#   30 │ N2Hpl + OH --> H2Opl + N2        0.221286
#   31 │ H2Opl + OH --> H3Opl + O         0.135253
#   32 │ H2pl + H2O --> H2Opl + H2        0.103124
#   33 │ H2pl + OH --> H2Opl + H          0.0485939
#   34 │ NHpl + OH --> H2Opl + N          0.00606642
#   35 │ H3pl + OH --> H2Opl + H2         0.00185583
#   36 │ HNOpl + OH --> H2Opl + NO        0.00104962
#   37 │ Hpl + HDO --> H2Opl + D          0.000702098
#   38 │ HO2pl + OH --> H2Opl + O2        0.000476453
#   39 │ Dpl + H2O --> H2Opl + D          0.000218603
#   40 │ Arpl + H2O --> H2Opl + Ar        0.000145007
#   41 │ OHpl + HCO --> H2Opl + CO        8.73569e-5
#   42 │ H2Opl + HCO --> H3Opl + CO       1.93204e-5
#   43 │ H2Opl + HCO --> HCOpl + H2O      1.93204e-5
#
# For H2pl:
# 100% of reactions is 25/25
# The column rate of top 100.0% of reactions is 573614.5954446219
# Which equates to 100.0% of the total column rate (573614.5954446219).
#
# 25×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼───────────────────────────────────────────
#    1 │ H2 --> H2pl                    2.86808e5
#    2 │ H2pl + CO2 --> HCO2pl + H      1.9573e5
#    3 │ H2pl + O --> OHpl + H      40705.8
#    4 │ H2pl + N2 --> N2Hpl + H    20752.5
#    5 │ H2pl + CO --> HCOpl + H    15991.5
#    6 │ H2pl + Ar --> ArHpl + H     4987.98
#    7 │ H2pl + CO --> COpl + H2     3551.23
#    8 │ H2pl + H2 --> H3pl + H      2723.02
#    9 │ H2pl + O2 --> HO2pl + H     1273.19
#   10 │ H2pl + O2 --> O2pl + H2      519.224
#   11 │ H2pl + H --> Hpl + H2        401.013
#   12 │ H2pl + E --> H + H            92.4611
#   13 │ H2pl + N --> NHpl + H         50.1047
#   14 │ H2pl + C --> CHpl + H         25.9179
#   15 │ H2pl + NO --> HNOpl + H        1.04259
#   16 │ H2pl + NO --> NOpl + H2        1.04259
#   17 │ H2pl + H2O --> H2Opl + H2      0.103124
#   18 │ H2pl + H2O --> H3Opl + H       0.0913989
#   19 │ H2pl + OH --> H2Opl + H        0.0485939
#   20 │ H2pl + OH --> OHpl + H2        0.0485939
#   21 │ Arpl + H2 --> H2pl + Ar        0.0323665
#   22 │ Hpl + HCO --> H2pl + CO        6.24305e-5
#   23 │ H2pl + HCO --> H3pl + CO       2.08199e-5
#   24 │ H2pl + HCO --> HCOpl + H2      2.08199e-5
#   25 │ Hpl + H --> H2pl               2.91294e-6
#
# For H3Opl:
# 100% of reactions is 21/21
# The column rate of top 100.0% of reactions is 126195.46116816218
# Which equates to 100.0% of the total column rate (126195.46116816218).
#
# 21×2 DataFrame
#  Row │ Rxn                           Value
#      │ String                        Float64
# ─────┼───────────────────────────────────────────────
#    1 │ HCOpl + H2O --> H3Opl + CO    60708.7
#    2 │ H3Opl + E --> OH + H + H      37518.2
#    3 │ H3Opl + E --> H2O + H         15611.6
#    4 │ H3Opl + E --> OH + H2          8729.07
#    5 │ H2Opl + H2 --> H3Opl + H       2378.58
#    6 │ H3Opl + E --> H2 + O + H        812.475
#    7 │ HCO2pl + H2O --> H3Opl + CO2    433.383
#    8 │ HDOpl + H2 --> H3Opl + D          1.22527
#    9 │ H2Opl + HD --> H3Opl + D          0.662357
#   10 │ OHpl + H2O --> H3Opl + O          0.495756
#   11 │ N2Hpl + H2O --> H3Opl + N2        0.368836
#   12 │ H2Opl + H2O --> H3Opl + OH        0.347821
#   13 │ H3Opl + C --> HCOpl + H2          0.145331
#   14 │ H2Opl + OH --> H3Opl + O          0.135253
#   15 │ H2pl + H2O --> H3Opl + H          0.0913989
#   16 │ CHpl + H2O --> H3Opl + C          0.030422
#   17 │ H3pl + H2O --> H3Opl + H2         0.00291609
#   18 │ NHpl + H2O --> H3Opl + N          0.00253344
#   19 │ HNOpl + H2O --> H3Opl + NO        0.00158595
#   20 │ HO2pl + H2O --> H3Opl + O2        0.000217933
#   21 │ H2Opl + HCO --> H3Opl + CO        1.93204e-5
#
# For H3pl:
# 100% of reactions is 23/23
# The column rate of top 100.0% of reactions is 5690.843523995101
# Which equates to 100.0% of the total column rate (5690.843523995101).
#
# 23×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼───────────────────────────────────────────
#    1 │ H2pl + H2 --> H3pl + H      2723.02
#    2 │ H3pl + CO2 --> HCO2pl + H2  1737.11
#    3 │ H3pl + O --> OHpl + H2       427.638
#    4 │ H3pl + N2 --> N2Hpl + H2     277.577
#    5 │ H3pl + O --> H2Opl + H       183.62
#    6 │ H3pl + CO --> HCOpl + H2     117.363
#    7 │ H3pl + CO --> HOCpl + H2      78.6945
#    8 │ HOCpl + H2 --> H3pl + CO      74.116
#    9 │ NHpl + H2 --> H3pl + N        23.5771
#   10 │ ArHpl + H2 --> H3pl + Ar      20.952
#   11 │ H3pl + Ar --> ArHpl + H2       8.72566
#   12 │ H3pl + O2 --> HO2pl + H2       6.40355
#   13 │ HO2pl + H2 --> H3pl + O2       4.58091
#   14 │ H3pl + E --> H + H + H         4.41689
#   15 │ H3pl + E --> H2 + H            2.3703
#   16 │ H3pl + C --> CHpl + H2         0.493831
#   17 │ H3pl + N --> NHpl + H2         0.151493
#   18 │ H3pl + NO --> HNOpl + H2       0.0290538
#   19 │ H2Dpl + H2 --> H3pl + HD       0.00562174
#   20 │ H3pl + H2O --> H3Opl + H2      0.00291609
#   21 │ H3pl + OH --> H2Opl + H2       0.00185583
#   22 │ N2Hpl + H2 --> H3pl + N2       3.62304e-5
#   23 │ H2pl + HCO --> H3pl + CO       2.08199e-5
#
# For HCO:
# 100% of reactions is 31/31
# The column rate of top 100.0% of reactions is 5.242318647211368e7
# Which equates to 100.0% of the total column rate (5.242318647211368e7).
#
# 31×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼──────────────────────────────────────────────
#    1 │ CO + H --> HCO                   2.61704e7
#    2 │ HCO + O2 --> HO2 + CO            2.22961e7
#    3 │ HCO + O2 --> CO2 + OH            3.25867e6
#    4 │ HCO + O --> CO + OH              3.41079e5
#    5 │ HCO + O --> CO2 + H              3.41079e5
#    6 │ HCO + H --> CO + H2          14080.3
#    7 │ NHpl + CO2 --> NOpl + HCO     1635.31
#    8 │ HCO + OH --> H2O + CO          132.454
#    9 │ HCO + D --> CO + HD              5.67946
#   10 │ O2pl + HCO --> HCOpl + O2        1.60158
#   11 │ O2pl + HCO --> HO2pl + CO        1.60158
#   12 │ HCO + OD --> HDO + CO            0.0295915
#   13 │ Opl + HCO --> HCOpl + O          0.00870521
#   14 │ Opl + HCO --> OHpl + CO          0.00870521
#   15 │ COpl + HCO --> HCOpl + CO        0.00360049
#   16 │ N2pl + HCO --> HCOpl + N2        0.00151356
#   17 │ N2pl + HCO --> N2Hpl + CO        0.00151356
#   18 │ Cpl + HCO --> CHpl + CO          0.000827448
#   19 │ Cpl + HCO --> HCOpl + C          0.000827448
#   20 │ Npl + HCO --> HCOpl + N          0.000199854
#   21 │ Npl + HCO --> NHpl + CO          0.000199854
#   22 │ OHpl + HCO --> H2Opl + CO        8.73569e-5
#   23 │ OHpl + HCO --> HCOpl + OH        8.73569e-5
#   24 │ Hpl + HCO --> COpl + H2          6.24305e-5
#   25 │ Hpl + HCO --> H2pl + CO          6.24305e-5
#   26 │ Hpl + HCO --> HCOpl + H          6.24305e-5
#   27 │ H2pl + HCO --> H3pl + CO         2.08199e-5
#   28 │ H2pl + HCO --> HCOpl + H2        2.08199e-5
#   29 │ H2Opl + HCO --> H3Opl + CO       1.93204e-5
#   30 │ H2Opl + HCO --> HCOpl + H2O      1.93204e-5
#   31 │ HCO + HCO --> CO + CO + H2       1.14913e-6
#
# For HCO2pl:
# 100% of reactions is 23/23
# The column rate of top 100.0% of reactions is 2.5920568598671755e8
# Which equates to 100.0% of the total column rate (2.5920568598671755e8).
#
# 23×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼──────────────────────────────────────────────
#    1 │ CO2pl + H2 --> HCO2pl + H          1.27302e8
#    2 │ HCO2pl + O --> HCOpl + O2          6.29888e7
#    3 │ HCO2pl + CO --> HCOpl + CO2        5.90042e7
#    4 │ HCO2pl + E --> CO + O + H          5.32587e6
#    5 │ HCO2pl + E --> CO + OH             2.11468e6
#    6 │ OHpl + CO2 --> HCO2pl + O          1.42099e6
#    7 │ HCO2pl + E --> CO2 + H             3.91608e5
#    8 │ N2Hpl + CO2 --> HCO2pl + N2        3.07621e5
#    9 │ H2pl + CO2 --> HCO2pl + H          1.9573e5
#   10 │ HOCpl + CO2 --> HCO2pl + CO    86657.0
#   11 │ CO2pl + H2O --> HCO2pl + OH    23211.5
#   12 │ CO2pl + HD --> HCO2pl + D      19192.6
#   13 │ HCO2pl + C --> CHpl + CO2      13221.6
#   14 │ ArHpl + CO2 --> HCO2pl + Ar     3882.06
#   15 │ NHpl + CO2 --> HCO2pl + N       1907.86
#   16 │ HNOpl + CO2 --> HCO2pl + NO     1756.93
#   17 │ H3pl + CO2 --> HCO2pl + H2      1737.11
#   18 │ HO2pl + CO2 --> HCO2pl + O2     1006.02
#   19 │ HCOpl + OH --> HCO2pl + H        952.004
#   20 │ HCO2pl + H2O --> H3Opl + CO2     433.383
#   21 │ HDpl + CO2 --> HCO2pl + D        145.314
#   22 │ CO2pl + HDO --> HCO2pl + OD       10.975
#   23 │ HCO2pl + HDO --> H2DOpl + CO2      0.803133
#
# For HCOpl:
# 100% of reactions is 50/50
# The column rate of top 100.0% of reactions is 2.914250888038997e8
# Which equates to 100.0% of the total column rate (2.914250888038997e8).
#
# 50×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼──────────────────────────────────────────────
#    1 │ HCOpl + E --> CO + H             1.42594e8
#    2 │ HCO2pl + O --> HCOpl + O2        6.29888e7
#    3 │ HCO2pl + CO --> HCOpl + CO2      5.90042e7
#    4 │ CO2pl + H --> HCOpl + O          2.19129e7
#    5 │ Hpl + CO2 --> HCOpl + O          3.17428e6
#    6 │ HCOpl + E --> OH + C             8.2702e5
#    7 │ CHpl + CO2 --> HCOpl + CO        2.67614e5
#    8 │ HCOpl + C --> CHpl + CO          2.62679e5
#    9 │ COpl + H2 --> HCOpl + H          1.94077e5
#   10 │ OHpl + CO --> HCOpl + O      64253.6
#   11 │ HCOpl + H2O --> H3Opl + CO   60708.7
#   12 │ H2Opl + CO --> HCOpl + OH    29197.4
#   13 │ N2Hpl + CO --> HCOpl + N2    23901.6
#   14 │ H2pl + CO --> HCOpl + H      15991.5
#   15 │ HOCpl + CO --> HCOpl + CO     1840.05
#   16 │ HCOpl + OH --> HCO2pl + H      952.004
#   17 │ CHpl + O2 --> HCOpl + O        795.594
#   18 │ HCOpl + OH --> H2Opl + CO      588.811
#   19 │ HCOpl + D --> DCOpl + H        415.847
#   20 │ ArHpl + CO --> HCOpl + Ar      261.359
#   21 │ NHpl + CO --> HCOpl + N        200.802
#   22 │ HNOpl + CO --> HCOpl + NO      127.126
#   23 │ HCOpl + HDO --> H2DOpl + CO    119.246
#   24 │ H3pl + CO --> HCOpl + H2       117.363
#   25 │ HOCpl + H2 --> HCOpl + H2      105.09
#   26 │ COpl + HD --> HCOpl + D         57.3194
#   27 │ HO2pl + CO --> HCOpl + O2       57.169
#   28 │ HDOpl + CO --> HCOpl + OD       37.1698
#   29 │ DCOpl + H --> HCOpl + D         34.1463
#   30 │ COpl + H2O --> HCOpl + OH       27.489
#   31 │ Cpl + H2O --> HCOpl + H         15.0817
#   32 │ HDpl + CO --> HCOpl + D         10.9446
#   33 │ COpl + OH --> HCOpl + O          5.40559
#   34 │ CHpl + CO --> HCOpl + C          2.51542
#   35 │ O2pl + HCO --> HCOpl + O2        1.60158
#   36 │ H3Opl + C --> HCOpl + H2         0.145331
#   37 │ H2Dpl + CO --> HCOpl + HD        0.0847835
#   38 │ CHpl + H2O --> HCOpl + H2        0.0557309
#   39 │ DOCpl + H2 --> HCOpl + HD        0.0360155
#   40 │ COpl + HDO --> HCOpl + OD        0.0251372
#   41 │ Opl + HCO --> HCOpl + O          0.00870521
#   42 │ Cpl + HDO --> HCOpl + D          0.00700875
#   43 │ COpl + HCO --> HCOpl + CO        0.00360049
#   44 │ N2pl + HCO --> HCOpl + N2        0.00151356
#   45 │ Cpl + HCO --> HCOpl + C          0.000827448
#   46 │ Npl + HCO --> HCOpl + N          0.000199854
#   47 │ OHpl + HCO --> HCOpl + OH        8.73569e-5
#   48 │ Hpl + HCO --> HCOpl + H          6.24305e-5
#   49 │ H2pl + HCO --> HCOpl + H2        2.08199e-5
#   50 │ H2Opl + HCO --> HCOpl + H2O      1.93204e-5
#
# For HD:
# 100% of reactions is 51/51
# The column rate of top 100.0% of reactions is 2.6517907901187344e6
# Which equates to 100.0% of the total column rate (2.6517907901187344e6).
#
# 51×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼─────────────────────────────────────────────
#    1 │ OH + HD --> HDO + H             7.62911e5
#    2 │ H + DO2 --> HD + O2        754308.0
#    3 │ D + HO2 --> HD + O2             6.397e5
#    4 │ OH + HD --> H2O + D        300805.0
#    5 │ O1D + HD --> D + OH         67540.7
#    6 │ O1D + HD --> H + OD         67540.7
#    7 │ CO2pl + HD --> DCO2pl + H   19192.6
#    8 │ CO2pl + HD --> HCO2pl + D   19192.6
#    9 │ H + HD --> H2 + D           10001.6
#   10 │ HD + O --> OH + D            2753.05
#   11 │ H + D + M --> HD + M         1860.98
#   12 │ D + H2 --> HD + H            1566.65
#   13 │ Opl + HD --> OHpl + D        1040.84
#   14 │ HD + O --> OD + H            1004.58
#   15 │ Opl + HD --> ODpl + H         886.639
#   16 │ HD --> HDpl                   408.143
#   17 │ HD --> H + D                  271.271
#   18 │ N2pl + HD --> N2Dpl + H       172.373
#   19 │ N2pl + HD --> N2Hpl + D       165.613
#   20 │ COpl + HD --> DCOpl + H        57.3194
#   21 │ COpl + HD --> DOCpl + H        57.3194
#   22 │ COpl + HD --> HCOpl + D        57.3194
#   23 │ COpl + HD --> HOCpl + D        57.3194
#   24 │ HDO --> HD + O1D               51.541
#   25 │ HD --> Dpl + H                 45.3492
#   26 │ HD --> Hpl + D                 45.3492
#   27 │ HDOpl + O --> O2pl + HD        20.5053
#   28 │ OHpl + HD --> H2Opl + D        20.0046
#   29 │ OHpl + HD --> HDOpl + H        20.0046
#   30 │ H2DOpl + E --> OH + HD          9.2411
#   31 │ DCO + H --> CO + HD             8.01274
#   32 │ HCO + D --> CO + HD             5.67946
#   33 │ Dpl + H2 --> Hpl + HD           4.46848
#   34 │ HDOpl + E --> HD + O            3.09606
#   35 │ Npl + HD --> NHpl + D           2.30923
#   36 │ H2DOpl + E --> HD + O + H       0.860133
#   37 │ H2Opl + HD --> H2DOpl + H       0.662357
#   38 │ H2Opl + HD --> H3Opl + D        0.662357
#   39 │ Hpl + HD --> Dpl + H2           0.580254
#   40 │ H2Dpl + CO --> HCOpl + HD       0.0847835
#   41 │ ArHpl + HD --> H2Dpl + Ar       0.0382802
#   42 │ DOCpl + H2 --> HCOpl + HD       0.0360155
#   43 │ ArDpl + H2 --> ArHpl + HD       0.0214036
#   44 │ HDOpl + N --> NOpl + HD         0.00925532
#   45 │ H2Dpl + H2 --> H3pl + HD        0.00562174
#   46 │ HDO --> Opl + HD                0.00511527
#   47 │ HDpl + HD --> H2Dpl + D         0.0042868
#   48 │ Arpl + HD --> ArDpl + H         0.000975465
#   49 │ Arpl + HD --> ArHpl + D         0.000934821
#   50 │ Arpl + HD --> HDpl + Ar         0.000121933
#   51 │ Cpl + HD --> CHpl + D           2.973e-6
#
# For HDO:
# 100% of reactions is 51/51
# The column rate of top 100.0% of reactions is 3.9726789234439895e7
# Which equates to 100.0% of the total column rate (3.9726789234439895e7).
#
# 51×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼─────────────────────────────────────────────────
#    1 │ OH + DO2 --> HDO + O2               8.90007e6
#    2 │ OD + HO2 --> HDO + O2               8.75583e6
#    3 │ HDO --> D + OH                      8.49736e6
#    4 │ HDO --> H + OD                      8.49736e6
#    5 │ O1D + HDO --> OD + OH               2.78704e6
#    6 │ OH + HD --> HDO + H                 7.62911e5
#    7 │ OD + H2 --> HDO + H                 4.26944e5
#    8 │ H + DO2 --> HDO + O1D          349824.0
#    9 │ D + HO2 --> HDO + O1D               2.96673e5
#   10 │ OD + H2O2 --> HDO + HO2             2.88412e5
#   11 │ OH + HDO2 --> HDO + HO2             1.48677e5
#   12 │ OD + OH --> HDO + O             12561.5
#   13 │ H + OD + CO2 --> HDO + CO2       1518.84
#   14 │ D + OH + CO2 --> HDO + CO2       1173.31
#   15 │ CO2pl + HDO --> HDOpl + CO2       131.7
#   16 │ HCOpl + HDO --> H2DOpl + CO       119.246
#   17 │ HDO --> HD + O1D                   51.541
#   18 │ D + H2O2 --> HDO + OH              37.4567
#   19 │ H + HDO2 --> HDO + OH              28.4459
#   20 │ HDOpl + O2 --> O2pl + HDO          24.5543
#   21 │ H2DOpl + E --> HDO + H             16.5274
#   22 │ CO2pl + HDO --> DCO2pl + OH        10.975
#   23 │ CO2pl + HDO --> HCO2pl + OD        10.975
#   24 │ HCO2pl + HDO --> H2DOpl + CO2       0.803133
#   25 │ Opl + HDO --> HDOpl + O             0.52758
#   26 │ HDO --> HDOpl                       0.30218
#   27 │ HOCO + OD --> CO2 + HDO             0.17565
#   28 │ DOCO + OH --> CO2 + HDO             0.168086
#   29 │ COpl + HDO --> HDOpl + CO           0.0933668
#   30 │ HDO --> ODpl + H                    0.0586517
#   31 │ HDO --> OHpl + D                    0.0586517
#   32 │ N2pl + HDO --> HDOpl + N2           0.035161
#   33 │ HDO --> Dpl + OH                    0.0319346
#   34 │ HDO --> Hpl + OD                    0.0319346
#   35 │ DCO + OH --> HDO + CO               0.0310397
#   36 │ HCO + OD --> HDO + CO               0.0295915
#   37 │ COpl + HDO --> DCOpl + OH           0.0251372
#   38 │ COpl + HDO --> HCOpl + OD           0.0251372
#   39 │ HDOpl + NO --> NOpl + HDO           0.0217685
#   40 │ Cpl + HDO --> DOCpl + H             0.0142392
#   41 │ Cpl + HDO --> HOCpl + D             0.0142392
#   42 │ Cpl + HDO --> DCOpl + H             0.00700875
#   43 │ Cpl + HDO --> HCOpl + D             0.00700875
#   44 │ Cpl + HDO --> HDOpl + C             0.00632853
#   45 │ HDO --> Opl + HD                    0.00511527
#   46 │ N2pl + HDO --> N2Dpl + OH           0.00466346
#   47 │ N2pl + HDO --> N2Hpl + OD           0.00466346
#   48 │ Hpl + HDO --> H2Opl + D             0.000702098
#   49 │ Hpl + HDO --> HDOpl + H             0.000702098
#   50 │ HDO --> H + D + O                   0.0
#   51 │ HDO2 --> HDO + O1D                  0.0
#
# For HDO2:
# 100% of reactions is 13/13
# The column rate of top 100.0% of reactions is 1.2557842024552768e7
# Which equates to 100.0% of the total column rate (1.2557842024552768e7).
#
# 13×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼────────────────────────────────────────────────
#    1 │ DO2 + HO2 --> HDO2 + O2              6.28822e6
#    2 │ HDO2 --> OH + OD                     5.58897e6
#    3 │ HDO2 --> DO2 + H                     1.49586e5
#    4 │ HDO2 --> HO2 + D                     1.49586e5
#    5 │ OH + HDO2 --> H2O + DO2              1.48677e5
#    6 │ OH + HDO2 --> HDO + HO2              1.48677e5
#    7 │ HO2 + DO2 + M --> HDO2 + O2 + M  81018.4
#    8 │ O + HDO2 --> OD + HO2             1482.19
#    9 │ O + HDO2 --> OH + DO2             1482.19
#   10 │ OD + OH --> HDO2                    86.8041
#   11 │ H + HDO2 --> H2O + OD               28.4459
#   12 │ H + HDO2 --> HDO + OH               28.4459
#   13 │ HDO2 --> HDO + O1D                   0.0
#
# For HDOpl:
# 100% of reactions is 23/23
# The column rate of top 100.0% of reactions is 313.5074168662531
# Which equates to 100.0% of the total column rate (313.5074168662531).
#
# 23×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼────────────────────────────────────────────
#    1 │ CO2pl + HDO --> HDOpl + CO2  131.7
#    2 │ HDOpl + CO --> DCOpl + OH     37.1698
#    3 │ HDOpl + CO --> HCOpl + OD     37.1698
#    4 │ HDOpl + O2 --> O2pl + HDO     24.5543
#    5 │ HDOpl + E --> O + D + H       24.3932
#    6 │ HDOpl + O --> O2pl + HD       20.5053
#    7 │ OHpl + HD --> HDOpl + H       20.0046
#    8 │ ODpl + H2 --> HDOpl + H        4.5858
#    9 │ HDOpl + E --> OD + H           3.43616
#   10 │ HDOpl + E --> OH + D           3.43616
#   11 │ HDOpl + E --> HD + O           3.09606
#   12 │ HDOpl + H2 --> H2DOpl + H      1.22527
#   13 │ HDOpl + H2 --> H3Opl + D       1.22527
#   14 │ Opl + HDO --> HDOpl + O        0.52758
#   15 │ HDO --> HDOpl                  0.30218
#   16 │ COpl + HDO --> HDOpl + CO      0.0933668
#   17 │ N2pl + HDO --> HDOpl + N2      0.035161
#   18 │ HDOpl + NO --> NOpl + HDO      0.0217685
#   19 │ HDOpl + N --> HNOpl + D        0.00925532
#   20 │ HDOpl + N --> NOpl + HD        0.00925532
#   21 │ Cpl + HDO --> HDOpl + C        0.00632853
#   22 │ Hpl + HDO --> HDOpl + H        0.000702098
#   23 │ Dpl + H2O --> HDOpl + H        0.000121877
#
# For HDpl:
# 100% of reactions is 15/15
# The column rate of top 100.0% of reactions is 816.2822496987881
# Which equates to 100.0% of the total column rate (816.2822496987881).
#
# 15×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ HD --> HDpl                408.143
#    2 │ HDpl + CO2 --> DCO2pl + H  145.314
#    3 │ HDpl + CO2 --> HCO2pl + D  145.314
#    4 │ HDpl + O --> ODpl + H       25.759
#    5 │ HDpl + O --> OHpl + D       25.759
#    6 │ HDpl + N2 --> N2Dpl + H     14.2168
#    7 │ HDpl + N2 --> N2Hpl + D     14.2168
#    8 │ HDpl + CO --> DCOpl + H     10.9446
#    9 │ HDpl + CO --> HCOpl + D     10.9446
#   10 │ HDpl + Ar --> ArHpl + D      8.03077
#   11 │ HDpl + Ar --> ArDpl + H      6.57063
#   12 │ HDpl + O2 --> HO2pl + D      0.89338
#   13 │ HDpl + E --> H + D           0.170984
#   14 │ HDpl + HD --> H2Dpl + D      0.0042868
#   15 │ Arpl + HD --> HDpl + Ar      0.000121933
#
# For HNOpl:
# 100% of reactions is 17/17
# The column rate of top 100.0% of reactions is 3860.7275492160315
# Which equates to 100.0% of the total column rate (3860.7275492160315).
#
# 17×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────────
#    1 │ NHpl + CO2 --> HNOpl + CO    1907.86
#    2 │ HNOpl + CO2 --> HCO2pl + NO  1756.93
#    3 │ HNOpl + CO --> HCOpl + NO     127.126
#    4 │ HNOpl + E --> NO + H           42.9243
#    5 │ H2Opl + N --> HNOpl + H        11.8444
#    6 │ OHpl + NO --> HNOpl + O         7.9586
#    7 │ HNOpl + N2 --> N2Hpl + NO       2.77169
#    8 │ N2Hpl + NO --> HNOpl + N2       1.56247
#    9 │ H2pl + NO --> HNOpl + H         1.04259
#   10 │ HOCpl + NO --> HNOpl + CO       0.387881
#   11 │ HNOpl + C --> CHpl + NO         0.264502
#   12 │ H3pl + NO --> HNOpl + H2        0.0290538
#   13 │ HDOpl + N --> HNOpl + D         0.00925532
#   14 │ HO2pl + NO --> HNOpl + O2       0.00903871
#   15 │ HNOpl + H2O --> H3Opl + NO      0.00158595
#   16 │ HNOpl + OH --> H2Opl + NO       0.00104962
#   17 │ NHpl + H2O --> HNOpl + H2       0.000844481
#
# For HO2:
# 100% of reactions is 36/36
# The column rate of top 100.0% of reactions is 2.952165156889833e12
# Which equates to 100.0% of the total column rate (2.952165156889833e12).
#
# 36×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼───────────────────────────────────────────────────
#    1 │ H + O2 --> HO2                        1.4822e12
#    2 │ HO2 + O --> O2 + OH                   1.34282e12
#    3 │ HO2 + H --> OH + OH                   4.35459e10
#    4 │ HO2 + OH --> H2O + O2                 3.06452e10
#    5 │ HO2 + HO2 --> H2O2 + O2               2.27018e10
#    6 │ HO2 --> OH + O                        1.83708e10
#    7 │ HOCO + O2 --> CO2 + HO2               5.84948e9
#    8 │ HO2 + H --> O2 + H2                   2.08658e9
#    9 │ OH + H2O2 --> H2O + HO2               1.09603e9
#   10 │ H2O2 --> HO2 + H                      1.07813e9
#   11 │ HO2 + H --> H2O + O1D                 9.67687e8
#   12 │ O3 + HO2 --> O2 + O2 + OH             3.59553e8
#   13 │ HO2 + HO2 + M --> H2O2 + O2 + M       2.81728e8
#   14 │ O3 + OH --> HO2 + O2                  6.05858e7
#   15 │ D + HO2 --> DO2 + H                   2.61155e7
#   16 │ HCO + O2 --> HO2 + CO                 2.22961e7
#   17 │ D + HO2 --> OH + OD                   1.33503e7
#   18 │ H2O2 + O --> HO2 + OH                 1.07641e7
#   19 │ O + H2O2 --> OH + HO2                 1.07641e7
#   20 │ OD + HO2 --> HDO + O2                 8.75583e6
#   21 │ DO2 + HO2 --> HDO2 + O2               6.28822e6
#   22 │ D + HO2 --> HD + O2                   6.397e5
#   23 │ D + HO2 --> HDO + O1D                 2.96673e5
#   24 │ OD + H2O2 --> HDO + HO2               2.88412e5
#   25 │ H + DO2 --> HO2 + D              228670.0
#   26 │ HO2 + N --> NO + OH              198821.0
#   27 │ HDO2 --> HO2 + D                      1.49586e5
#   28 │ OH + HDO2 --> HDO + HO2               1.48677e5
#   29 │ H + H2O2 --> HO2 + H2                 1.48487e5
#   30 │ H2O2 + H --> HO2 + H2                 1.47959e5
#   31 │ HO2 + DO2 + M --> HDO2 + O2 + M   81018.4
#   32 │ O + HDO2 --> OD + HO2              1482.19
#   33 │ HO2 + CO --> CO2 + OH                 9.29165e-7
#   34 │ HO2 + H2 --> H2O2 + H                 4.37853e-10
#   35 │ HO2 + H2O --> H2O2 + OH               8.88464e-16
#   36 │ O2 + H2 --> HO2 + H                   1.96851e-32
#
# For HO2pl:
# 100% of reactions is 17/17
# The column rate of top 100.0% of reactions is 2778.4163087032566
# Which equates to 100.0% of the total column rate (2778.4163087032566).
#
# 17×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────────
#    1 │ H2pl + O2 --> HO2pl + H      1273.19
#    2 │ HO2pl + CO2 --> HCO2pl + O2  1006.02
#    3 │ HO2pl + O --> OHpl + O2       199.316
#    4 │ HO2pl + N2 --> N2Hpl + O2     102.169
#    5 │ HOCpl + O2 --> HO2pl + CO      85.6268
#    6 │ HO2pl + CO --> HCOpl + O2      57.169
#    7 │ HO2pl + E --> O2 + H           19.6742
#    8 │ ArHpl + O2 --> HO2pl + Ar      13.225
#    9 │ NHpl + O2 --> HO2pl + N         8.40559
#   10 │ H3pl + O2 --> HO2pl + H2        6.40355
#   11 │ HO2pl + H2 --> H3pl + O2        4.58091
#   12 │ O2pl + HCO --> HO2pl + CO       1.60158
#   13 │ HDpl + O2 --> HO2pl + D         0.89338
#   14 │ HO2pl + C --> CHpl + O2         0.124144
#   15 │ HO2pl + NO --> HNOpl + O2       0.00903871
#   16 │ HO2pl + OH --> H2Opl + O2       0.000476453
#   17 │ HO2pl + H2O --> H3Opl + O2      0.000217933
#
# For HOCO:
# 100% of reactions is 4/4
# The column rate of top 100.0% of reactions is 1.1803441137026474e10
# Which equates to 100.0% of the total column rate (1.1803441137026474e10).
#
# 4×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼──────────────────────────────────────
#    1 │ CO + OH --> HOCO           5.95397e9
#    2 │ HOCO + O2 --> CO2 + HO2    5.84948e9
#    3 │ HOCO + OH --> CO2 + H2O  553.155
#    4 │ HOCO + OD --> CO2 + HDO    0.17565
#
# For HOCpl:
# 100% of reactions is 14/14
# The column rate of top 100.0% of reactions is 391997.8761246027
# Which equates to 100.0% of the total column rate (391997.8761246027).
#
# 14×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼────────────────────────────────────────────
#    1 │ COpl + H2 --> HOCpl + H          1.94077e5
#    2 │ HOCpl + E --> OH + C             1.04869e5
#    3 │ HOCpl + CO2 --> HCO2pl + CO  86657.0
#    4 │ HOCpl + N2 --> N2Hpl + CO     3956.68
#    5 │ HOCpl + CO --> HCOpl + CO     1840.05
#    6 │ HOCpl + E --> CO + H           166.437
#    7 │ HOCpl + H2 --> HCOpl + H2      105.09
#    8 │ HOCpl + O2 --> HO2pl + CO       85.6268
#    9 │ H3pl + CO --> HOCpl + H2        78.6945
#   10 │ HOCpl + H2 --> H3pl + CO        74.116
#   11 │ COpl + HD --> HOCpl + D         57.3194
#   12 │ Cpl + H2O --> HOCpl + H         30.8976
#   13 │ HOCpl + NO --> HNOpl + CO        0.387881
#   14 │ Cpl + HDO --> HOCpl + D          0.0142392
#
# For Hpl:
# 100% of reactions is 26/26
# The column rate of top 100.0% of reactions is 6.434514838648515e6
# Which equates to 100.0% of the total column rate (6.434514838648515e6).
#
# 26×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼──────────────────────────────────────────
#    1 │ Hpl + CO2 --> HCOpl + O      3.17428e6
#    2 │ CO2pl + H --> Hpl + CO2      2.69285e6
#    3 │ Opl + H --> Hpl + O          2.97234e5
#    4 │ H --> Hpl                    1.49971e5
#    5 │ COpl + H --> Hpl + CO    43545.9
#    6 │ Hpl + O --> Opl + H      36879.9
#    7 │ H2 --> Hpl + H           31867.5
#    8 │ Hpl + O2 --> O2pl + H     4762.93
#    9 │ Hpl + H --> H + Hpl       2641.17
#   10 │ H2pl + H --> Hpl + H2      401.013
#   11 │ HD --> Hpl + D              45.3492
#   12 │ H2O --> Hpl + OH            17.0067
#   13 │ Hpl + NO --> NOpl + H        9.26618
#   14 │ Dpl + H2 --> Hpl + HD        4.46848
#   15 │ Dpl + H --> D + Hpl          1.19811
#   16 │ Hpl + H2O --> H2Opl + H      0.848848
#   17 │ Hpl + HD --> Dpl + H2        0.580254
#   18 │ Hpl + OH --> OHpl + H        0.425851
#   19 │ Hpl + E --> H                0.236417
#   20 │ HDO --> Hpl + OD             0.0319346
#   21 │ Hpl + HDO --> H2Opl + D      0.000702098
#   22 │ Hpl + HDO --> HDOpl + H      0.000702098
#   23 │ Hpl + HCO --> COpl + H2      6.24305e-5
#   24 │ Hpl + HCO --> H2pl + CO      6.24305e-5
#   25 │ Hpl + HCO --> HCOpl + H      6.24305e-5
#   26 │ Hpl + H --> H2pl             2.91294e-6
#
# For N2Hpl:
# 100% of reactions is 26/26
# The column rate of top 100.0% of reactions is 713831.8974552002
# Which equates to 100.00000000000001% of the total column rate (713831.8974552002).
#
# 26×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────────
#    1 │ N2Hpl + CO2 --> HCO2pl + N2      3.07621e5
#    2 │ N2pl + H2 --> N2Hpl + H          2.96692e5
#    3 │ OHpl + N2 --> N2Hpl + O      34536.4
#    4 │ N2Hpl + CO --> HCOpl + N2    23901.6
#    5 │ H2pl + N2 --> N2Hpl + H      20752.5
#    6 │ N2Hpl + O --> OHpl + N2      20397.2
#    7 │ N2Hpl + E --> N2 + H          4470.32
#    8 │ HOCpl + N2 --> N2Hpl + CO     3956.68
#    9 │ NHpl + N2 --> N2Hpl + N        554.57
#   10 │ ArHpl + N2 --> N2Hpl + Ar      314.979
#   11 │ H3pl + N2 --> N2Hpl + H2       277.577
#   12 │ N2pl + HD --> N2Hpl + D        165.613
#   13 │ HO2pl + N2 --> N2Hpl + O2      102.169
#   14 │ N2Hpl + C --> CHpl + N2         64.4965
#   15 │ HDpl + N2 --> N2Hpl + D         14.2168
#   16 │ N2pl + H2O --> N2Hpl + OH        5.35431
#   17 │ HNOpl + N2 --> N2Hpl + NO        2.77169
#   18 │ N2Hpl + NO --> HNOpl + N2        1.56247
#   19 │ N2Hpl + H2O --> H3Opl + N2       0.368836
#   20 │ N2Hpl + D --> N2Dpl + H          0.249515
#   21 │ N2Hpl + OH --> H2Opl + N2        0.221286
#   22 │ N2Dpl + H --> N2Hpl + D          0.183649
#   23 │ NHpl + NO --> N2Hpl + O          0.0136811
#   24 │ N2pl + HDO --> N2Hpl + OD        0.00466346
#   25 │ N2pl + HCO --> N2Hpl + CO        0.00151356
#   26 │ N2Hpl + H2 --> H3pl + N2         3.62304e-5
#
# For NHpl:
# 100% of reactions is 21/21
# The column rate of top 100.0% of reactions is 17562.652772940466
# Which equates to 100.0% of the total column rate (17562.652772940466).
#
# 21×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼───────────────────────────────────────────
#    1 │ Npl + H2 --> NHpl + H      8746.9
#    2 │ NHpl + O --> OHpl + N      2489.04
#    3 │ NHpl + CO2 --> HCO2pl + N  1907.86
#    4 │ NHpl + CO2 --> HNOpl + CO  1907.86
#    5 │ NHpl + CO2 --> NOpl + HCO  1635.31
#    6 │ NHpl + N2 --> N2Hpl + N     554.57
#    7 │ NHpl + CO --> HCOpl + N     200.802
#    8 │ H2pl + N --> NHpl + H        50.1047
#    9 │ NHpl + H2 --> H3pl + N       23.5771
#   10 │ NHpl + E --> N + H           20.4365
#   11 │ NHpl + O2 --> NOpl + OH      10.507
#   12 │ NHpl + O2 --> HO2pl + N       8.40559
#   13 │ NHpl + N --> N2pl + H         3.1762
#   14 │ Npl + HD --> NHpl + D         2.30923
#   15 │ NHpl + C --> CHpl + N         1.62017
#   16 │ H3pl + N --> NHpl + H2        0.151493
#   17 │ NHpl + NO --> N2Hpl + O       0.0136811
#   18 │ NHpl + OH --> H2Opl + N       0.00606642
#   19 │ NHpl + H2O --> H3Opl + N      0.00253344
#   20 │ NHpl + H2O --> HNOpl + H2     0.000844481
#   21 │ Npl + HCO --> NHpl + CO       0.000199854
#
# For OH:
# 100% of reactions is 111/111
# The column rate of top 100.0% of reactions is 3.134859593593384e12
# Which equates to 100.0% of the total column rate (3.134859593593384e12).
#
# 111×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼───────────────────────────────────────────────
#    1 │ CO + OH --> CO2 + H               1.344e12
#    2 │ HO2 + O --> O2 + OH               1.34282e12
#    3 │ OH + O --> O2 + H                 2.05675e11
#    4 │ O3 + H --> O2 + OH                8.61523e10
#    5 │ HO2 + H --> OH + OH               4.35459e10
#    6 │ H2O --> H + OH                    3.24901e10
#    7 │ HO2 + OH --> H2O + O2             3.06452e10
#    8 │ H2O2 --> OH + OH                  2.01288e10
#    9 │ HO2 --> OH + O                    1.83708e10
#   10 │ CO + OH --> HOCO                  5.95397e9
#   11 │ O1D + H2O --> OH + OH             1.62693e9
#   12 │ OH + H2 --> H2O + H               1.61533e9
#   13 │ OH + H2O2 --> H2O + HO2           1.09603e9
#   14 │ O3 + HO2 --> O2 + O2 + OH         3.59553e8
#   15 │ O1D + H2 --> OH + H               1.32058e8
#   16 │ O3 + OH --> HO2 + O2              6.05858e7
#   17 │ OH + OH --> H2O + O               3.56231e7
#   18 │ OH + D --> OD + H                 2.00481e7
#   19 │ O + H --> OH                      1.91269e7
#   20 │ H2 + O --> OH + H                 1.87528e7
#   21 │ H + DO2 --> OH + OD               1.57421e7
#   22 │ D + HO2 --> OH + OD               1.33503e7
#   23 │ H2O2 + O --> HO2 + OH             1.07641e7
#   24 │ O + H2O2 --> OH + HO2             1.07641e7
#   25 │ OH + DO2 --> HDO + O2             8.90007e6
#   26 │ HDO --> D + OH                    8.49736e6
#   27 │ HDO2 --> OH + OD                  5.58897e6
#   28 │ OH + H + CO2 --> H2O + CO2        3.69939e6
#   29 │ HCO + O2 --> CO2 + OH             3.25867e6
#   30 │ O1D + HDO --> OD + OH             2.78704e6
#   31 │ HCO2pl + E --> CO + OH            2.11468e6
#   32 │ H + H2O2 --> H2O + OH             1.42154e6
#   33 │ H2O2 + H --> H2O + OH             1.42154e6
#   34 │ OH --> O + H                      1.39357e6
#   35 │ HCOpl + E --> OH + C              8.2702e5
#   36 │ OH + HD --> HDO + H               7.62911e5
#   37 │ HCO + O --> CO + OH               3.41079e5
#   38 │ OD + H --> OH + D                 3.14005e5
#   39 │ OH + HD --> H2O + D          300805.0
#   40 │ OH + OH --> H2O2                  3.00472e5
#   41 │ HO2 + N --> NO + OH          198821.0
#   42 │ OH + N --> NO + H                 1.59357e5
#   43 │ OH + HDO2 --> H2O + DO2           1.48677e5
#   44 │ OH + HDO2 --> HDO + HO2           1.48677e5
#   45 │ HOCpl + E --> OH + C              1.04869e5
#   46 │ O1D + HD --> D + OH           67540.7
#   47 │ H3Opl + E --> OH + H + H      37518.2
#   48 │ H2Opl + CO --> HCOpl + OH     29197.4
#   49 │ CO2pl + H2O --> HCO2pl + OH   23211.5
#   50 │ OD + OH --> HDO + O           12561.5
#   51 │ H3Opl + E --> OH + H2          8729.07
#   52 │ OHpl + O2 --> O2pl + OH        3422.46
#   53 │ OH + C --> CO + H              2821.32
#   54 │ HD + O --> OH + D              2753.05
#   55 │ H2Opl + E --> OH + H           1978.31
#   56 │ O + HDO2 --> OH + DO2          1482.19
#   57 │ D + OH + CO2 --> HDO + CO2     1173.31
#   58 │ HCOpl + OH --> HCO2pl + H       952.004
#   59 │ HCOpl + OH --> H2Opl + CO       588.811
#   60 │ HOCO + OH --> CO2 + H2O         553.155
#   61 │ HCO + OH --> H2O + CO           132.454
#   62 │ OD + OH --> HDO2                 86.8041
#   63 │ OH --> O1D + H                   52.9651
#   64 │ H2DOpl + E --> OH + D + H        39.719
#   65 │ D + H2O2 --> HDO + OH            37.4567
#   66 │ HDOpl + CO --> DCOpl + OH        37.1698
#   67 │ H2Opl + C --> CHpl + OH          34.7721
#   68 │ OH + H --> H2 + O                30.301
#   69 │ H + HDO2 --> HDO + OH            28.4459
#   70 │ COpl + H2O --> HCOpl + OH        27.489
#   71 │ Opl + OH --> O2pl + H            25.4526
#   72 │ Opl + OH --> OHpl + O            25.4526
#   73 │ H2O --> Hpl + OH                 17.0067
#   74 │ CO2pl + HDO --> DCO2pl + OH      10.975
#   75 │ OHpl + NO --> NOpl + OH          10.6158
#   76 │ NHpl + O2 --> NOpl + OH          10.507
#   77 │ H2DOpl + E --> OH + HD            9.2411
#   78 │ N2pl + OH --> OHpl + N2           8.05569
#   79 │ COpl + OH --> HCOpl + O           5.40559
#   80 │ COpl + OH --> OHpl + CO           5.40559
#   81 │ N2pl + H2O --> N2Hpl + OH         5.35431
#   82 │ Cpl + OH --> COpl + H             4.92356
#   83 │ HDOpl + E --> OH + D              3.43616
#   84 │ O2 + H --> OH + O                 0.825526
#   85 │ OHpl + OH --> H2Opl + O           0.651195
#   86 │ OHpl + H2O --> H2Opl + OH         0.606347
#   87 │ Npl + OH --> OHpl + N             0.518834
#   88 │ Hpl + OH --> OHpl + H             0.425851
#   89 │ H2Opl + H2O --> H3Opl + OH        0.347821
#   90 │ H2O + O --> OH + OH               0.347638
#   91 │ N2Hpl + OH --> H2Opl + N2         0.221286
#   92 │ DOCO + OH --> CO2 + HDO           0.168086
#   93 │ H2Opl + OH --> H3Opl + O          0.135253
#   94 │ H2pl + OH --> H2Opl + H           0.0485939
#   95 │ H2pl + OH --> OHpl + H2           0.0485939
#   96 │ HDO --> Dpl + OH                  0.0319346
#   97 │ DCO + OH --> HDO + CO             0.0310397
#   98 │ CHpl + OH --> COpl + H2           0.0291679
#   99 │ COpl + HDO --> DCOpl + OH         0.0251372
#  100 │ NHpl + OH --> H2Opl + N           0.00606642
#  101 │ N2pl + HDO --> N2Dpl + OH         0.00466346
#  102 │ H3pl + OH --> H2Opl + H2          0.00185583
#  103 │ HNOpl + OH --> H2Opl + NO         0.00104962
#  104 │ HO2pl + OH --> H2Opl + O2         0.000476453
#  105 │ OHpl + HCO --> HCOpl + OH         8.73569e-5
#  106 │ Arpl + H2O --> ArHpl + OH         3.61403e-5
#  107 │ H2O + H --> OH + H2               3.84817e-6
#  108 │ HO2 + CO --> CO2 + OH             9.29165e-7
#  109 │ CO2 + H --> CO + OH               1.06592e-7
#  110 │ HO2 + H2O --> H2O2 + OH           8.88464e-16
#  111 │ O2 + H2 --> OH + OH               1.21192e-19
#
# For OHpl:
# 100% of reactions is 36/36
# The column rate of top 100.0% of reactions is 3.643380677306023e6
# Which equates to 100.00000000000001% of the total column rate (3.643380677306023e6).
#
# 36×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼───────────────────────────────────────────
#    1 │ Opl + H2 --> OHpl + H          1.75584e6
#    2 │ OHpl + CO2 --> HCO2pl + O      1.42099e6
#    3 │ OHpl + O --> O2pl + H          2.76386e5
#    4 │ OHpl + CO --> HCOpl + O    64253.6
#    5 │ H2pl + O --> OHpl + H      40705.8
#    6 │ OHpl + N2 --> N2Hpl + O    34536.4
#    7 │ N2Hpl + O --> OHpl + N2    20397.2
#    8 │ OHpl + H2 --> H2Opl + H    18653.6
#    9 │ OHpl + O2 --> O2pl + OH     3422.46
#   10 │ OHpl + E --> O + H          2843.25
#   11 │ NHpl + O --> OHpl + N       2489.04
#   12 │ Opl + HD --> OHpl + D       1040.84
#   13 │ ArHpl + O --> OHpl + Ar      513.096
#   14 │ H3pl + O --> OHpl + H2       427.638
#   15 │ OHpl + N --> NOpl + H        337.164
#   16 │ HO2pl + O --> OHpl + O2      199.316
#   17 │ OHpl + C --> CHpl + O        186.522
#   18 │ H2O --> OHpl + H              31.6029
#   19 │ HDpl + O --> OHpl + D         25.759
#   20 │ Opl + OH --> OHpl + O         25.4526
#   21 │ OHpl + HD --> H2Opl + D       20.0046
#   22 │ OHpl + HD --> HDOpl + H       20.0046
#   23 │ OHpl + NO --> NOpl + OH       10.6158
#   24 │ N2pl + OH --> OHpl + N2        8.05569
#   25 │ OHpl + NO --> HNOpl + O        7.9586
#   26 │ COpl + OH --> OHpl + CO        5.40559
#   27 │ OHpl + OH --> H2Opl + O        0.651195
#   28 │ OHpl + H2O --> H2Opl + OH      0.606347
#   29 │ Npl + OH --> OHpl + N          0.518834
#   30 │ OHpl + H2O --> H3Opl + O       0.495756
#   31 │ Hpl + OH --> OHpl + H          0.425851
#   32 │ HDO --> OHpl + D               0.0586517
#   33 │ H2pl + OH --> OHpl + H2        0.0485939
#   34 │ Opl + HCO --> OHpl + CO        0.00870521
#   35 │ OHpl + HCO --> H2Opl + CO      8.73569e-5
#   36 │ OHpl + HCO --> HCOpl + OH      8.73569e-5

# %% [markdown]
# # Figure out which reactions need deuterated analogue by collecting reactions sufficient to comprise 99% of this total column rate

# %% [markdown]
# ## Take H-bearing rxn dataframe, filter out duplicates, and sort it by column value

# %%
bigdf_Hrxns_sorted_uniques = unique(sort(bigdf_Hrxns, [:Value], rev=true))
# Out:
# 437×2 DataFrame
#  Row │ Rxn                         Value
#      │ Any                         Any
# ─────┼─────────────────────────────────────────
#    1 │ H + O2 --> HO2              1.4822e12
#    2 │ CO + OH --> CO2 + H         1.344e12
#    3 │ HO2 + O --> O2 + OH         1.34282e12
#    4 │ OH + O --> O2 + H           2.05675e11
#    5 │ O3 + H --> O2 + OH          8.61523e10
#    6 │ HO2 + H --> OH + OH         4.35459e10
#    7 │ H2O --> H + OH              3.24901e10
#    8 │ HO2 + OH --> H2O + O2       3.06452e10
#    9 │ HO2 + HO2 --> H2O2 + O2     2.27018e10
#   10 │ H2O2 --> OH + OH            2.01288e10
#   11 │ HO2 --> OH + O              1.83708e10
#   ⋮  │             ⋮                    ⋮
#  428 │ HO2 + CO --> CO2 + OH       9.29165e-7
#  429 │ CO2 + H --> CO + OH         1.06592e-7
#  430 │ HO2 + H2 --> H2O2 + H       4.37853e-10
#  431 │ HO2 + H2O --> H2O2 + OH     8.88464e-16
#  432 │ O2 + H2 --> OH + OH         1.21192e-19
#  433 │ O2 + H2 --> HO2 + H         1.96851e-32
#  434 │ H2O --> H + H + O           0.0
#  435 │ HDO --> H + D + O           0.0
#  436 │ H2O2 --> H2O + O1D          0.0
#  437 │ HDO2 --> HDO + O1D          0.0
#                                416 rows omitted

# %% [markdown]
# ## Filter out any reactions that already are deuterated

# %%
# This is what we will filter out:
# blah = filter(row->any(x->occursin(x, row."Rxn"), [r"^D ", " D", "DO2", "HD", "DCO", "Dpl", "H2D", "OD"]), bigdf_sorted_uniques)
# for row in eachrow(blah)
#     println(row."Rxn")
# end
# println(nrow(blah))

deuteration_candidates = filter(row->!any(x->occursin(x, row."Rxn"), [r"^D ", " D", "DO2", "HD", "DCO", "Dpl", "H2D", "OD"]), bigdf_Hrxns_sorted_uniques)

# for row in eachrow(needs_d_analogue)
#     println(row."Rxn")
# end
# Out:
# 282×2 DataFrame
#  Row │ Rxn                          Value
#      │ Any                          Any
# ─────┼──────────────────────────────────────────
#    1 │ H + O2 --> HO2               1.4822e12
#    2 │ CO + OH --> CO2 + H          1.344e12
#    3 │ HO2 + O --> O2 + OH          1.34282e12
#    4 │ OH + O --> O2 + H            2.05675e11
#    5 │ O3 + H --> O2 + OH           8.61523e10
#    6 │ HO2 + H --> OH + OH          4.35459e10
#    7 │ H2O --> H + OH               3.24901e10
#    8 │ HO2 + OH --> H2O + O2        3.06452e10
#    9 │ HO2 + HO2 --> H2O2 + O2      2.27018e10
#   10 │ H2O2 --> OH + OH             2.01288e10
#   11 │ HO2 --> OH + O               1.83708e10
#   ⋮  │              ⋮                    ⋮
#  273 │ Hpl + H --> H2pl             2.91294e-6
#  274 │ HCO + HCO --> CO + CO + H2   1.14913e-6
#  275 │ HO2 + CO --> CO2 + OH        9.29165e-7
#  276 │ CO2 + H --> CO + OH          1.06592e-7
#  277 │ HO2 + H2 --> H2O2 + H        4.37853e-10
#  278 │ HO2 + H2O --> H2O2 + OH      8.88464e-16
#  279 │ O2 + H2 --> OH + OH          1.21192e-19
#  280 │ O2 + H2 --> HO2 + H          1.96851e-32
#  281 │ H2O --> H + H + O            0.0
#  282 │ H2O2 --> H2O + O1D           0.0
#                                 261 rows omitted

# %% [markdown]
# ## Retrieve only the reactions which comprise top 99.99% of the column rate

# %%
top_rxns = rxns_comprising_p_pct_colrate(deuteration_candidates, 0.9999; Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
# Out:
# 282 is 100.0%
# 281 is 100.0%
# 280 is 100.0%
# 279 is 100.0%
# 278 is 100.0%
# 277 is 100.0%
# 276 is 100.0%
# 275 is 100.0%
# 274 is 100.0%
# 273 is 100.0%
# 272 is 100.0%
# 271 is 100.0%
# 270 is 100.0%
# 269 is 100.0%
# 268 is 100.0%
# 267 is 100.0%
# 266 is 100.0%
# 265 is 100.0%
# 264 is 100.0%
# 263 is 100.0%
# 262 is 100.0%
# 261 is 100.0%
# 260 is 100.0%
# 259 is 100.0%
# 258 is 100.0%
# 257 is 100.0%
# 256 is 100.0%
# 255 is 100.0%
# 254 is 99.99999999999997%
# 253 is 99.99999999999996%
# 252 is 99.99999999999993%
# 251 is 99.99999999999991%
# 250 is 99.9999999999999%
# 249 is 99.99999999999986%
# 248 is 99.99999999999982%
# 247 is 99.99999999999977%
# 246 is 99.99999999999972%
# 245 is 99.99999999999967%
# 244 is 99.9999999999996%
# 243 is 99.99999999999952%
# 242 is 99.99999999999939%
# 241 is 99.9999999999992%
# 240 is 99.999999999999%
# 239 is 99.99999999999882%
# 238 is 99.99999999999854%
# 237 is 99.9999999999979%
# 236 is 99.99999999999727%
# 235 is 99.99999999999662%
# 234 is 99.99999999999592%
# 233 is 99.99999999999487%
# 232 is 99.99999999999383%
# 231 is 99.99999999999262%
# 230 is 99.99999999999065%
# 229 is 99.99999999998843%
# 228 is 99.99999999998576%
# 227 is 99.99999999998288%
# 226 is 99.99999999997974%
# 225 is 99.99999999997648%
# 224 is 99.9999999999717%
# 223 is 99.99999999996663%
# 222 is 99.99999999996095%
# 221 is 99.99999999995437%
# 220 is 99.99999999994733%
# 219 is 99.99999999993986%
# 218 is 99.99999999993238%
# 217 is 99.99999999992446%
# 216 is 99.99999999991611%
# 215 is 99.99999999990695%
# 214 is 99.99999999989633%
# 213 is 99.99999999988566%
# 212 is 99.99999999987452%
# 211 is 99.99999999986147%
# 210 is 99.99999999984746%
# 209 is 99.99999999982971%
# 208 is 99.99999999981148%
# 207 is 99.99999999978904%
# 206 is 99.99999999976662%
# 205 is 99.999999999733%
# 204 is 99.9999999996989%
# 203 is 99.99999999966447%
# 202 is 99.99999999963003%
# 201 is 99.99999999959519%
# 200 is 99.99999999954423%
# 199 is 99.99999999949013%
# 198 is 99.99999999943226%
# 197 is 99.99999999937266%
# 196 is 99.999999999309%
# 195 is 99.99999999924071%
# 194 is 99.99999999916689%
# 193 is 99.99999999908988%
# 192 is 99.99999999899629%
# 191 is 99.99999999890132%
# 190 is 99.99999999880299%
# 189 is 99.99999999870448%
# 188 is 99.99999999859861%
# 187 is 99.99999999848347%
# 186 is 99.99999999836724%
# 185 is 99.99999999825101%
# 184 is 99.99999999811331%
# 183 is 99.99999999794217%
# 182 is 99.99999999776894%
# 181 is 99.9999999975882%
# 180 is 99.99999999740056%
# 179 is 99.9999999972013%
# 178 is 99.99999999697538%
# 177 is 99.99999999674709%
# 176 is 99.99999999649239%
# 175 is 99.99999999620802%
# 174 is 99.9999999958837%
# 173 is 99.999999995518%
# 172 is 99.99999999509495%
# 171 is 99.99999999466091%
# 170 is 99.99999999422145%
# 169 is 99.99999999377091%
# 168 is 99.99999999326393%
# 167 is 99.99999999271662%
# 166 is 99.99999999216932%
# 165 is 99.99999999161199%
# 164 is 99.99999999102089%
# 163 is 99.99999999036932%
# 162 is 99.99999998970492%
# 161 is 99.99999998902535%
# 160 is 99.99999998831343%
# 159 is 99.99999998756572%
# 158 is 99.9999999866427%
# 157 is 99.9999999855653%
# 156 is 99.99999998446752%
# 155 is 99.9999999833286%
# 154 is 99.99999998209927%
# 153 is 99.99999998071239%
# 152 is 99.99999997911864%
# 151 is 99.99999997742646%
# 150 is 99.99999997558518%
# 149 is 99.99999997359697%
# 148 is 99.9999999714%
# 147 is 99.9999999691402%
# 146 is 99.99999996661653%
# 145 is 99.99999996388289%
# 144 is 99.99999996103469%
# 143 is 99.99999995753693%
# 142 is 99.99999995395797%
# 141 is 99.99999995000951%
# 140 is 99.99999994599865%
# 139 is 99.99999994177924%
# 138 is 99.99999993749327%
# 137 is 99.99999993317536%
# 136 is 99.99999992755525%
# 135 is 99.99999992158641%
# 134 is 99.99999991532965%
# 133 is 99.99999990855656%
# 132 is 99.99999990130641%
# 131 is 99.9999998926833%
# 130 is 99.99999988348766%
# 129 is 99.99999987416845%
# 128 is 99.99999986313516%
# 127 is 99.99999985197009%
# 126 is 99.99999984007539%
# 125 is 99.9999998281503%
# 124 is 99.99999981548888%
# 123 is 99.99999979924664%
# 122 is 99.9999997821387%
# 121 is 99.99999976466778%
# 120 is 99.99999974550288%
# 119 is 99.9999997250316%
# 118 is 99.99999970339873%
# 117 is 99.9999996760208%
# 116 is 99.99999964085615%
# 115 is 99.99999960350246%
# 114 is 99.99999956572252%
# 113 is 99.9999995261553%
# 112 is 99.99999948512988%
# 111 is 99.99999944410443%
# 110 is 99.99999940156414%
# 109 is 99.99999935041664%
# 108 is 99.99999929689398%
# 107 is 99.9999992401%
# 106 is 99.99999918154604%
# 105 is 99.99999912087823%
# 104 is 99.99999905973883%
# 103 is 99.99999898614442%
# 102 is 99.99999890978117%
# 101 is 99.99999882630382%
# 100 is 99.99999874122197%
# 99 is 99.999998646793%
# 98 is 99.99999855066609%
# 97 is 99.99999844824724%
# 96 is 99.99999834098897%
# 95 is 99.99999822241917%
# 94 is 99.99999807522822%
# 93 is 99.99999792423199%
# 92 is 99.99999773652782%
# 91 is 99.9999975484402%
# 90 is 99.99999726413219%
# 89 is 99.99999696135897%
# 88 is 99.99999662565727%
# 87 is 99.9999962817855%
# 86 is 99.99999588067155%
# 85 is 99.99999544206398%
# 84 is 99.99999499581658%
# 83 is 99.99999449669133%
# 82 is 99.99999398272658%
# 81 is 99.99999335488523%
# 80 is 99.99999267662282%
# 79 is 99.99999199136475%
# 78 is 99.9999912487154%
# 77 is 99.99999045567395%
# 76 is 99.99998964890699%
# 75 is 99.9999887735962%
# 74 is 99.99998783721348%
# 73 is 99.999986531774%
# 72 is 99.99998515010682%
# 71 is 99.9999834818588%
# 70 is 99.99998161844175%
# 69 is 99.9999793634129%
# 68 is 99.99997618180493%
# 67 is 99.99997298883407%
# 66 is 99.99996976396486%
# 65 is 99.99996651642172%
# 64 is 99.99996308972095%
# 63 is 99.99995904773819%
# 62 is 99.99995487443638%
# 61 is 99.99995070113457%
# 60 is 99.99994649227364%
# 59 is 99.9999422169547%
# 58 is 99.99993656848348%
# 57 is 99.99993081389277%
# 56 is 99.9999248706583%
# 55 is 99.99991870332897%
# 54 is 99.9999123234662%
# 53 is 99.99990593194835%
# 52 is 99.99989947078679%
# 51 is 99.99989285589737%
# 50 is 99.99988552156125%
# 49 is 99.99987818722514%
# 48 is 99.99986976633683%
# 47 is 99.99985198263236%
# 46 is 99.99982201626098%
# 45 is 99.99979146018218%
# 44 is 99.99976089227182%
# 43 is 99.99973032436147%
# 42 is 99.99969256793058%
# 41 is 99.99964709513374%
# 40 is 99.9995891898262%
# 39 is 99.99952093210898%
# 38 is 99.99945085985193%
# 37 is 99.99937131048344%
# 36 is 99.99927118765159%
# 35 is 99.9991566635707%
# 34 is 99.99892519972772%
# 33 is 99.99869373588474%
# 32 is 99.99829048877562%
# 31 is 99.99787919626678%
# 30 is 99.99740799575328%
# 29 is 99.99692855399452%
# 28 is 99.99636580342717%
# 27 is 99.99559978767925%
# 26 is 99.99433099871605%
# 25 is 99.9930282002404%
# 24 is 99.99167373081706%
# 23 is 99.98893630967612%
# 23 reactions needed to make up 99.99% of col rate
# 23×2 DataFrame
#  Row │ Rxn                              Value
#      │ Any                              Any
# ─────┼─────────────────────────────────────────────
#    1 │ H + O2 --> HO2                   1.4822e12
#    2 │ CO + OH --> CO2 + H              1.344e12
#    3 │ HO2 + O --> O2 + OH              1.34282e12
#    4 │ OH + O --> O2 + H                2.05675e11
#    5 │ O3 + H --> O2 + OH               8.61523e10
#    6 │ HO2 + H --> OH + OH              4.35459e10
#    7 │ H2O --> H + OH                   3.24901e10
#    8 │ HO2 + OH --> H2O + O2            3.06452e10
#    9 │ HO2 + HO2 --> H2O2 + O2          2.27018e10
#   10 │ H2O2 --> OH + OH                 2.01288e10
#   11 │ HO2 --> OH + O                   1.83708e10
#   12 │ CO + OH --> HOCO                 5.95397e9
#   13 │ HOCO + O2 --> CO2 + HO2          5.84948e9
#   14 │ HO2 + H --> O2 + H2              2.08658e9
#   15 │ O1D + H2O --> OH + OH            1.62693e9
#   16 │ OH + H2 --> H2O + H              1.61533e9
#   17 │ OH + H2O2 --> H2O + HO2          1.09603e9
#   18 │ H2O2 --> HO2 + H                 1.07813e9
#   19 │ HO2 + H --> H2O + O1D            9.67687e8
#   20 │ O3 + HO2 --> O2 + O2 + OH        3.59553e8
#   21 │ HO2 + HO2 + M --> H2O2 + O2 + M  2.81728e8
#   22 │ HCOpl + E --> CO + H             1.42594e8
#   23 │ O1D + H2 --> OH + H              1.32058e8

# %% [markdown]
# # Now get the deuterated analogues

# %%
D_bearing_species = [s for s in setdiff(union(vardict["neutral_species"], vardict["ion_species"]), [:O1D, :Nup2D]) if occursin('D', string(s))];

# %%
function deuterated_combinations(s; D_to_H=false)
    #=
    Given a reactant or product string (i.e. one set of prodcuts),
    this figures out all the possible ways to singly deuterate it.
    No duplicates.
    =#
    
    prods_split = split(s, " + ")

    N = length(prods_split)
    n = collect(1:N)

    newopts = Array{String}(undef, N, N)

    # Fill in all possible options by changing to deuterated analogue of products, one by one
    for i in 1:N
        newopts[i, :] = [prods_split[j] for j in n] # fills in the array with the products
        newopts[i, i] = H_to_D(newopts[i, i]; reverse=D_to_H) 
    end
    
    # Blank out any rows for which the product sets are functionally the same
    for i in 1:N
        for j in i+1:N
            if Set(newopts[i, :]) == Set(newopts[j, :])
                newopts[j, :] .= ""
            end
        end
    end
    
    # Delete the blank rows
    deletetheserows = []
    if D_to_H == true 
        for i in 1:N      
            # get rid of any rows that have even one D-bearing species or a blank reactant/product
            # (takes care of rows that have a rogue O1D, and blank rows)
            if any(x->in(Symbol(x), D_bearing_species), newopts[i, :]) | any(x->x=="", newopts[i, :])
                append!(deletetheserows, i)
            end
        end
    else
        for i in 1:N      
            # get rid of any rows that don't have a D-bearing species 
            # (takes care of rows that have a rogue O1D, and blank rows)
            if all(x->!in(Symbol(x), D_bearing_species), newopts[i, :])
                append!(deletetheserows, i)
            end
        end
    end

    newopts = newopts[setdiff(1:end, deletetheserows), :]
    new_prod_str = []
    for i in 1:size(newopts)[1] # length has changed
        push!(new_prod_str, join(newopts[i, :], " + "))
    end

    return new_prod_str
end

function H_to_D(s; count=100, reverse=false)

    if reverse==true
        return replace(s, "O1D"=>"O1D", "H2D"=>"H3", "HD"=>"H2", "D"=>"H"; count=count) # This makes sure not to fuck up O1D
    else
        return replace(s, "H3"=>"H2D", "H2"=>"HD", "H"=>"D"; count=count)
    end
end
# Out:
# H_to_D (generic function with 1 method)

# %% [markdown]
# ## Testing...

# %%
deuterated_combinations("OH + H + H")
# Out:
# 2-element Vector{Any}:
#  "OD + H + H"
#  "OH + D + H"

# %%
deuterated_combinations("OH + OH")
# Out:
# 1-element Vector{Any}:
#  "OD + OH"

# %%
deuterated_combinations("H + H + H")
# Out:
# 1-element Vector{Any}:
#  "D + H + H"

# %% [markdown]
# ## Code that allows us to automatically create the deuterated analogue reactions

# %% [markdown]
# ### Good code

# %%
function translate_D_and_H(rxndf; D_to_H=false)
    #=
    Take a dataframe containing reactions and their column values and replace H with D to form deuterated analogues.
    =#
    
    look_for_these = []
    
    if D_to_H == true
        replaced_atom = "D"
    else
        replaced_atom = "H"
    end
    
    for r in eachrow(rxndf)
        reactants, products = decompose_chemistry_string(r[1]; returntype="strings")
        
        #Count H in the reactants and products
        H_or_D_in_reactants = count("replaced_atom", reactants)
        H_or_D_in_products = count("replaced_atom", products)
        
        if (H_or_D_in_reactants == 1) & (H_or_D_in_products == 1)
            new_reacts = H_to_D(reactants; reverse=D_to_H)
            new_prods = H_to_D(products; reverse=D_to_H)
            println("$(r[1]) -----> $(new_reacts) --> $(new_prods)")
            
            new_reacts_symb = [Symbol(r) for r in split(new_reacts, " + ")]
            new_prods_symb = [Symbol(r) for r in split(new_prods, " + ")]
            
            push!(look_for_these, [new_reacts_symb, new_prods_symb])
            println()
        else
            new_reacts = deuterated_combinations(reactants; D_to_H=D_to_H)
            new_prods = deuterated_combinations(products; D_to_H=D_to_H)
            
            println("Deuteration options for $(reactants) --> $(products)")
            for R in new_reacts
                for P in new_prods
                    new_reacts_symb = [Symbol(r) for r in split(R, " + ")]
                    new_prods_symb = [Symbol(p) for p in split(P, " + ")]
                    
                    # push!(look_for_these, "$(r) --> $(p)")
                    push!(look_for_these, [new_reacts_symb, new_prods_symb])
                    println("$(R) --> $(P)")
                end
            end

            println()
        
        end
    end
    return look_for_these
end
# Out:
# translate_D_and_H (generic function with 1 method)

# %%
look_for_these = translate_D_and_H(top_rxns."Rxn")
# Out:
# Deuteration options for H + O2 --> HO2
# D + O2 --> DO2
#
# Deuteration options for CO + OH --> CO2 + H
# CO + OD --> CO2 + D
#
# Deuteration options for HO2 + O --> O2 + OH
# DO2 + O --> O2 + OD
#
# Deuteration options for OH + O --> O2 + H
# OD + O --> O2 + D
#
# Deuteration options for O3 + H --> O2 + OH
# O3 + D --> O2 + OD
#
# Deuteration options for HO2 + H --> OH + OH
# DO2 + H --> OD + OH
# HO2 + D --> OD + OH
#
# Deuteration options for H2O --> H + OH
# HDO --> D + OH
# HDO --> H + OD
#
# Deuteration options for HO2 + OH --> H2O + O2
# DO2 + OH --> HDO + O2
# HO2 + OD --> HDO + O2
#
# Deuteration options for HO2 + HO2 --> H2O2 + O2
# DO2 + HO2 --> HDO2 + O2
#
# Deuteration options for H2O2 --> OH + OH
# HDO2 --> OD + OH
#
# Deuteration options for HO2 --> OH + O
# DO2 --> OD + O
#
# Deuteration options for CO + OH --> HOCO
# CO + OD --> DOCO
#
# Deuteration options for HOCO + O2 --> CO2 + HO2
# DOCO + O2 --> CO2 + DO2
#
# Deuteration options for HO2 + H --> O2 + H2
# DO2 + H --> O2 + HD
# HO2 + D --> O2 + HD
#
# Deuteration options for O1D + H2O --> OH + OH
# O1D + HDO --> OD + OH
#
# Deuteration options for OH + H2 --> H2O + H
# OD + H2 --> HDO + H
# OD + H2 --> H2O + D
# OH + HD --> HDO + H
# OH + HD --> H2O + D
#
# Deuteration options for OH + H2O2 --> H2O + HO2
# OD + H2O2 --> HDO + HO2
# OD + H2O2 --> H2O + DO2
# OH + HDO2 --> HDO + HO2
# OH + HDO2 --> H2O + DO2
#
# Deuteration options for H2O2 --> HO2 + H
# HDO2 --> DO2 + H
# HDO2 --> HO2 + D
#
# Deuteration options for HO2 + H --> H2O + O1D
# DO2 + H --> HDO + O1D
# HO2 + D --> HDO + O1D
#
# Deuteration options for O3 + HO2 --> O2 + O2 + OH
# O3 + DO2 --> O2 + O2 + OD
#
# Deuteration options for HO2 + HO2 + M --> H2O2 + O2 + M
# DO2 + HO2 + M --> HDO2 + O2 + M
#
# Deuteration options for HCOpl + E --> CO + H
# DCOpl + E --> CO + D
#
# Deuteration options for O1D + H2 --> OH + H
# O1D + HD --> OD + H
# O1D + HD --> OH + D
# 36-element Vector{Any}:
#  [[:D, :O2], [:DO2]]
#  [[:CO, :OD], [:CO2, :D]]
#  [[:DO2, :O], [:O2, :OD]]
#  [[:OD, :O], [:O2, :D]]
#  [[:O3, :D], [:O2, :OD]]
#  [[:DO2, :H], [:OD, :OH]]
#  [[:HO2, :D], [:OD, :OH]]
#  [[:HDO], [:D, :OH]]
#  [[:HDO], [:H, :OD]]
#  [[:DO2, :OH], [:HDO, :O2]]
#  [[:HO2, :OD], [:HDO, :O2]]
#  [[:DO2, :HO2], [:HDO2, :O2]]
#  [[:HDO2], [:OD, :OH]]
#  ⋮
#  [[:OD, :H2O2], [:H2O, :DO2]]
#  [[:OH, :HDO2], [:HDO, :HO2]]
#  [[:OH, :HDO2], [:H2O, :DO2]]
#  [[:HDO2], [:DO2, :H]]
#  [[:HDO2], [:HO2, :D]]
#  [[:DO2, :H], [:HDO, :O1D]]
#  [[:HO2, :D], [:HDO, :O1D]]
#  [[:O3, :DO2], [:O2, :O2, :OD]]
#  [[:DO2, :HO2, :M], [:HDO2, :O2, :M]]
#  [[:DCOpl, :E], [:CO, :D]]
#  [[:O1D, :HD], [:OD, :H]]
#  [[:O1D, :HD], [:OH, :D]]

# %% [markdown]
# # Search for the deuterated analogues in the network

# %%
function reactions_present(rxns_to_find; return_found=false, reaction_network)
    #=
    rxns_to_find: list of reactions like [[reactants], [products]] (symbols) that
    are deuterated analogues that we should have in reaction_network. reports how many
    are not there and what they are.
    WARNING: It is finding an O1D reaction that it shouldn't be check each to be sure
    =#
    
    missing_count = 0
    not_found = []
    
    found = []

    flag = false
    for rxn in rxns_to_find
        for rxn_in_net in reaction_network
            if (Set(rxn[1])==Set(rxn_in_net[1])) & (Set(rxn[2])==Set(rxn_in_net[2]))
                # println("Found $(format_chemistry_string(rxn[1], rxn[2])) match: $(format_chemistry_string(rxn_in_net[1], rxn_in_net[2]))")
                flag = true
                push!(found, rxn_in_net)
            end
        end
        if flag == false
            push!(not_found, rxn)
            # println("\n !!!!!!!!!!!!!!!!! \n $(rxn) not found in the network\n !!!!!!!!!!!!!!!!! \n ")
            missing_count += 1
        end
        flag = false
    end
    println("Missing $(missing_count) reactions")
    
    if return_found
        if missing_count > 0
            println("These are the ones I couldn't find, suspiciously")
            println(not_found)
            println()
        end
        return found
    else
        return not_found
    end
end
# Out:
# reactions_present (generic function with 1 method)

# %%
not_found = reactions_present(look_for_these; reaction_network)
# Out:
# Missing 2 reactions
# 2-element Vector{Any}:
#  [[:OD, :H2], [:H2O, :D]]
#  [[:OD, :H2O2], [:H2O, :DO2]]

# %% [markdown]
# Wait a second--that first reaction isn't possible. I think the code is coming up with garbage. Need to review the auto-creation of the analogues...

# %% [markdown]
# # Figure out exactly how much of the total H column the H analogues of our actual D network cover.

# %%
bigdf_Drxns = DataFrame(Rxn=[], Value=[])

# Retrieve 100% of reactions for all species
for Dsp in D_bearing_species
    # Get the basic df
    println("For $(Dsp): ")
    col_rate_df = get_column_rates_NEW(Dsp, ncur; which="all", Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
    
    thisdf = get_p_pct_of_column(col_rate_df, 1; Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
    bigdf_Drxns = vcat(bigdf_Drxns, thisdf)
    println()
end
# Out:
# For D:
# 100% of reactions is 84/84
# The column rate of top 100.0% of reactions is 9.845765378507174e8
# Which equates to 100.0% of the total column rate (9.845765378507174e8).
#
# 84×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼──────────────────────────────────────────────
#    1 │ D + O2 --> DO2                   4.02785e8
#    2 │ CO + OD --> CO2 + D              3.87903e8
#    3 │ O + OD --> O2 + D                9.10775e7
#    4 │ D + O3 --> OD + O2               3.2716e7
#    5 │ D + HO2 --> DO2 + H              2.61155e7
#    6 │ OH + D --> OD + H                2.00481e7
#    7 │ D + HO2 --> OH + OD              1.33503e7
#    8 │ HDO --> D + OH                   8.49736e6
#    9 │ D + HO2 --> HD + O2              6.397e5
#   10 │ OD + H --> OH + D                3.14005e5
#   11 │ OH + HD --> H2O + D         300805.0
#   12 │ D + HO2 --> HDO + O1D            2.96673e5
#   13 │ H + DO2 --> HO2 + D         228670.0
#   14 │ HDO2 --> HO2 + D                 1.49586e5
#   15 │ O1D + HD --> D + OH          67540.7
#   16 │ CO2pl + HD --> HCO2pl + D    19192.6
#   17 │ DCOpl + E --> CO + D         18455.5
#   18 │ CO + D --> DCO               10902.5
#   19 │ H + HD --> H2 + D            10001.6
#   20 │ O + D --> OD                  9150.48
#   21 │ CO2pl + D --> DCOpl + O       3045.64
#   22 │ HD + O --> OH + D             2753.05
#   23 │ DCO2pl + E --> CO + O + D     2394.28
#   24 │ H + D + M --> HD + M          1860.98
#   25 │ D + H2 --> HD + H             1566.65
#   26 │ D + OH + CO2 --> HDO + CO2    1173.31
#   27 │ Opl + HD --> OHpl + D         1040.84
#   28 │ CO2pl + D --> Dpl + CO2        961.782
#   29 │ Dpl + CO2 --> CO2pl + D        782.129
#   30 │ OD --> O + D                   517.178
#   31 │ HCOpl + D --> DCOpl + H        415.847
#   32 │ HD --> H + D                   271.271
#   33 │ DCO + O --> CO2 + D            211.321
#   34 │ Opl + D --> Dpl + O            207.532
#   35 │ DCO2pl + E --> CO2 + D         176.05
#   36 │ N2pl + HD --> N2Hpl + D        165.613
#   37 │ D --> Dpl                      148.075
#   38 │ HDpl + CO2 --> HCO2pl + D      145.314
#   39 │ ODpl + O --> O2pl + D          140.201
#   40 │ COpl + HD --> HCOpl + D         57.3194
#   41 │ COpl + HD --> HOCpl + D         57.3194
#   42 │ HD --> Hpl + D                  45.3492
#   43 │ H2DOpl + E --> OH + D + H       39.719
#   44 │ D + H2O2 --> H2O + OD           37.4567
#   45 │ D + H2O2 --> HDO + OH           37.4567
#   46 │ DCOpl + H --> HCOpl + D         34.1463
#   47 │ HDpl + O --> OHpl + D           25.759
#   48 │ HDOpl + E --> O + D + H         24.3932
#   49 │ OHpl + HD --> H2Opl + D         20.0046
#   50 │ H2DOpl + E --> H2O + D          16.5274
#   51 │ HDpl + N2 --> N2Hpl + D         14.2168
#   52 │ Dpl + O --> D + Opl             11.699
#   53 │ HDpl + CO --> HCOpl + D         10.9446
#   54 │ COpl + D --> Dpl + CO            9.73291
#   55 │ N2pl + D --> Dpl + N2            9.47469
#   56 │ HDpl + Ar --> ArHpl + D          8.03077
#   57 │ HCO + D --> CO + HD              5.67946
#   58 │ ODpl + H2 --> H2Opl + D          4.5858
#   59 │ N2Dpl + E --> N2 + D             4.30468
#   60 │ HDOpl + E --> OH + D             3.43616
#   61 │ Npl + HD --> NHpl + D            2.30923
#   62 │ Dpl + O2 --> O2pl + D            2.05822
#   63 │ ODpl + E --> O + D               1.46403
#   64 │ HDOpl + H2 --> H3Opl + D         1.22527
#   65 │ Dpl + H --> D + Hpl              1.19811
#   66 │ HDpl + O2 --> HO2pl + D          0.89338
#   67 │ H2DOpl + E --> H2 + O + D        0.860133
#   68 │ H2Opl + HD --> H3Opl + D         0.662357
#   69 │ N2Hpl + D --> N2Dpl + H          0.249515
#   70 │ N2Dpl + H --> N2Hpl + D          0.183649
#   71 │ HDpl + E --> H + D               0.170984
#   72 │ ODpl + N --> NOpl + D            0.17014
#   73 │ HDO --> OHpl + D                 0.0586517
#   74 │ OD --> O1D + D                   0.0333291
#   75 │ Cpl + HDO --> HOCpl + D          0.0142392
#   76 │ HDOpl + N --> HNOpl + D          0.00925532
#   77 │ Cpl + HDO --> HCOpl + D          0.00700875
#   78 │ HDpl + HD --> H2Dpl + D          0.0042868
#   79 │ Dpl + NO --> NOpl + D            0.00298752
#   80 │ Arpl + HD --> ArHpl + D          0.000934821
#   81 │ Hpl + HDO --> H2Opl + D          0.000702098
#   82 │ Dpl + H2O --> H2Opl + D          0.000218603
#   83 │ Cpl + HD --> CHpl + D            2.973e-6
#   84 │ HDO --> H + D + O                0.0
#
# For DCO:
# 100% of reactions is 7/7
# The column rate of top 100.0% of reactions is 21838.898135053747
# Which equates to 100.0% of the total column rate (21838.898135053747).
#
# 7×2 DataFrame
#  Row │ Rxn                    Value
#      │ String                 Float64
# ─────┼──────────────────────────────────────
#    1 │ CO + D --> DCO         10902.5
#    2 │ DCO + O2 --> DO2 + CO   9166.02
#    3 │ DCO + O2 --> CO2 + OD   1339.65
#    4 │ DCO + O --> CO + OD      211.321
#    5 │ DCO + O --> CO2 + D      211.321
#    6 │ DCO + H --> CO + HD        8.01274
#    7 │ DCO + OH --> HDO + CO      0.0310397
#
# For DO2:
# 100% of reactions is 19/19
# The column rate of top 100.0% of reactions is 8.603702034177815e8
# Which equates to 100.0% of the total column rate (8.603702034177815e8).
#
# 19×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼─────────────────────────────────────────────────
#    1 │ D + O2 --> DO2                        4.02785e8
#    2 │ O + DO2 --> OD + O2                   3.92045e8
#    3 │ D + HO2 --> DO2 + H                   2.61155e7
#    4 │ H + DO2 --> OH + OD                   1.57421e7
#    5 │ OH + DO2 --> HDO + O2                 8.90007e6
#    6 │ DO2 + HO2 --> HDO2 + O2               6.28822e6
#    7 │ DO2 --> OD + O                        5.12786e6
#    8 │ DOCO + O2 --> DO2 + CO2               1.52371e6
#    9 │ H + DO2 --> HD + O2              754308.0
#   10 │ H + DO2 --> HDO + O1D            349824.0
#   11 │ H + DO2 --> HO2 + D              228670.0
#   12 │ HDO2 --> DO2 + H                      1.49586e5
#   13 │ OH + HDO2 --> H2O + DO2               1.48677e5
#   14 │ DO2 + O3 --> OD + O2 + O2             1.0422e5
#   15 │ HO2 + DO2 + M --> HDO2 + O2 + M   81018.4
#   16 │ OD + O3 --> DO2 + O2              15533.8
#   17 │ DCO + O2 --> DO2 + CO              9166.02
#   18 │ O + HDO2 --> OH + DO2              1482.19
#   19 │ DO2 + N --> NO + OD                  62.2126
#
# For DOCO:
# 100% of reactions is 3/3
# The column rate of top 100.0% of reactions is 3.074609301615067e6
# Which equates to 99.99999999999999% of the total column rate (3.074609301615067e6).
#
# 3×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼────────────────────────────────────
#    1 │ CO + OD --> DOCO         1.5509e6
#    2 │ DOCO + O2 --> DO2 + CO2  1.52371e6
#    3 │ DOCO + OH --> CO2 + HDO  0.168086
#
# For HD:
# 100% of reactions is 51/51
# The column rate of top 100.0% of reactions is 2.6517907901187344e6
# Which equates to 100.0% of the total column rate (2.6517907901187344e6).
#
# 51×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼─────────────────────────────────────────────
#    1 │ OH + HD --> HDO + H             7.62911e5
#    2 │ H + DO2 --> HD + O2        754308.0
#    3 │ D + HO2 --> HD + O2             6.397e5
#    4 │ OH + HD --> H2O + D        300805.0
#    5 │ O1D + HD --> D + OH         67540.7
#    6 │ O1D + HD --> H + OD         67540.7
#    7 │ CO2pl + HD --> DCO2pl + H   19192.6
#    8 │ CO2pl + HD --> HCO2pl + D   19192.6
#    9 │ H + HD --> H2 + D           10001.6
#   10 │ HD + O --> OH + D            2753.05
#   11 │ H + D + M --> HD + M         1860.98
#   12 │ D + H2 --> HD + H            1566.65
#   13 │ Opl + HD --> OHpl + D        1040.84
#   14 │ HD + O --> OD + H            1004.58
#   15 │ Opl + HD --> ODpl + H         886.639
#   16 │ HD --> HDpl                   408.143
#   17 │ HD --> H + D                  271.271
#   18 │ N2pl + HD --> N2Dpl + H       172.373
#   19 │ N2pl + HD --> N2Hpl + D       165.613
#   20 │ COpl + HD --> DCOpl + H        57.3194
#   21 │ COpl + HD --> DOCpl + H        57.3194
#   22 │ COpl + HD --> HCOpl + D        57.3194
#   23 │ COpl + HD --> HOCpl + D        57.3194
#   24 │ HDO --> HD + O1D               51.541
#   25 │ HD --> Dpl + H                 45.3492
#   26 │ HD --> Hpl + D                 45.3492
#   27 │ HDOpl + O --> O2pl + HD        20.5053
#   28 │ OHpl + HD --> H2Opl + D        20.0046
#   29 │ OHpl + HD --> HDOpl + H        20.0046
#   30 │ H2DOpl + E --> OH + HD          9.2411
#   31 │ DCO + H --> CO + HD             8.01274
#   32 │ HCO + D --> CO + HD             5.67946
#   33 │ Dpl + H2 --> Hpl + HD           4.46848
#   34 │ HDOpl + E --> HD + O            3.09606
#   35 │ Npl + HD --> NHpl + D           2.30923
#   36 │ H2DOpl + E --> HD + O + H       0.860133
#   37 │ H2Opl + HD --> H2DOpl + H       0.662357
#   38 │ H2Opl + HD --> H3Opl + D        0.662357
#   39 │ Hpl + HD --> Dpl + H2           0.580254
#   40 │ H2Dpl + CO --> HCOpl + HD       0.0847835
#   41 │ ArHpl + HD --> H2Dpl + Ar       0.0382802
#   42 │ DOCpl + H2 --> HCOpl + HD       0.0360155
#   43 │ ArDpl + H2 --> ArHpl + HD       0.0214036
#   44 │ HDOpl + N --> NOpl + HD         0.00925532
#   45 │ H2Dpl + H2 --> H3pl + HD        0.00562174
#   46 │ HDO --> Opl + HD                0.00511527
#   47 │ HDpl + HD --> H2Dpl + D         0.0042868
#   48 │ Arpl + HD --> ArDpl + H         0.000975465
#   49 │ Arpl + HD --> ArHpl + D         0.000934821
#   50 │ Arpl + HD --> HDpl + Ar         0.000121933
#   51 │ Cpl + HD --> CHpl + D           2.973e-6
#
# For HDO:
# 100% of reactions is 51/51
# The column rate of top 100.0% of reactions is 3.9726789234439895e7
# Which equates to 100.0% of the total column rate (3.9726789234439895e7).
#
# 51×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼─────────────────────────────────────────────────
#    1 │ OH + DO2 --> HDO + O2               8.90007e6
#    2 │ OD + HO2 --> HDO + O2               8.75583e6
#    3 │ HDO --> D + OH                      8.49736e6
#    4 │ HDO --> H + OD                      8.49736e6
#    5 │ O1D + HDO --> OD + OH               2.78704e6
#    6 │ OH + HD --> HDO + H                 7.62911e5
#    7 │ OD + H2 --> HDO + H                 4.26944e5
#    8 │ H + DO2 --> HDO + O1D          349824.0
#    9 │ D + HO2 --> HDO + O1D               2.96673e5
#   10 │ OD + H2O2 --> HDO + HO2             2.88412e5
#   11 │ OH + HDO2 --> HDO + HO2             1.48677e5
#   12 │ OD + OH --> HDO + O             12561.5
#   13 │ H + OD + CO2 --> HDO + CO2       1518.84
#   14 │ D + OH + CO2 --> HDO + CO2       1173.31
#   15 │ CO2pl + HDO --> HDOpl + CO2       131.7
#   16 │ HCOpl + HDO --> H2DOpl + CO       119.246
#   17 │ HDO --> HD + O1D                   51.541
#   18 │ D + H2O2 --> HDO + OH              37.4567
#   19 │ H + HDO2 --> HDO + OH              28.4459
#   20 │ HDOpl + O2 --> O2pl + HDO          24.5543
#   21 │ H2DOpl + E --> HDO + H             16.5274
#   22 │ CO2pl + HDO --> DCO2pl + OH        10.975
#   23 │ CO2pl + HDO --> HCO2pl + OD        10.975
#   24 │ HCO2pl + HDO --> H2DOpl + CO2       0.803133
#   25 │ Opl + HDO --> HDOpl + O             0.52758
#   26 │ HDO --> HDOpl                       0.30218
#   27 │ HOCO + OD --> CO2 + HDO             0.17565
#   28 │ DOCO + OH --> CO2 + HDO             0.168086
#   29 │ COpl + HDO --> HDOpl + CO           0.0933668
#   30 │ HDO --> ODpl + H                    0.0586517
#   31 │ HDO --> OHpl + D                    0.0586517
#   32 │ N2pl + HDO --> HDOpl + N2           0.035161
#   33 │ HDO --> Dpl + OH                    0.0319346
#   34 │ HDO --> Hpl + OD                    0.0319346
#   35 │ DCO + OH --> HDO + CO               0.0310397
#   36 │ HCO + OD --> HDO + CO               0.0295915
#   37 │ COpl + HDO --> DCOpl + OH           0.0251372
#   38 │ COpl + HDO --> HCOpl + OD           0.0251372
#   39 │ HDOpl + NO --> NOpl + HDO           0.0217685
#   40 │ Cpl + HDO --> DOCpl + H             0.0142392
#   41 │ Cpl + HDO --> HOCpl + D             0.0142392
#   42 │ Cpl + HDO --> DCOpl + H             0.00700875
#   43 │ Cpl + HDO --> HCOpl + D             0.00700875
#   44 │ Cpl + HDO --> HDOpl + C             0.00632853
#   45 │ HDO --> Opl + HD                    0.00511527
#   46 │ N2pl + HDO --> N2Dpl + OH           0.00466346
#   47 │ N2pl + HDO --> N2Hpl + OD           0.00466346
#   48 │ Hpl + HDO --> H2Opl + D             0.000702098
#   49 │ Hpl + HDO --> HDOpl + H             0.000702098
#   50 │ HDO --> H + D + O                   0.0
#   51 │ HDO2 --> HDO + O1D                  0.0
#
# For HDO2:
# 100% of reactions is 13/13
# The column rate of top 100.0% of reactions is 1.2557842024552768e7
# Which equates to 100.0% of the total column rate (1.2557842024552768e7).
#
# 13×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼────────────────────────────────────────────────
#    1 │ DO2 + HO2 --> HDO2 + O2              6.28822e6
#    2 │ HDO2 --> OH + OD                     5.58897e6
#    3 │ HDO2 --> DO2 + H                     1.49586e5
#    4 │ HDO2 --> HO2 + D                     1.49586e5
#    5 │ OH + HDO2 --> H2O + DO2              1.48677e5
#    6 │ OH + HDO2 --> HDO + HO2              1.48677e5
#    7 │ HO2 + DO2 + M --> HDO2 + O2 + M  81018.4
#    8 │ O + HDO2 --> OD + HO2             1482.19
#    9 │ O + HDO2 --> OH + DO2             1482.19
#   10 │ OD + OH --> HDO2                    86.8041
#   11 │ H + HDO2 --> H2O + OD               28.4459
#   12 │ H + HDO2 --> HDO + OH               28.4459
#   13 │ HDO2 --> HDO + O1D                   0.0
#
# For OD:
# 100% of reactions is 46/46
# The column rate of top 100.0% of reactions is 9.86437469503797e8
# Which equates to 100.0% of the total column rate (9.86437469503797e8).
#
# 46×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────────
#    1 │ O + DO2 --> OD + O2              3.92045e8
#    2 │ CO + OD --> CO2 + D              3.87903e8
#    3 │ O + OD --> O2 + D                9.10775e7
#    4 │ D + O3 --> OD + O2               3.2716e7
#    5 │ OH + D --> OD + H                2.00481e7
#    6 │ H + DO2 --> OH + OD              1.57421e7
#    7 │ D + HO2 --> OH + OD              1.33503e7
#    8 │ OD + HO2 --> HDO + O2            8.75583e6
#    9 │ HDO --> H + OD                   8.49736e6
#   10 │ HDO2 --> OH + OD                 5.58897e6
#   11 │ DO2 --> OD + O                   5.12786e6
#   12 │ O1D + HDO --> OD + OH            2.78704e6
#   13 │ CO + OD --> DOCO                 1.5509e6
#   14 │ OD + H2 --> HDO + H              4.26944e5
#   15 │ OD + H --> OH + D                3.14005e5
#   16 │ OD + H2O2 --> HDO + HO2          2.88412e5
#   17 │ DO2 + O3 --> OD + O2 + O2        1.0422e5
#   18 │ O1D + HD --> H + OD          67540.7
#   19 │ OD + O3 --> DO2 + O2         15533.8
#   20 │ OD + OH --> HDO + O          12561.5
#   21 │ O + D --> OD                  9150.48
#   22 │ H + OD + CO2 --> HDO + CO2    1518.84
#   23 │ O + HDO2 --> OD + HO2         1482.19
#   24 │ DCOpl + E --> OD + C          1404.22
#   25 │ DCO + O2 --> CO2 + OD         1339.65
#   26 │ HD + O --> OD + H             1004.58
#   27 │ DCO2pl + E --> CO + OD         950.672
#   28 │ OD --> O + D                   517.178
#   29 │ DCO + O --> CO + OD            211.321
#   30 │ OD + OH --> HDO2                86.8041
#   31 │ DO2 + N --> NO + OD             62.2126
#   32 │ DOCpl + E --> OD + C            54.5236
#   33 │ H2DOpl + E --> OD + H + H       39.719
#   34 │ D + H2O2 --> H2O + OD           37.4567
#   35 │ HDOpl + CO --> HCOpl + OD       37.1698
#   36 │ H + HDO2 --> H2O + OD           28.4459
#   37 │ CO2pl + HDO --> HCO2pl + OD     10.975
#   38 │ H2DOpl + E --> OD + H2           9.2411
#   39 │ HDOpl + E --> OD + H             3.43616
#   40 │ ODpl + O2 --> O2pl + OD          1.81575
#   41 │ HOCO + OD --> CO2 + HDO          0.17565
#   42 │ OD --> O1D + D                   0.0333291
#   43 │ HDO --> Hpl + OD                 0.0319346
#   44 │ HCO + OD --> HDO + CO            0.0295915
#   45 │ COpl + HDO --> HCOpl + OD        0.0251372
#   46 │ N2pl + HDO --> N2Hpl + OD        0.00466346
#
# For ArDpl:
# 100% of reactions is 7/7
# The column rate of top 100.0% of reactions is 13.1432058842378
# Which equates to 100.0% of the total column rate (13.1432058842378).
#
# 7×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼──────────────────────────────────────────
#    1 │ HDpl + Ar --> ArDpl + H      6.57063
#    2 │ ArDpl + CO2 --> DCO2pl + Ar  5.76634
#    3 │ ArDpl + CO --> DCOpl + Ar    0.389776
#    4 │ ArDpl + N2 --> N2Dpl + Ar    0.352224
#    5 │ ArDpl + H2 --> H2Dpl + Ar    0.0418559
#    6 │ ArDpl + H2 --> ArHpl + HD    0.0214036
#    7 │ Arpl + HD --> ArDpl + H      0.000975465
#
# For DCO2pl:
# 100% of reactions is 11/11
# The column rate of top 100.0% of reactions is 40189.593824085234
# Which equates to 100.0% of the total column rate (40189.593824085234).
#
# 11×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼──────────────────────────────────────────────
#    1 │ CO2pl + HD --> DCO2pl + H      19192.6
#    2 │ DCO2pl + O --> DCOpl + O2       8543.24
#    3 │ DCO2pl + CO --> DCOpl + CO2     7990.88
#    4 │ DCO2pl + E --> CO + O + D       2394.28
#    5 │ DCO2pl + E --> CO + OD           950.672
#    6 │ ODpl + CO2 --> DCO2pl + O        779.744
#    7 │ DCO2pl + E --> CO2 + D           176.05
#    8 │ HDpl + CO2 --> DCO2pl + H        145.314
#    9 │ CO2pl + HDO --> DCO2pl + OH       10.975
#   10 │ ArDpl + CO2 --> DCO2pl + Ar        5.76634
#   11 │ DCO2pl + H2O --> H2DOpl + CO2      0.0588014
#
# For DCOpl:
# 100% of reactions is 19/19
# The column rate of top 100.0% of reactions is 40756.035681382236
# Which equates to 100.0% of the total column rate (40756.035681382236).
#
# 19×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────────
#    1 │ DCOpl + E --> CO + D         18455.5
#    2 │ DCO2pl + O --> DCOpl + O2     8543.24
#    3 │ DCO2pl + CO --> DCOpl + CO2   7990.88
#    4 │ CO2pl + D --> DCOpl + O       3045.64
#    5 │ DCOpl + E --> OD + C          1404.22
#    6 │ Dpl + CO2 --> DCOpl + O        581.01
#    7 │ HCOpl + D --> DCOpl + H        415.847
#    8 │ N2Dpl + CO --> DCOpl + N2      128.83
#    9 │ COpl + HD --> DCOpl + H         57.3194
#   10 │ HDOpl + CO --> DCOpl + OH       37.1698
#   11 │ DCOpl + H --> HCOpl + D         34.1463
#   12 │ ODpl + CO --> DCOpl + O         33.6709
#   13 │ DCOpl + H2O --> H2DOpl + CO     12.463
#   14 │ HDpl + CO --> DCOpl + H         10.9446
#   15 │ DOCpl + CO --> DCOpl + CO        4.73905
#   16 │ ArDpl + CO --> DCOpl + Ar        0.389776
#   17 │ H2Dpl + CO --> DCOpl + H2        0.041759
#   18 │ COpl + HDO --> DCOpl + OH        0.0251372
#   19 │ Cpl + HDO --> DCOpl + H          0.00700875
#
# For DOCpl:
# 100% of reactions is 6/6
# The column rate of top 100.0% of reactions is 116.6801022743559
# Which equates to 100.0% of the total column rate (116.6801022743559).
#
# 6×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼───────────────────────────────────────
#    1 │ COpl + HD --> DOCpl + H    57.3194
#    2 │ DOCpl + E --> OD + C       54.5236
#    3 │ DOCpl + CO --> DCOpl + CO   4.73905
#    4 │ DOCpl + H2 --> H2Dpl + CO   0.0477414
#    5 │ DOCpl + H2 --> HCOpl + HD   0.0360155
#    6 │ Cpl + HDO --> DOCpl + H     0.0142392
#
# For Dpl:
# 100% of reactions is 17/17
# The column rate of top 100.0% of reactions is 2765.124614438978
# Which equates to 100.0% of the total column rate (2765.124614438978).
#
# 17×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼────────────────────────────────────────
#    1 │ CO2pl + D --> Dpl + CO2  961.782
#    2 │ Dpl + CO2 --> CO2pl + D  782.129
#    3 │ Dpl + CO2 --> DCOpl + O  581.01
#    4 │ Opl + D --> Dpl + O      207.532
#    5 │ D --> Dpl                148.075
#    6 │ HD --> Dpl + H            45.3492
#    7 │ Dpl + O --> D + Opl       11.699
#    8 │ COpl + D --> Dpl + CO      9.73291
#    9 │ N2pl + D --> Dpl + N2      9.47469
#   10 │ Dpl + H2 --> Hpl + HD      4.46848
#   11 │ Dpl + O2 --> O2pl + D      2.05822
#   12 │ Dpl + H --> D + Hpl        1.19811
#   13 │ Hpl + HD --> Dpl + H2      0.580254
#   14 │ HDO --> Dpl + OH           0.0319346
#   15 │ Dpl + NO --> NOpl + D      0.00298752
#   16 │ Dpl + H2O --> H2Opl + D    0.000218603
#   17 │ Dpl + H2O --> HDOpl + H    0.000121877
#
# For H2DOpl:
# 100% of reactions is 14/14
# The column rate of top 100.0% of reactions is 267.1541552960093
# Which equates to 100.0% of the total column rate (267.1541552960093).
#
# 14×2 DataFrame
#  Row │ Rxn                            Value
#      │ String                         Float64
# ─────┼────────────────────────────────────────────
#    1 │ HCOpl + HDO --> H2DOpl + CO    119.246
#    2 │ H2DOpl + E --> OD + H + H       39.719
#    3 │ H2DOpl + E --> OH + D + H       39.719
#    4 │ H2DOpl + E --> H2O + D          16.5274
#    5 │ H2DOpl + E --> HDO + H          16.5274
#    6 │ DCOpl + H2O --> H2DOpl + CO     12.463
#    7 │ H2DOpl + E --> OD + H2           9.2411
#    8 │ H2DOpl + E --> OH + HD           9.2411
#    9 │ HDOpl + H2 --> H2DOpl + H        1.22527
#   10 │ H2DOpl + E --> H2 + O + D        0.860133
#   11 │ H2DOpl + E --> HD + O + H        0.860133
#   12 │ HCO2pl + HDO --> H2DOpl + CO2    0.803133
#   13 │ H2Opl + HD --> H2DOpl + H        0.662357
#   14 │ DCO2pl + H2O --> H2DOpl + CO2    0.0588014
#
# For H2Dpl:
# 100% of reactions is 7/7
# The column rate of top 100.0% of reactions is 0.26432856873893157
# Which equates to 100.0% of the total column rate (0.26432856873893157).
#
# 7×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼───────────────────────────────────────
#    1 │ H2Dpl + CO --> HCOpl + HD  0.0847835
#    2 │ DOCpl + H2 --> H2Dpl + CO  0.0477414
#    3 │ ArDpl + H2 --> H2Dpl + Ar  0.0418559
#    4 │ H2Dpl + CO --> DCOpl + H2  0.041759
#    5 │ ArHpl + HD --> H2Dpl + Ar  0.0382802
#    6 │ H2Dpl + H2 --> H3pl + HD   0.00562174
#    7 │ HDpl + HD --> H2Dpl + D    0.0042868
#
# For HDOpl:
# 100% of reactions is 23/23
# The column rate of top 100.0% of reactions is 313.5074168662531
# Which equates to 100.0% of the total column rate (313.5074168662531).
#
# 23×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼────────────────────────────────────────────
#    1 │ CO2pl + HDO --> HDOpl + CO2  131.7
#    2 │ HDOpl + CO --> DCOpl + OH     37.1698
#    3 │ HDOpl + CO --> HCOpl + OD     37.1698
#    4 │ HDOpl + O2 --> O2pl + HDO     24.5543
#    5 │ HDOpl + E --> O + D + H       24.3932
#    6 │ HDOpl + O --> O2pl + HD       20.5053
#    7 │ OHpl + HD --> HDOpl + H       20.0046
#    8 │ ODpl + H2 --> HDOpl + H        4.5858
#    9 │ HDOpl + E --> OD + H           3.43616
#   10 │ HDOpl + E --> OH + D           3.43616
#   11 │ HDOpl + E --> HD + O           3.09606
#   12 │ HDOpl + H2 --> H2DOpl + H      1.22527
#   13 │ HDOpl + H2 --> H3Opl + D       1.22527
#   14 │ Opl + HDO --> HDOpl + O        0.52758
#   15 │ HDO --> HDOpl                  0.30218
#   16 │ COpl + HDO --> HDOpl + CO      0.0933668
#   17 │ N2pl + HDO --> HDOpl + N2      0.035161
#   18 │ HDOpl + NO --> NOpl + HDO      0.0217685
#   19 │ HDOpl + N --> HNOpl + D        0.00925532
#   20 │ HDOpl + N --> NOpl + HD        0.00925532
#   21 │ Cpl + HDO --> HDOpl + C        0.00632853
#   22 │ Hpl + HDO --> HDOpl + H        0.000702098
#   23 │ Dpl + H2O --> HDOpl + H        0.000121877
#
# For HDpl:
# 100% of reactions is 15/15
# The column rate of top 100.0% of reactions is 816.2822496987881
# Which equates to 100.0% of the total column rate (816.2822496987881).
#
# 15×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ HD --> HDpl                408.143
#    2 │ HDpl + CO2 --> DCO2pl + H  145.314
#    3 │ HDpl + CO2 --> HCO2pl + D  145.314
#    4 │ HDpl + O --> ODpl + H       25.759
#    5 │ HDpl + O --> OHpl + D       25.759
#    6 │ HDpl + N2 --> N2Dpl + H     14.2168
#    7 │ HDpl + N2 --> N2Hpl + D     14.2168
#    8 │ HDpl + CO --> DCOpl + H     10.9446
#    9 │ HDpl + CO --> HCOpl + D     10.9446
#   10 │ HDpl + Ar --> ArHpl + D      8.03077
#   11 │ HDpl + Ar --> ArDpl + H      6.57063
#   12 │ HDpl + O2 --> HO2pl + D      0.89338
#   13 │ HDpl + E --> H + D           0.170984
#   14 │ HDpl + HD --> H2Dpl + D      0.0042868
#   15 │ Arpl + HD --> HDpl + Ar      0.000121933
#
# For N2Dpl:
# 100% of reactions is 10/10
# The column rate of top 100.0% of reactions is 410.5327782657466
# Which equates to 100.00000000000001% of the total column rate (410.5327782657466).
#
# 10×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼─────────────────────────────────────────
#    1 │ N2pl + HD --> N2Dpl + H    172.373
#    2 │ N2Dpl + CO --> DCOpl + N2  128.83
#    3 │ N2Dpl + O --> ODpl + N2     71.9107
#    4 │ ODpl + N2 --> N2Dpl + O     18.1084
#    5 │ HDpl + N2 --> N2Dpl + H     14.2168
#    6 │ N2Dpl + E --> N2 + D         4.30468
#    7 │ ArDpl + N2 --> N2Dpl + Ar    0.352224
#    8 │ N2Hpl + D --> N2Dpl + H      0.249515
#    9 │ N2Dpl + H --> N2Hpl + D      0.183649
#   10 │ N2pl + HDO --> N2Dpl + OH    0.00466346
#
# For ODpl:
# 100% of reactions is 13/13
# The column rate of top 100.0% of reactions is 1968.712975983902
# Which equates to 100.0% of the total column rate (1968.712975983902).
#
# 13×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼────────────────────────────────────────
#    1 │ Opl + HD --> ODpl + H      886.639
#    2 │ ODpl + CO2 --> DCO2pl + O  779.744
#    3 │ ODpl + O --> O2pl + D      140.201
#    4 │ N2Dpl + O --> ODpl + N2     71.9107
#    5 │ ODpl + CO --> DCOpl + O     33.6709
#    6 │ HDpl + O --> ODpl + H       25.759
#    7 │ ODpl + N2 --> N2Dpl + O     18.1084
#    8 │ ODpl + H2 --> H2Opl + D      4.5858
#    9 │ ODpl + H2 --> HDOpl + H      4.5858
#   10 │ ODpl + O2 --> O2pl + OD      1.81575
#   11 │ ODpl + E --> O + D           1.46403
#   12 │ ODpl + N --> NOpl + D        0.17014
#   13 │ HDO --> ODpl + H             0.0586517

# %%
bigdf_Drxns_sorted_uniques = unique(sort(bigdf_Drxns, [:Value], rev=true))

back_to_H_version = unique(translate_D_and_H(bigdf_Drxns_sorted_uniques."Rxn"; D_to_H=true))
# Out:
# Deuteration options for D + O2 --> DO2
# H + O2 --> HO2
#
# Deuteration options for O + DO2 --> OD + O2
# O + HO2 --> OH + O2
#
# Deuteration options for CO + OD --> CO2 + D
# CO + OH --> CO2 + H
#
# Deuteration options for O + OD --> O2 + D
# O + OH --> O2 + H
#
# Deuteration options for D + O3 --> OD + O2
# H + O3 --> OH + O2
#
# Deuteration options for D + HO2 --> DO2 + H
# H + HO2 --> HO2 + H
#
# Deuteration options for OH + D --> OD + H
# OH + H --> OH + H
#
# Deuteration options for H + DO2 --> OH + OD
# H + HO2 --> OH + OH
#
# Deuteration options for D + HO2 --> OH + OD
# H + HO2 --> OH + OH
#
# Deuteration options for OH + DO2 --> HDO + O2
# OH + HO2 --> H2O + O2
#
# Deuteration options for OD + HO2 --> HDO + O2
# OH + HO2 --> H2O + O2
#
# Deuteration options for HDO --> D + OH
# H2O --> H + OH
#
# Deuteration options for HDO --> H + OD
# H2O --> H + OH
#
# Deuteration options for DO2 + HO2 --> HDO2 + O2
# HO2 + HO2 --> H2O2 + O2
#
# Deuteration options for HDO2 --> OH + OD
# H2O2 --> OH + OH
#
# Deuteration options for DO2 --> OD + O
# HO2 --> OH + O
#
# Deuteration options for O1D + HDO --> OD + OH
# O1D + H2O --> OH + OH
#
# Deuteration options for CO + OD --> DOCO
# CO + OH --> HOCO
#
# Deuteration options for DOCO + O2 --> DO2 + CO2
# HOCO + O2 --> HO2 + CO2
#
# Deuteration options for OH + HD --> HDO + H
# OH + H2 --> H2O + H
#
# Deuteration options for H + DO2 --> HD + O2
# H + HO2 --> H2 + O2
#
# Deuteration options for D + HO2 --> HD + O2
# H + HO2 --> H2 + O2
#
# Deuteration options for OD + H2 --> HDO + H
# OH + H2 --> H2O + H
#
# Deuteration options for H + DO2 --> HDO + O1D
# H + HO2 --> H2O + O1D
#
# Deuteration options for OD + H --> OH + D
# OH + H --> OH + H
#
# Deuteration options for OH + HD --> H2O + D
# OH + H2 --> H2O + H
#
# Deuteration options for D + HO2 --> HDO + O1D
# H + HO2 --> H2O + O1D
#
# Deuteration options for OD + H2O2 --> HDO + HO2
# OH + H2O2 --> H2O + HO2
#
# Deuteration options for H + DO2 --> HO2 + D
# H + HO2 --> HO2 + H
#
# Deuteration options for HDO2 --> HO2 + D
# H2O2 --> HO2 + H
#
# Deuteration options for HDO2 --> DO2 + H
# H2O2 --> HO2 + H
#
# Deuteration options for OH + HDO2 --> H2O + DO2
# OH + H2O2 --> H2O + HO2
#
# Deuteration options for OH + HDO2 --> HDO + HO2
# OH + H2O2 --> H2O + HO2
#
# Deuteration options for DO2 + O3 --> OD + O2 + O2
# HO2 + O3 --> OH + O2 + O2
#
# Deuteration options for HO2 + DO2 + M --> HDO2 + O2 + M
# HO2 + HO2 + M --> H2O2 + O2 + M
#
# Deuteration options for O1D + HD --> D + OH
# O1D + H2 --> H + OH
#
# Deuteration options for O1D + HD --> H + OD
# O1D + H2 --> H + OH
#
# Deuteration options for CO2pl + HD --> HCO2pl + D
# CO2pl + H2 --> HCO2pl + H
#
# Deuteration options for CO2pl + HD --> DCO2pl + H
# CO2pl + H2 --> HCO2pl + H
#
# Deuteration options for DCOpl + E --> CO + D
# HCOpl + E --> CO + H
#
# Deuteration options for OD + O3 --> DO2 + O2
# OH + O3 --> HO2 + O2
#
# Deuteration options for OD + OH --> HDO + O
# OH + OH --> H2O + O
#
# Deuteration options for CO + D --> DCO
# CO + H --> HCO
#
# Deuteration options for H + HD --> H2 + D
# H + H2 --> H2 + H
#
# Deuteration options for DCO + O2 --> DO2 + CO
# HCO + O2 --> HO2 + CO
#
# Deuteration options for O + D --> OD
# O + H --> OH
#
# Deuteration options for DCO2pl + O --> DCOpl + O2
# HCO2pl + O --> HCOpl + O2
#
# Deuteration options for DCO2pl + CO --> DCOpl + CO2
# HCO2pl + CO --> HCOpl + CO2
#
# Deuteration options for CO2pl + D --> DCOpl + O
# CO2pl + H --> HCOpl + O
#
# Deuteration options for HD + O --> OH + D
# H2 + O --> OH + H
#
# Deuteration options for DCO2pl + E --> CO + O + D
# HCO2pl + E --> CO + O + H
#
# Deuteration options for H + D + M --> HD + M
# H + H + M --> H2 + M
#
# Deuteration options for D + H2 --> HD + H
# H + H2 --> H2 + H
#
# Deuteration options for H + OD + CO2 --> HDO + CO2
# H + OH + CO2 --> H2O + CO2
#
# Deuteration options for O + HDO2 --> OH + DO2
# O + H2O2 --> OH + HO2
#
# Deuteration options for O + HDO2 --> OD + HO2
# O + H2O2 --> OH + HO2
#
# Deuteration options for DCOpl + E --> OD + C
# HCOpl + E --> OH + C
#
# Deuteration options for DCO + O2 --> CO2 + OD
# HCO + O2 --> CO2 + OH
#
# Deuteration options for D + OH + CO2 --> HDO + CO2
# H + OH + CO2 --> H2O + CO2
#
# Deuteration options for Opl + HD --> OHpl + D
# Opl + H2 --> OHpl + H
#
# Deuteration options for HD + O --> OD + H
# H2 + O --> OH + H
#
# Deuteration options for CO2pl + D --> Dpl + CO2
# CO2pl + H --> Hpl + CO2
#
# Deuteration options for DCO2pl + E --> CO + OD
# HCO2pl + E --> CO + OH
#
# Deuteration options for Opl + HD --> ODpl + H
# Opl + H2 --> OHpl + H
#
# Deuteration options for Dpl + CO2 --> CO2pl + D
# Hpl + CO2 --> CO2pl + H
#
# Deuteration options for ODpl + CO2 --> DCO2pl + O
# OHpl + CO2 --> HCO2pl + O
#
# Deuteration options for Dpl + CO2 --> DCOpl + O
# Hpl + CO2 --> HCOpl + O
#
# Deuteration options for OD --> O + D
# OH --> O + H
#
# Deuteration options for HCOpl + D --> DCOpl + H
# HCOpl + H --> HCOpl + H
#
# Deuteration options for HD --> HDpl
# H2 --> H2pl
#
# Deuteration options for HD --> H + D
# H2 --> H + H
#
# Deuteration options for DCO + O --> CO2 + D
# HCO + O --> CO2 + H
#
# Deuteration options for DCO + O --> CO + OD
# HCO + O --> CO + OH
#
# Deuteration options for Opl + D --> Dpl + O
# Opl + H --> Hpl + O
#
# Deuteration options for DCO2pl + E --> CO2 + D
# HCO2pl + E --> CO2 + H
#
# Deuteration options for N2pl + HD --> N2Dpl + H
# N2pl + H2 --> N2Hpl + H
#
# Deuteration options for N2pl + HD --> N2Hpl + D
# N2pl + H2 --> N2Hpl + H
#
# Deuteration options for D --> Dpl
# H --> Hpl
#
# Deuteration options for HDpl + CO2 --> HCO2pl + D
# H2pl + CO2 --> HCO2pl + H
#
# Deuteration options for HDpl + CO2 --> DCO2pl + H
# H2pl + CO2 --> HCO2pl + H
#
# Deuteration options for ODpl + O --> O2pl + D
# OHpl + O --> O2pl + H
#
# Deuteration options for CO2pl + HDO --> HDOpl + CO2
# CO2pl + H2O --> H2Opl + CO2
#
# Deuteration options for N2Dpl + CO --> DCOpl + N2
# N2Hpl + CO --> HCOpl + N2
#
# Deuteration options for HCOpl + HDO --> H2DOpl + CO
# HCOpl + H2O --> H3Opl + CO
#
# Deuteration options for OD + OH --> HDO2
# OH + OH --> H2O2
#
# Deuteration options for N2Dpl + O --> ODpl + N2
# N2Hpl + O --> OHpl + N2
#
# Deuteration options for DO2 + N --> NO + OD
# HO2 + N --> NO + OH
#
# Deuteration options for COpl + HD --> HCOpl + D
# COpl + H2 --> HCOpl + H
#
# Deuteration options for COpl + HD --> HOCpl + D
# COpl + H2 --> HOCpl + H
#
# Deuteration options for COpl + HD --> DCOpl + H
# COpl + H2 --> HCOpl + H
#
# Deuteration options for COpl + HD --> DOCpl + H
# COpl + H2 --> HOCpl + H
#
# Deuteration options for DOCpl + E --> OD + C
# HOCpl + E --> OH + C
#
# Deuteration options for HDO --> HD + O1D
# H2O --> H2 + O1D
#
# Deuteration options for HD --> Hpl + D
# H2 --> Hpl + H
#
# Deuteration options for HD --> Dpl + H
# H2 --> Hpl + H
#
# Deuteration options for H2DOpl + E --> OH + D + H
# H3Opl + E --> OH + H + H
#
# Deuteration options for H2DOpl + E --> OD + H + H
# H3Opl + E --> OH + H + H
#
# Deuteration options for D + H2O2 --> H2O + OD
# H + H2O2 --> H2O + OH
#
# Deuteration options for D + H2O2 --> HDO + OH
# H + H2O2 --> H2O + OH
#
# Deuteration options for HDOpl + CO --> HCOpl + OD
# H2Opl + CO --> HCOpl + OH
#
# Deuteration options for HDOpl + CO --> DCOpl + OH
# H2Opl + CO --> HCOpl + OH
#
# Deuteration options for DCOpl + H --> HCOpl + D
# HCOpl + H --> HCOpl + H
#
# Deuteration options for ODpl + CO --> DCOpl + O
# OHpl + CO --> HCOpl + O
#
# Deuteration options for H + HDO2 --> HDO + OH
# H + H2O2 --> H2O + OH
#
# Deuteration options for H + HDO2 --> H2O + OD
# H + H2O2 --> H2O + OH
#
# Deuteration options for HDpl + O --> OHpl + D
# H2pl + O --> OHpl + H
#
# Deuteration options for HDpl + O --> ODpl + H
# H2pl + O --> OHpl + H
#
# Deuteration options for HDOpl + O2 --> O2pl + HDO
# H2Opl + O2 --> O2pl + H2O
#
# Deuteration options for HDOpl + E --> O + D + H
# H2Opl + E --> O + H + H
#
# Deuteration options for HDOpl + O --> O2pl + HD
# H2Opl + O --> O2pl + H2
#
# Deuteration options for OHpl + HD --> H2Opl + D
# OHpl + H2 --> H2Opl + H
#
# Deuteration options for OHpl + HD --> HDOpl + H
# OHpl + H2 --> H2Opl + H
#
# Deuteration options for ODpl + N2 --> N2Dpl + O
# OHpl + N2 --> N2Hpl + O
#
# Deuteration options for H2DOpl + E --> H2O + D
# H3Opl + E --> H2O + H
#
# Deuteration options for H2DOpl + E --> HDO + H
# H3Opl + E --> H2O + H
#
# Deuteration options for HDpl + N2 --> N2Hpl + D
# H2pl + N2 --> N2Hpl + H
#
# Deuteration options for HDpl + N2 --> N2Dpl + H
# H2pl + N2 --> N2Hpl + H
#
# Deuteration options for DCOpl + H2O --> H2DOpl + CO
# HCOpl + H2O --> H3Opl + CO
#
# Deuteration options for Dpl + O --> D + Opl
# Hpl + O --> H + Opl
#
# Deuteration options for CO2pl + HDO --> DCO2pl + OH
# CO2pl + H2O --> HCO2pl + OH
#
# Deuteration options for CO2pl + HDO --> HCO2pl + OD
# CO2pl + H2O --> HCO2pl + OH
#
# Deuteration options for HDpl + CO --> HCOpl + D
# H2pl + CO --> HCOpl + H
#
# Deuteration options for HDpl + CO --> DCOpl + H
# H2pl + CO --> HCOpl + H
#
# Deuteration options for COpl + D --> Dpl + CO
# COpl + H --> Hpl + CO
#
# Deuteration options for N2pl + D --> Dpl + N2
# N2pl + H --> Hpl + N2
#
# Deuteration options for H2DOpl + E --> OH + HD
# H3Opl + E --> OH + H2
#
# Deuteration options for H2DOpl + E --> OD + H2
# H3Opl + E --> OH + H2
#
# Deuteration options for HDpl + Ar --> ArHpl + D
# H2pl + Ar --> ArHpl + H
#
# Deuteration options for DCO + H --> CO + HD
# HCO + H --> CO + H2
#
# Deuteration options for HDpl + Ar --> ArDpl + H
# H2pl + Ar --> ArHpl + H
#
# Deuteration options for ArDpl + CO2 --> DCO2pl + Ar
# ArHpl + CO2 --> HCO2pl + Ar
#
# Deuteration options for HCO + D --> CO + HD
# HCO + H --> CO + H2
#
# Deuteration options for DOCpl + CO --> DCOpl + CO
# HOCpl + CO --> HCOpl + CO
#
# Deuteration options for ODpl + H2 --> H2Opl + D
# OHpl + H2 --> H2Opl + H
#
# Deuteration options for ODpl + H2 --> HDOpl + H
# OHpl + H2 --> H2Opl + H
#
# Deuteration options for Dpl + H2 --> Hpl + HD
# Hpl + H2 --> Hpl + H2
#
# Deuteration options for N2Dpl + E --> N2 + D
# N2Hpl + E --> N2 + H
#
# Deuteration options for HDOpl + E --> OH + D
# H2Opl + E --> OH + H
#
# Deuteration options for HDOpl + E --> OD + H
# H2Opl + E --> OH + H
#
# Deuteration options for HDOpl + E --> HD + O
# H2Opl + E --> H2 + O
#
# Deuteration options for Npl + HD --> NHpl + D
# Npl + H2 --> NHpl + H
#
# Deuteration options for Dpl + O2 --> O2pl + D
# Hpl + O2 --> O2pl + H
#
# Deuteration options for ODpl + O2 --> O2pl + OD
# OHpl + O2 --> O2pl + OH
#
# Deuteration options for ODpl + E --> O + D
# OHpl + E --> O + H
#
# Deuteration options for HDOpl + H2 --> H3Opl + D
# H2Opl + H2 --> H3Opl + H
#
# Deuteration options for HDOpl + H2 --> H2DOpl + H
# H2Opl + H2 --> H3Opl + H
#
# Deuteration options for Dpl + H --> D + Hpl
# Hpl + H --> H + Hpl
#
# Deuteration options for HDpl + O2 --> HO2pl + D
# H2pl + O2 --> HO2pl + H
#
# Deuteration options for H2DOpl + E --> H2 + O + D
# H3Opl + E --> H2 + O + H
#
# Deuteration options for H2DOpl + E --> HD + O + H
# H3Opl + E --> H2 + O + H
#
# Deuteration options for HCO2pl + HDO --> H2DOpl + CO2
# HCO2pl + H2O --> H3Opl + CO2
#
# Deuteration options for H2Opl + HD --> H3Opl + D
# H2Opl + H2 --> H3Opl + H
#
# Deuteration options for H2Opl + HD --> H2DOpl + H
# H2Opl + H2 --> H3Opl + H
#
# Deuteration options for Hpl + HD --> Dpl + H2
# Hpl + H2 --> Hpl + H2
#
# Deuteration options for Opl + HDO --> HDOpl + O
# Opl + H2O --> H2Opl + O
#
# Deuteration options for ArDpl + CO --> DCOpl + Ar
# ArHpl + CO --> HCOpl + Ar
#
# Deuteration options for ArDpl + N2 --> N2Dpl + Ar
# ArHpl + N2 --> N2Hpl + Ar
#
# Deuteration options for HDO --> HDOpl
# H2O --> H2Opl
#
# Deuteration options for N2Hpl + D --> N2Dpl + H
# N2Hpl + H --> N2Hpl + H
#
# Deuteration options for N2Dpl + H --> N2Hpl + D
# N2Hpl + H --> N2Hpl + H
#
# Deuteration options for HOCO + OD --> CO2 + HDO
# HOCO + OH --> CO2 + H2O
#
# Deuteration options for HDpl + E --> H + D
# H2pl + E --> H + H
#
# Deuteration options for ODpl + N --> NOpl + D
# OHpl + N --> NOpl + H
#
# Deuteration options for DOCO + OH --> CO2 + HDO
# HOCO + OH --> CO2 + H2O
#
# Deuteration options for COpl + HDO --> HDOpl + CO
# COpl + H2O --> H2Opl + CO
#
# Deuteration options for H2Dpl + CO --> HCOpl + HD
# H3pl + CO --> HCOpl + H2
#
# Deuteration options for DCO2pl + H2O --> H2DOpl + CO2
# HCO2pl + H2O --> H3Opl + CO2
#
# Deuteration options for HDO --> OHpl + D
# H2O --> OHpl + H
#
# Deuteration options for HDO --> ODpl + H
# H2O --> OHpl + H
#
# Deuteration options for DOCpl + H2 --> H2Dpl + CO
# HOCpl + H2 --> H3pl + CO
#
# Deuteration options for ArDpl + H2 --> H2Dpl + Ar
# ArHpl + H2 --> H3pl + Ar
#
# Deuteration options for H2Dpl + CO --> DCOpl + H2
# H3pl + CO --> HCOpl + H2
#
# Deuteration options for ArHpl + HD --> H2Dpl + Ar
# ArHpl + H2 --> H3pl + Ar
#
# Deuteration options for DOCpl + H2 --> HCOpl + HD
# HOCpl + H2 --> HCOpl + H2
#
# Deuteration options for N2pl + HDO --> HDOpl + N2
# N2pl + H2O --> H2Opl + N2
#
# Deuteration options for OD --> O1D + D
# OH --> O1D + H
#
# Deuteration options for HDO --> Dpl + OH
# H2O --> Hpl + OH
#
# Deuteration options for HDO --> Hpl + OD
# H2O --> Hpl + OH
#
# Deuteration options for DCO + OH --> HDO + CO
# HCO + OH --> H2O + CO
#
# Deuteration options for HCO + OD --> HDO + CO
# HCO + OH --> H2O + CO
#
# Deuteration options for COpl + HDO --> DCOpl + OH
# COpl + H2O --> HCOpl + OH
#
# Deuteration options for COpl + HDO --> HCOpl + OD
# COpl + H2O --> HCOpl + OH
#
# Deuteration options for HDOpl + NO --> NOpl + HDO
# H2Opl + NO --> NOpl + H2O
#
# Deuteration options for ArDpl + H2 --> ArHpl + HD
# ArHpl + H2 --> ArHpl + H2
#
# Deuteration options for Cpl + HDO --> HOCpl + D
# Cpl + H2O --> HOCpl + H
#
# Deuteration options for Cpl + HDO --> DOCpl + H
# Cpl + H2O --> HOCpl + H
#
# Deuteration options for HDOpl + N --> HNOpl + D
# H2Opl + N --> HNOpl + H
#
# Deuteration options for HDOpl + N --> NOpl + HD
# H2Opl + N --> NOpl + H2
#
# Deuteration options for Cpl + HDO --> HCOpl + D
# Cpl + H2O --> HCOpl + H
#
# Deuteration options for Cpl + HDO --> DCOpl + H
# Cpl + H2O --> HCOpl + H
#
# Deuteration options for Cpl + HDO --> HDOpl + C
# Cpl + H2O --> H2Opl + C
#
# Deuteration options for H2Dpl + H2 --> H3pl + HD
# H3pl + H2 --> H3pl + H2
#
# Deuteration options for HDO --> Opl + HD
# H2O --> Opl + H2
#
# Deuteration options for N2pl + HDO --> N2Dpl + OH
# N2pl + H2O --> N2Hpl + OH
#
# Deuteration options for N2pl + HDO --> N2Hpl + OD
# N2pl + H2O --> N2Hpl + OH
#
# Deuteration options for HDpl + HD --> H2Dpl + D
#
# Deuteration options for Dpl + NO --> NOpl + D
# Hpl + NO --> NOpl + H
#
# Deuteration options for Arpl + HD --> ArDpl + H
# Arpl + H2 --> ArHpl + H
#
# Deuteration options for Arpl + HD --> ArHpl + D
# Arpl + H2 --> ArHpl + H
#
# Deuteration options for Hpl + HDO --> H2Opl + D
# Hpl + H2O --> H2Opl + H
#
# Deuteration options for Hpl + HDO --> HDOpl + H
# Hpl + H2O --> H2Opl + H
#
# Deuteration options for Dpl + H2O --> H2Opl + D
# Hpl + H2O --> H2Opl + H
#
# Deuteration options for Arpl + HD --> HDpl + Ar
# Arpl + H2 --> H2pl + Ar
#
# Deuteration options for Dpl + H2O --> HDOpl + H
# Hpl + H2O --> H2Opl + H
#
# Deuteration options for Cpl + HD --> CHpl + D
# Cpl + H2 --> CHpl + H
#
# Deuteration options for HDO --> H + D + O
# H2O --> H + H + O
#
# Deuteration options for HDO2 --> HDO + O1D
# H2O2 --> H2O + O1D
# 142-element Vector{Any}:
#  [[:H, :O2], [:HO2]]
#  [[:O, :HO2], [:OH, :O2]]
#  [[:CO, :OH], [:CO2, :H]]
#  [[:O, :OH], [:O2, :H]]
#  [[:H, :O3], [:OH, :O2]]
#  [[:H, :HO2], [:HO2, :H]]
#  [[:OH, :H], [:OH, :H]]
#  [[:H, :HO2], [:OH, :OH]]
#  [[:OH, :HO2], [:H2O, :O2]]
#  [[:H2O], [:H, :OH]]
#  [[:HO2, :HO2], [:H2O2, :O2]]
#  [[:H2O2], [:OH, :OH]]
#  [[:HO2], [:OH, :O]]
#  ⋮
#  [[:Cpl, :H2O], [:HCOpl, :H]]
#  [[:Cpl, :H2O], [:H2Opl, :C]]
#  [[:H3pl, :H2], [:H3pl, :H2]]
#  [[:H2O], [:Opl, :H2]]
#  [[:N2pl, :H2O], [:N2Hpl, :OH]]
#  [[:Hpl, :NO], [:NOpl, :H]]
#  [[:Arpl, :H2], [:ArHpl, :H]]
#  [[:Hpl, :H2O], [:H2Opl, :H]]
#  [[:Arpl, :H2], [:H2pl, :Ar]]
#  [[:Cpl, :H2], [:CHpl, :H]]
#  [[:H2O], [:H, :H, :O]]
#  [[:H2O2], [:H2O, :O1D]]

# %%
# Retrieve the list of reactions from the network with the rates

reconstructed_H_network = reactions_present(back_to_H_version; return_found=true, reaction_network)
# Out:
# Missing 10 reactions
# These are the ones I couldn't find, suspiciously
# Any[[[:H, :HO2], [:HO2, :H]], [[:OH, :H], [:OH, :H]], [[:H, :H2], [:H2, :H]], [[:Hpl, :CO2], [:CO2pl, :H]], [[:HCOpl, :H], [:HCOpl, :H]], [[:N2pl, :H], [:Hpl, :N2]], [[:Hpl, :H2], [:Hpl, :H2]], [[:N2Hpl, :H], [:N2Hpl, :H]], [[:ArHpl, :H2], [:ArHpl, :H2]], [[:H3pl, :H2], [:H3pl, :H2]]]
# 134-element Vector{Any}:
#  Any[[:H, :O2], [:HO2], :((((1.4613e-28 .* Tn .^ -1.3) .* M) ./ (1 .+ ((1.4613e-28 .* Tn .^ -1.3) .* M) ./ (2.39683e-11 .* Tn .^ 0.2))) .* 0.6 .^ ((1 .+ log10.(((1.4613e-28 .* Tn .^ -1.3) .* M) ./ (2.39683e-11 .* Tn .^ 0.2)) .^ 2) .^ -1.0))]
#  Any[[:HO2, :O], [:O2, :OH], :(3.0e-11 .* exp.(200 ./ Tn))]
#  Any[[:CO, :OH], [:CO2, :H], :(((4.89574181180489e-15 .* Tn .^ 0.6) ./ (1 .+ (4.89574181180489e-15 .* Tn .^ 0.6) ./ ((1.62846954489706e-6 .* Tn .^ 6.1) ./ M))) .* 0.6 .^ ((1 .+ log10.((4.89574181180489e-15 .* Tn .^ 0.6) ./ ((1.62846954489706e-6 .* Tn .^ 6.1) .* M)) .^ 2) .^ -1.0))]
#  Any[[:OH, :O], [:O2, :H], :(1.8e-11 .* exp.(180 ./ Tn))]
#  Any[[:O3, :H], [:O2, :OH], :(1.4e-10 .* exp.(-470 ./ Tn))]
#  Any[[:HO2, :H], [:OH, :OH], 7.2e-11]
#  Any[[:HO2, :OH], [:H2O, :O2], :(4.8e-11 .* exp.(250 ./ Tn))]
#  Any[[:H2O], [:H, :OH], :JH2OtoHpOH]
#  Any[[:HO2, :HO2], [:H2O2, :O2], :(3.0e-13 .* exp.(460 ./ Tn))]
#  Any[[:H2O2], [:OH, :OH], :JH2O2toOHpOH]
#  Any[[:HO2], [:OH, :O], :JHO2toOHpO]
#  Any[[:O1D, :H2O], [:OH, :OH], :(1.63e-10 .* exp.(60 ./ Tn))]
#  Any[[:CO, :OH], [:HOCO], :((((1.73309260137893e-29 .* Tn .^ -1.4) .* M) ./ (1 .+ ((1.73309260137893e-29 .* Tn .^ -1.4) .* M) ./ (6.62422467428728e-16 .* Tn .^ 1.3))) .* 0.6 .^ ((1 .+ log10.(((1.73309260137893e-29 .* Tn .^ -1.4) .* M) ./ (6.62422467428728e-16 .* Tn .^ 1.3)) .^ 2) .^ -1.0))]
#  ⋮
#  Any[[:H2Opl, :N], [:NOpl, :H2], 2.8e-11]
#  Any[[:Cpl, :H2O], [:HCOpl, :H], :(1.56e-8 .* Ti .^ -0.5)]
#  Any[[:Cpl, :H2O], [:H2Opl, :C], 2.4e-10]
#  Any[[:H2O], [:Opl, :H2], :JH2OtoOplpH2]
#  Any[[:N2pl, :H2O], [:N2Hpl, :OH], 5.04e-10]
#  Any[[:Hpl, :NO], [:NOpl, :H], 1.9e-9]
#  Any[[:Arpl, :H2], [:ArHpl, :H], 8.72e-10]
#  Any[[:Hpl, :H2O], [:H2Opl, :H], 8.2e-9]
#  Any[[:Arpl, :H2], [:H2pl, :Ar], 1.78e-11]
#  Any[[:Cpl, :H2], [:CHpl, :H], :(7.4e-10 .* exp.(-4537 ./ Ti))]
#  Any[[:H2O], [:H, :H, :O], :JH2OtoHpHpO]
#  Any[[:H2O2], [:H2O, :O1D], :JH2O2toH2OpO1D]

# %% [markdown]
# I've decided I don't care about those 10 reactions. I'll just calculate the percent of the total rate for the found ones and call it a day

# %% [markdown]
# ## Send the reconstructed H diagram back into the column rates calculator...

# %%
species_with_ONLY_H = setdiff(H_bearing_species, D_bearing_species)
# Out:
# 23-element Vector{Symbol}:
#  :ArHpl
#  :CHpl
#  :H
#  :H2
#  :H2O
#  :H2O2
#  :H2Opl
#  :H2pl
#  :H3Opl
#  :H3pl
#  :HCO
#  :HCO2pl
#  :HCOpl
#  :HNOpl
#  :HO2
#  :HO2pl
#  :HOCO
#  :HOCpl
#  :Hpl
#  :N2Hpl
#  :NHpl
#  :OH
#  :OHpl

# %%
bigdf_H_reconstructed = DataFrame(Rxn=[], Value=[])

# Retrieve 100% of reactions for all species
for Hsp in species_with_ONLY_H
    # Get the basic df
    println("For $(Hsp): ")
    col_rate_df = get_column_rates_NEW(Hsp, ncur; which="all", Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reconstructed_H_network, # !!!!!!!!!!! the change
                                   num_layers, dz)
    
    thisdf = get_p_pct_of_column(col_rate_df, 1; Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reconstructed_H_network, # !!!!!!!!!!! the change
                                   num_layers, dz)
    bigdf_H_reconstructed = vcat(bigdf_H_reconstructed, thisdf)
    println()
end

bigdf_H_reconstructed = unique(sort(bigdf_H_reconstructed, [:Value], rev=true))
# Out:
# For ArHpl:
# 100% of reactions is 6/6
# The column rate of top 100.0% of reactions is 9468.91689737013
# Which equates to 100.0% of the total column rate (9468.91689737013).
#
# 6×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼─────────────────────────────────────────
#    1 │ H2pl + Ar --> ArHpl + H      4987.98
#    2 │ ArHpl + CO2 --> HCO2pl + Ar  3882.06
#    3 │ ArHpl + N2 --> N2Hpl + Ar     314.979
#    4 │ ArHpl + CO --> HCOpl + Ar     261.359
#    5 │ ArHpl + H2 --> H3pl + Ar       20.952
#    6 │ Arpl + H2 --> ArHpl + H         1.58559
#
# For CHpl:
# 100% of reactions is 1/1
# The column rate of top 100.0% of reactions is 4.352715331858977
# Which equates to 100.0% of the total column rate (4.352715331858977).
#
# 1×2 DataFrame
#  Row │ Rxn                    Value
#      │ String                 Float64
# ─────┼────────────────────────────────
#    1 │ Cpl + H2 --> CHpl + H  4.35272
#
# For H:
# 100% of reactions is 68/68
# The column rate of top 100.0% of reactions is 3.2003297182631123e12
# Which equates to 100.0% of the total column rate (3.2003297182631123e12).
#
# 68×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼────────────────────────────────────────────
#    1 │ H + O2 --> HO2                  1.4822e12
#    2 │ CO + OH --> CO2 + H             1.344e12
#    3 │ OH + O --> O2 + H               2.05675e11
#    4 │ O3 + H --> O2 + OH              8.61523e10
#    5 │ HO2 + H --> OH + OH             4.35459e10
#    6 │ H2O --> H + OH                  3.24901e10
#    7 │ HO2 + H --> O2 + H2             2.08658e9
#    8 │ OH + H2 --> H2O + H             1.61533e9
#    9 │ H2O2 --> HO2 + H                1.07813e9
#   10 │ HO2 + H --> H2O + O1D           9.67687e8
#   11 │ HCOpl + E --> CO + H            1.42594e8
#   12 │ O1D + H2 --> OH + H             1.32058e8
#   13 │ CO2pl + H2 --> HCO2pl + H       1.27302e8
#   14 │ CO + H --> HCO                  2.61704e7
#   15 │ CO2pl + H --> HCOpl + O         2.19129e7
#   16 │ O + H --> OH                    1.91269e7
#   17 │ H2 + O --> OH + H               1.87528e7
#   18 │ HCO2pl + E --> CO + O + H       5.32587e6
#   19 │ H + H + M --> H2 + M            4.65615e6
#   20 │ OH + H + CO2 --> H2O + CO2      3.69939e6
#   21 │ CO2pl + H --> Hpl + CO2         2.69285e6
#   22 │ Opl + H2 --> OHpl + H           1.75584e6
#   23 │ H + H2O2 --> H2O + OH           1.42154e6
#   24 │ H2O2 + H --> H2O + OH           1.42154e6
#   25 │ OH --> O + H                    1.39357e6
#   26 │ HCO2pl + E --> CO2 + H          3.91608e5
#   27 │ HCO + O --> CO2 + H             3.41079e5
#   28 │ Opl + H --> Hpl + O             2.97234e5
#   29 │ N2pl + H2 --> N2Hpl + H         2.96692e5
#   30 │ OHpl + O --> O2pl + H           2.76386e5
#   31 │ H2pl + CO2 --> HCO2pl + H       1.9573e5
#   32 │ COpl + H2 --> HCOpl + H         1.94077e5
#   33 │ COpl + H2 --> HOCpl + H         1.94077e5
#   34 │ H2 --> H + H                    1.8797e5
#   35 │ H --> Hpl                       1.49971e5
#   36 │ COpl + H --> Hpl + CO       43545.9
#   37 │ H2pl + O --> OHpl + H       40705.8
#   38 │ H3Opl + E --> OH + H + H    37518.2
#   39 │ Hpl + O --> Opl + H         36879.9
#   40 │ H2 --> Hpl + H              31867.5
#   41 │ H2pl + N2 --> N2Hpl + H     20752.5
#   42 │ OHpl + H2 --> H2Opl + H     18653.6
#   43 │ H2pl + CO --> HCOpl + H     15991.5
#   44 │ H3Opl + E --> H2O + H       15611.6
#   45 │ HCO + H --> CO + H2         14080.3
#   46 │ Npl + H2 --> NHpl + H        8746.9
#   47 │ H2Opl + E --> O + H + H      7021.99
#   48 │ H2pl + Ar --> ArHpl + H      4987.98
#   49 │ Hpl + O2 --> O2pl + H        4762.93
#   50 │ N2Hpl + E --> N2 + H         4470.32
#   51 │ OHpl + E --> O + H           2843.25
#   52 │ Hpl + H --> H + Hpl          2641.17
#   53 │ H2Opl + H2 --> H3Opl + H     2378.58
#   54 │ H2Opl + E --> OH + H         1978.31
#   55 │ H2pl + O2 --> HO2pl + H      1273.19
#   56 │ H3Opl + E --> H2 + O + H      812.475
#   57 │ OHpl + N --> NOpl + H         337.164
#   58 │ H2pl + E --> H + H             92.4611
#   59 │ OH --> O1D + H                 52.9651
#   60 │ H2O --> OHpl + H               31.6029
#   61 │ Cpl + H2O --> HOCpl + H        30.8976
#   62 │ Cpl + H2O --> HCOpl + H        15.0817
#   63 │ H2Opl + N --> HNOpl + H        11.8444
#   64 │ Hpl + NO --> NOpl + H           9.26618
#   65 │ Cpl + H2 --> CHpl + H           4.35272
#   66 │ Arpl + H2 --> ArHpl + H         1.58559
#   67 │ Hpl + H2O --> H2Opl + H         0.848848
#   68 │ H2O --> H + H + O               0.0
#
# For H2:
# 100% of reactions is 31/31
# The column rate of top 100.0% of reactions is 3.9877563797734885e9
# Which equates to 100.0% of the total column rate (3.9877563797734885e9).
#
# 31×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ HO2 + H --> O2 + H2            2.08658e9
#    2 │ OH + H2 --> H2O + H            1.61533e9
#    3 │ O1D + H2 --> OH + H            1.32058e8
#    4 │ CO2pl + H2 --> HCO2pl + H      1.27302e8
#    5 │ H2 + O --> OH + H              1.87528e7
#    6 │ H + H + M --> H2 + M           4.65615e6
#    7 │ Opl + H2 --> OHpl + H          1.75584e6
#    8 │ N2pl + H2 --> N2Hpl + H        2.96692e5
#    9 │ H2 --> H2pl                    2.86808e5
#   10 │ COpl + H2 --> HCOpl + H        1.94077e5
#   11 │ COpl + H2 --> HOCpl + H        1.94077e5
#   12 │ H2 --> H + H                   1.8797e5
#   13 │ H2O --> H2 + O1D           77580.8
#   14 │ H2 --> Hpl + H             31867.5
#   15 │ OHpl + H2 --> H2Opl + H    18653.6
#   16 │ HCO + H --> CO + H2        14080.3
#   17 │ Npl + H2 --> NHpl + H       8746.9
#   18 │ H3Opl + E --> OH + H2       8729.07
#   19 │ H2Opl + O --> O2pl + H2     5514.01
#   20 │ H2Opl + H2 --> H3Opl + H    2378.58
#   21 │ H2Opl + E --> H2 + O         891.252
#   22 │ H3Opl + E --> H2 + O + H     812.475
#   23 │ H3pl + CO --> HCOpl + H2     117.363
#   24 │ HOCpl + H2 --> HCOpl + H2    105.09
#   25 │ HOCpl + H2 --> H3pl + CO      74.116
#   26 │ ArHpl + H2 --> H3pl + Ar      20.952
#   27 │ Cpl + H2 --> CHpl + H          4.35272
#   28 │ H2Opl + N --> NOpl + H2        2.96111
#   29 │ H2O --> Opl + H2               2.69162
#   30 │ Arpl + H2 --> ArHpl + H        1.58559
#   31 │ Arpl + H2 --> H2pl + Ar        0.0323665
#
# For H2O:
# 100% of reactions is 35/35
# The column rate of top 100.0% of reactions is 6.848364261242726e10
# Which equates to 100.0% of the total column rate (6.848364261242726e10).
#
# 35×2 DataFrame
#  Row │ Rxn                           Value
#      │ String                        Float64
# ─────┼──────────────────────────────────────────────
#    1 │ H2O --> H + OH                    3.24901e10
#    2 │ HO2 + OH --> H2O + O2             3.06452e10
#    3 │ O1D + H2O --> OH + OH             1.62693e9
#    4 │ OH + H2 --> H2O + H               1.61533e9
#    5 │ OH + H2O2 --> H2O + HO2           1.09603e9
#    6 │ HO2 + H --> H2O + O1D             9.67687e8
#    7 │ OH + OH --> H2O + O               3.56231e7
#    8 │ OH + H + CO2 --> H2O + CO2        3.69939e6
#    9 │ H + H2O2 --> H2O + OH             1.42154e6
#   10 │ H2O2 + H --> H2O + OH             1.42154e6
#   11 │ H2O --> H2 + O1D              77580.8
#   12 │ HCOpl + H2O --> H3Opl + CO    60708.7
#   13 │ CO2pl + H2O --> H2Opl + CO2   31542.2
#   14 │ CO2pl + H2O --> HCO2pl + OH   23211.5
#   15 │ H3Opl + E --> H2O + H         15611.6
#   16 │ H2Opl + O2 --> O2pl + H2O      4391.36
#   17 │ HOCO + OH --> CO2 + H2O         553.155
#   18 │ HCO2pl + H2O --> H3Opl + CO2    433.383
#   19 │ Opl + H2O --> H2Opl + O         290.967
#   20 │ H2O --> H2Opl                   162.661
#   21 │ HCO + OH --> H2O + CO           132.454
#   22 │ COpl + H2O --> H2Opl + CO        51.0511
#   23 │ H2O --> OHpl + H                 31.6029
#   24 │ Cpl + H2O --> HOCpl + H          30.8976
#   25 │ COpl + H2O --> HCOpl + OH        27.489
#   26 │ N2pl + H2O --> H2Opl + N2        20.1849
#   27 │ H2O --> Hpl + OH                 17.0067
#   28 │ Cpl + H2O --> HCOpl + H          15.0817
#   29 │ N2pl + H2O --> N2Hpl + OH         5.35431
#   30 │ H2Opl + NO --> NOpl + H2O         4.5727
#   31 │ Cpl + H2O --> H2Opl + C           3.43306
#   32 │ H2O --> Opl + H2                  2.69162
#   33 │ Hpl + H2O --> H2Opl + H           0.848848
#   34 │ H2O --> H + H + O                 0.0
#   35 │ H2O2 --> H2O + O1D                0.0
#
# For H2O2:
# 100% of reactions is 11/11
# The column rate of top 100.0% of reactions is 4.531115114569117e10
# Which equates to 100.0% of the total column rate (4.531115114569117e10).
#
# 11×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼─────────────────────────────────────────────
#    1 │ HO2 + HO2 --> H2O2 + O2          2.27018e10
#    2 │ H2O2 --> OH + OH                 2.01288e10
#    3 │ OH + H2O2 --> H2O + HO2          1.09603e9
#    4 │ H2O2 --> HO2 + H                 1.07813e9
#    5 │ HO2 + HO2 + M --> H2O2 + O2 + M  2.81728e8
#    6 │ H2O2 + O --> HO2 + OH            1.07641e7
#    7 │ O + H2O2 --> OH + HO2            1.07641e7
#    8 │ H + H2O2 --> H2O + OH            1.42154e6
#    9 │ H2O2 + H --> H2O + OH            1.42154e6
#   10 │ OH + OH --> H2O2                 3.00472e5
#   11 │ H2O2 --> H2O + O1D               0.0
#
# For H2Opl:
# 100% of reactions is 18/18
# The column rate of top 100.0% of reactions is 102117.12385439481
# Which equates to 100.0% of the total column rate (102117.12385439481).
#
# 18×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼───────────────────────────────────────────
#    1 │ CO2pl + H2O --> H2Opl + CO2  31542.2
#    2 │ H2Opl + CO --> HCOpl + OH    29197.4
#    3 │ OHpl + H2 --> H2Opl + H      18653.6
#    4 │ H2Opl + E --> O + H + H       7021.99
#    5 │ H2Opl + O --> O2pl + H2       5514.01
#    6 │ H2Opl + O2 --> O2pl + H2O     4391.36
#    7 │ H2Opl + H2 --> H3Opl + H      2378.58
#    8 │ H2Opl + E --> OH + H          1978.31
#    9 │ H2Opl + E --> H2 + O           891.252
#   10 │ Opl + H2O --> H2Opl + O        290.967
#   11 │ H2O --> H2Opl                  162.661
#   12 │ COpl + H2O --> H2Opl + CO       51.0511
#   13 │ N2pl + H2O --> H2Opl + N2       20.1849
#   14 │ H2Opl + N --> HNOpl + H         11.8444
#   15 │ H2Opl + NO --> NOpl + H2O        4.5727
#   16 │ Cpl + H2O --> H2Opl + C          3.43306
#   17 │ H2Opl + N --> NOpl + H2          2.96111
#   18 │ Hpl + H2O --> H2Opl + H          0.848848
#
# For H2pl:
# 100% of reactions is 9/9
# The column rate of top 100.0% of reactions is 566341.7179380034
# Which equates to 100.0% of the total column rate (566341.7179380034).
#
# 9×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ H2 --> H2pl                    2.86808e5
#    2 │ H2pl + CO2 --> HCO2pl + H      1.9573e5
#    3 │ H2pl + O --> OHpl + H      40705.8
#    4 │ H2pl + N2 --> N2Hpl + H    20752.5
#    5 │ H2pl + CO --> HCOpl + H    15991.5
#    6 │ H2pl + Ar --> ArHpl + H     4987.98
#    7 │ H2pl + O2 --> HO2pl + H     1273.19
#    8 │ H2pl + E --> H + H            92.4611
#    9 │ Arpl + H2 --> H2pl + Ar        0.0323665
#
# For H3Opl:
# 100% of reactions is 7/7
# The column rate of top 100.0% of reactions is 126191.95144563018
# Which equates to 100.0% of the total column rate (126191.95144563018).
#
# 7×2 DataFrame
#  Row │ Rxn                           Value
#      │ String                        Float64
# ─────┼─────────────────────────────────────────
#    1 │ HCOpl + H2O --> H3Opl + CO    60708.7
#    2 │ H3Opl + E --> OH + H + H      37518.2
#    3 │ H3Opl + E --> H2O + H         15611.6
#    4 │ H3Opl + E --> OH + H2          8729.07
#    5 │ H2Opl + H2 --> H3Opl + H       2378.58
#    6 │ H3Opl + E --> H2 + O + H        812.475
#    7 │ HCO2pl + H2O --> H3Opl + CO2    433.383
#
# For H3pl:
# 100% of reactions is 3/3
# The column rate of top 100.0% of reactions is 212.43074198538847
# Which equates to 99.99999999999999% of the total column rate (212.43074198538847).
#
# 3×2 DataFrame
#  Row │ Rxn                       Value
#      │ String                    Float64
# ─────┼───────────────────────────────────
#    1 │ H3pl + CO --> HCOpl + H2  117.363
#    2 │ HOCpl + H2 --> H3pl + CO   74.116
#    3 │ ArHpl + H2 --> H3pl + Ar   20.952
#
# For HCO:
# 100% of reactions is 7/7
# The column rate of top 100.0% of reactions is 5.2421542223030694e7
# Which equates to 100.0% of the total column rate (5.2421542223030694e7).
#
# 7×2 DataFrame
#  Row │ Rxn                    Value
#      │ String                 Float64
# ─────┼──────────────────────────────────────
#    1 │ CO + H --> HCO             2.61704e7
#    2 │ HCO + O2 --> HO2 + CO      2.22961e7
#    3 │ HCO + O2 --> CO2 + OH      3.25867e6
#    4 │ HCO + O --> CO + OH        3.41079e5
#    5 │ HCO + O --> CO2 + H        3.41079e5
#    6 │ HCO + H --> CO + H2    14080.3
#    7 │ HCO + OH --> H2O + CO    132.454
#
# For HCO2pl:
# 100% of reactions is 11/11
# The column rate of top 100.0% of reactions is 2.5877147641910836e8
# Which equates to 100.0% of the total column rate (2.5877147641910836e8).
#
# 11×2 DataFrame
#  Row │ Rxn                           Value
#      │ String                        Float64
# ─────┼─────────────────────────────────────────────
#    1 │ CO2pl + H2 --> HCO2pl + H         1.27302e8
#    2 │ HCO2pl + O --> HCOpl + O2         6.29888e7
#    3 │ HCO2pl + CO --> HCOpl + CO2       5.90042e7
#    4 │ HCO2pl + E --> CO + O + H         5.32587e6
#    5 │ HCO2pl + E --> CO + OH            2.11468e6
#    6 │ OHpl + CO2 --> HCO2pl + O         1.42099e6
#    7 │ HCO2pl + E --> CO2 + H            3.91608e5
#    8 │ H2pl + CO2 --> HCO2pl + H         1.9573e5
#    9 │ CO2pl + H2O --> HCO2pl + OH   23211.5
#   10 │ ArHpl + CO2 --> HCO2pl + Ar    3882.06
#   11 │ HCO2pl + H2O --> H3Opl + CO2    433.383
#
# For HCOpl:
# 100% of reactions is 18/18
# The column rate of top 100.0% of reactions is 2.90891390436331e8
# Which equates to 100.0% of the total column rate (2.90891390436331e8).
#
# 18×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼────────────────────────────────────────────
#    1 │ HCOpl + E --> CO + H             1.42594e8
#    2 │ HCO2pl + O --> HCOpl + O2        6.29888e7
#    3 │ HCO2pl + CO --> HCOpl + CO2      5.90042e7
#    4 │ CO2pl + H --> HCOpl + O          2.19129e7
#    5 │ Hpl + CO2 --> HCOpl + O          3.17428e6
#    6 │ HCOpl + E --> OH + C             8.2702e5
#    7 │ COpl + H2 --> HCOpl + H          1.94077e5
#    8 │ OHpl + CO --> HCOpl + O      64253.6
#    9 │ HCOpl + H2O --> H3Opl + CO   60708.7
#   10 │ H2Opl + CO --> HCOpl + OH    29197.4
#   11 │ N2Hpl + CO --> HCOpl + N2    23901.6
#   12 │ H2pl + CO --> HCOpl + H      15991.5
#   13 │ HOCpl + CO --> HCOpl + CO     1840.05
#   14 │ ArHpl + CO --> HCOpl + Ar      261.359
#   15 │ H3pl + CO --> HCOpl + H2       117.363
#   16 │ HOCpl + H2 --> HCOpl + H2      105.09
#   17 │ COpl + H2O --> HCOpl + OH       27.489
#   18 │ Cpl + H2O --> HCOpl + H         15.0817
#
# For HNOpl:
# 100% of reactions is 1/1
# The column rate of top 100.0% of reactions is 11.844441973001256
# Which equates to 100.0% of the total column rate (11.844441973001256).
#
# 1×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼──────────────────────────────────
#    1 │ H2Opl + N --> HNOpl + H  11.8444
#
# For HO2:
# 100% of reactions is 18/18
# The column rate of top 100.0% of reactions is 2.952108516355063e12
# Which equates to 100.0% of the total column rate (2.952108516355063e12).
#
# 18×2 DataFrame
#  Row │ Rxn                              Value
#      │ String                           Float64
# ─────┼──────────────────────────────────────────────────
#    1 │ H + O2 --> HO2                        1.4822e12
#    2 │ HO2 + O --> O2 + OH                   1.34282e12
#    3 │ HO2 + H --> OH + OH                   4.35459e10
#    4 │ HO2 + OH --> H2O + O2                 3.06452e10
#    5 │ HO2 + HO2 --> H2O2 + O2               2.27018e10
#    6 │ HO2 --> OH + O                        1.83708e10
#    7 │ HOCO + O2 --> CO2 + HO2               5.84948e9
#    8 │ HO2 + H --> O2 + H2                   2.08658e9
#    9 │ OH + H2O2 --> H2O + HO2               1.09603e9
#   10 │ H2O2 --> HO2 + H                      1.07813e9
#   11 │ HO2 + H --> H2O + O1D                 9.67687e8
#   12 │ O3 + HO2 --> O2 + O2 + OH             3.59553e8
#   13 │ HO2 + HO2 + M --> H2O2 + O2 + M       2.81728e8
#   14 │ O3 + OH --> HO2 + O2                  6.05858e7
#   15 │ HCO + O2 --> HO2 + CO                 2.22961e7
#   16 │ H2O2 + O --> HO2 + OH                 1.07641e7
#   17 │ O + H2O2 --> OH + HO2                 1.07641e7
#   18 │ HO2 + N --> NO + OH              198821.0
#
# For HO2pl:
# 100% of reactions is 1/1
# The column rate of top 100.0% of reactions is 1273.1938032561072
# Which equates to 100.0% of the total column rate (1273.1938032561072).
#
# 1×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼──────────────────────────────────
#    1 │ H2pl + O2 --> HO2pl + H  1273.19
#
# For HOCO:
# 100% of reactions is 3/3
# The column rate of top 100.0% of reactions is 1.1803441136850824e10
# Which equates to 100.00000000000001% of the total column rate (1.1803441136850824e10).
#
# 3×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼──────────────────────────────────────
#    1 │ CO + OH --> HOCO           5.95397e9
#    2 │ HOCO + O2 --> CO2 + HO2    5.84948e9
#    3 │ HOCO + OH --> CO2 + H2O  553.155
#
# For HOCpl:
# 100% of reactions is 6/6
# The column rate of top 100.0% of reactions is 300995.6681467642
# Which equates to 100.0% of the total column rate (300995.6681467642).
#
# 6×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼─────────────────────────────────────────
#    1 │ COpl + H2 --> HOCpl + H       1.94077e5
#    2 │ HOCpl + E --> OH + C          1.04869e5
#    3 │ HOCpl + CO --> HCOpl + CO  1840.05
#    4 │ HOCpl + H2 --> HCOpl + H2   105.09
#    5 │ HOCpl + H2 --> H3pl + CO     74.116
#    6 │ Cpl + H2O --> HOCpl + H      30.8976
#
# For Hpl:
# 100% of reactions is 12/12
# The column rate of top 100.0% of reactions is 6.434061533715276e6
# Which equates to 99.99999999999999% of the total column rate (6.434061533715276e6).
#
# 12×2 DataFrame
#  Row │ Rxn                      Value
#      │ String                   Float64
# ─────┼────────────────────────────────────────
#    1 │ Hpl + CO2 --> HCOpl + O      3.17428e6
#    2 │ CO2pl + H --> Hpl + CO2      2.69285e6
#    3 │ Opl + H --> Hpl + O          2.97234e5
#    4 │ H --> Hpl                    1.49971e5
#    5 │ COpl + H --> Hpl + CO    43545.9
#    6 │ Hpl + O --> Opl + H      36879.9
#    7 │ H2 --> Hpl + H           31867.5
#    8 │ Hpl + O2 --> O2pl + H     4762.93
#    9 │ Hpl + H --> H + Hpl       2641.17
#   10 │ H2O --> Hpl + OH            17.0067
#   11 │ Hpl + NO --> NOpl + H        9.26618
#   12 │ Hpl + H2O --> H2Opl + H      0.848848
#
# For N2Hpl:
# 100% of reactions is 8/8
# The column rate of top 100.0% of reactions is 401069.88610981876
# Which equates to 100.0% of the total column rate (401069.88610981876).
#
# 8×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ N2pl + H2 --> N2Hpl + H        2.96692e5
#    2 │ OHpl + N2 --> N2Hpl + O    34536.4
#    3 │ N2Hpl + CO --> HCOpl + N2  23901.6
#    4 │ H2pl + N2 --> N2Hpl + H    20752.5
#    5 │ N2Hpl + O --> OHpl + N2    20397.2
#    6 │ N2Hpl + E --> N2 + H        4470.32
#    7 │ ArHpl + N2 --> N2Hpl + Ar    314.979
#    8 │ N2pl + H2O --> N2Hpl + OH      5.35431
#
# For NHpl:
# 100% of reactions is 1/1
# The column rate of top 100.0% of reactions is 8746.897512350595
# Which equates to 100.0% of the total column rate (8746.897512350595).
#
# 1×2 DataFrame
#  Row │ Rxn                    Value
#      │ String                 Float64
# ─────┼────────────────────────────────
#    1 │ Npl + H2 --> NHpl + H   8746.9
#
# For OH:
# 100% of reactions is 44/44
# The column rate of top 100.0% of reactions is 3.1347827550022646e12
# Which equates to 99.99999999999999% of the total column rate (3.1347827550022646e12).
#
# 44×2 DataFrame
#  Row │ Rxn                          Value
#      │ String                       Float64
# ─────┼──────────────────────────────────────────────
#    1 │ CO + OH --> CO2 + H               1.344e12
#    2 │ HO2 + O --> O2 + OH               1.34282e12
#    3 │ OH + O --> O2 + H                 2.05675e11
#    4 │ O3 + H --> O2 + OH                8.61523e10
#    5 │ HO2 + H --> OH + OH               4.35459e10
#    6 │ H2O --> H + OH                    3.24901e10
#    7 │ HO2 + OH --> H2O + O2             3.06452e10
#    8 │ H2O2 --> OH + OH                  2.01288e10
#    9 │ HO2 --> OH + O                    1.83708e10
#   10 │ CO + OH --> HOCO                  5.95397e9
#   11 │ O1D + H2O --> OH + OH             1.62693e9
#   12 │ OH + H2 --> H2O + H               1.61533e9
#   13 │ OH + H2O2 --> H2O + HO2           1.09603e9
#   14 │ O3 + HO2 --> O2 + O2 + OH         3.59553e8
#   15 │ O1D + H2 --> OH + H               1.32058e8
#   16 │ O3 + OH --> HO2 + O2              6.05858e7
#   17 │ OH + OH --> H2O + O               3.56231e7
#   18 │ O + H --> OH                      1.91269e7
#   19 │ H2 + O --> OH + H                 1.87528e7
#   20 │ H2O2 + O --> HO2 + OH             1.07641e7
#   21 │ O + H2O2 --> OH + HO2             1.07641e7
#   22 │ OH + H + CO2 --> H2O + CO2        3.69939e6
#   23 │ HCO + O2 --> CO2 + OH             3.25867e6
#   24 │ HCO2pl + E --> CO + OH            2.11468e6
#   25 │ H + H2O2 --> H2O + OH             1.42154e6
#   26 │ H2O2 + H --> H2O + OH             1.42154e6
#   27 │ OH --> O + H                      1.39357e6
#   28 │ HCOpl + E --> OH + C              8.2702e5
#   29 │ HCO + O --> CO + OH               3.41079e5
#   30 │ OH + OH --> H2O2                  3.00472e5
#   31 │ HO2 + N --> NO + OH          198821.0
#   32 │ HOCpl + E --> OH + C              1.04869e5
#   33 │ H3Opl + E --> OH + H + H      37518.2
#   34 │ H2Opl + CO --> HCOpl + OH     29197.4
#   35 │ CO2pl + H2O --> HCO2pl + OH   23211.5
#   36 │ H3Opl + E --> OH + H2          8729.07
#   37 │ OHpl + O2 --> O2pl + OH        3422.46
#   38 │ H2Opl + E --> OH + H           1978.31
#   39 │ HOCO + OH --> CO2 + H2O         553.155
#   40 │ HCO + OH --> H2O + CO           132.454
#   41 │ OH --> O1D + H                   52.9651
#   42 │ COpl + H2O --> HCOpl + OH        27.489
#   43 │ H2O --> Hpl + OH                 17.0067
#   44 │ N2pl + H2O --> N2Hpl + OH         5.35431
#
# For OHpl:
# 100% of reactions is 12/12
# The column rate of top 100.0% of reactions is 3.638398159394904e6
# Which equates to 99.99999999999999% of the total column rate (3.638398159394904e6).
#
# 12×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ Opl + H2 --> OHpl + H          1.75584e6
#    2 │ OHpl + CO2 --> HCO2pl + O      1.42099e6
#    3 │ OHpl + O --> O2pl + H          2.76386e5
#    4 │ OHpl + CO --> HCOpl + O    64253.6
#    5 │ H2pl + O --> OHpl + H      40705.8
#    6 │ OHpl + N2 --> N2Hpl + O    34536.4
#    7 │ N2Hpl + O --> OHpl + N2    20397.2
#    8 │ OHpl + H2 --> H2Opl + H    18653.6
#    9 │ OHpl + O2 --> O2pl + OH     3422.46
#   10 │ OHpl + E --> O + H          2843.25
#   11 │ OHpl + N --> NOpl + H        337.164
#   12 │ H2O --> OHpl + H              31.6029
# 134×2 DataFrame
#  Row │ Rxn                        Value
#      │ Any                        Any
# ─────┼───────────────────────────────────────
#    1 │ H + O2 --> HO2             1.4822e12
#    2 │ CO + OH --> CO2 + H        1.344e12
#    3 │ HO2 + O --> O2 + OH        1.34282e12
#    4 │ OH + O --> O2 + H          2.05675e11
#    5 │ O3 + H --> O2 + OH         8.61523e10
#    6 │ HO2 + H --> OH + OH        4.35459e10
#    7 │ H2O --> H + OH             3.24901e10
#    8 │ HO2 + OH --> H2O + O2      3.06452e10
#    9 │ HO2 + HO2 --> H2O2 + O2    2.27018e10
#   10 │ H2O2 --> OH + OH           2.01288e10
#   11 │ HO2 --> OH + O             1.83708e10
#   ⋮  │             ⋮                  ⋮
#  125 │ H2Opl + NO --> NOpl + H2O  4.5727
#  126 │ Cpl + H2 --> CHpl + H      4.35272
#  127 │ Cpl + H2O --> H2Opl + C    3.43306
#  128 │ H2Opl + N --> NOpl + H2    2.96111
#  129 │ H2O --> Opl + H2           2.69162
#  130 │ Arpl + H2 --> ArHpl + H    1.58559
#  131 │ Hpl + H2O --> H2Opl + H    0.848848
#  132 │ Arpl + H2 --> H2pl + Ar    0.0323665
#  133 │ H2O --> H + H + O          0.0
#  134 │ H2O2 --> H2O + O1D         0.0
#                              113 rows omitted

# %%
PERCENT_OF_H_COLUMN_EQUIVALENT = sum(bigdf_H_reconstructed."Value") / sum(deuteration_candidates."Value")
# Out:
# 0.9999996592038692

# %%
deuteration_candidates
# Out:
# 282×2 DataFrame
#  Row │ Rxn                          Value
#      │ Any                          Any
# ─────┼──────────────────────────────────────────
#    1 │ H + O2 --> HO2               1.4822e12
#    2 │ CO + OH --> CO2 + H          1.344e12
#    3 │ HO2 + O --> O2 + OH          1.34282e12
#    4 │ OH + O --> O2 + H            2.05675e11
#    5 │ O3 + H --> O2 + OH           8.61523e10
#    6 │ HO2 + H --> OH + OH          4.35459e10
#    7 │ H2O --> H + OH               3.24901e10
#    8 │ HO2 + OH --> H2O + O2        3.06452e10
#    9 │ HO2 + HO2 --> H2O2 + O2      2.27018e10
#   10 │ H2O2 --> OH + OH             2.01288e10
#   11 │ HO2 --> OH + O               1.83708e10
#   ⋮  │              ⋮                    ⋮
#  273 │ Hpl + H --> H2pl             2.91294e-6
#  274 │ HCO + HCO --> CO + CO + H2   1.14913e-6
#  275 │ HO2 + CO --> CO2 + OH        9.29165e-7
#  276 │ CO2 + H --> CO + OH          1.06592e-7
#  277 │ HO2 + H2 --> H2O2 + H        4.37853e-10
#  278 │ HO2 + H2O --> H2O2 + OH      8.88464e-16
#  279 │ O2 + H2 --> OH + OH          1.21192e-19
#  280 │ O2 + H2 --> HO2 + H          1.96851e-32
#  281 │ H2O --> H + H + O            0.0
#  282 │ H2O2 --> H2O + O1D           0.0
#                                 261 rows omitted

# %% [markdown]
# # Dominant reactions for H

# %%
print_dominant_reactions(ncur, :H, 0.33; use_ion=false, Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
# Out:
# Column rates will be collected for reaction type = krates and species role = both
# The sum of all 145 reactions is: 3.166825049012297e12
# 33.0% of reactions is 47/145
# The column rate of top 33.0% of reactions is 3.166824869036046e12
# Which equates to 99.99999431682367% of the total column rate.
#
# 47×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼─────────────────────────────────────────────
#    1 │ H + O2 --> HO2                   1.4822e12
#    2 │ CO + OH --> CO2 + H              1.344e12
#    3 │ OH + O --> O2 + H                2.05675e11
#    4 │ O3 + H --> O2 + OH               8.61523e10
#    5 │ HO2 + H --> OH + OH              4.35459e10
#    6 │ HO2 + H --> O2 + H2              2.08658e9
#    7 │ OH + H2 --> H2O + H              1.61533e9
#    8 │ HO2 + H --> H2O + O1D            9.67687e8
#    9 │ HCOpl + E --> CO + H             1.42594e8
#   10 │ O1D + H2 --> OH + H              1.32058e8
#   11 │ CO2pl + H2 --> HCO2pl + H        1.27302e8
#   12 │ CO + H --> HCO                   2.61704e7
#   13 │ D + HO2 --> DO2 + H              2.61155e7
#   14 │ CO2pl + H --> HCOpl + O          2.19129e7
#   15 │ OH + D --> OD + H                2.00481e7
#   16 │ O + H --> OH                     1.91269e7
#   17 │ H2 + O --> OH + H                1.87528e7
#   18 │ H + DO2 --> OH + OD              1.57421e7
#   19 │ HCO2pl + E --> CO + O + H        5.32587e6
#   20 │ H + H + M --> H2 + M             4.65615e6
#   21 │ OH + H + CO2 --> H2O + CO2       3.69939e6
#   22 │ CO2pl + H --> Hpl + CO2          2.69285e6
#   23 │ Opl + H2 --> OHpl + H            1.75584e6
#   24 │ H + H2O2 --> H2O + OH            1.42154e6
#   25 │ H2O2 + H --> H2O + OH            1.42154e6
#   26 │ OH + HD --> HDO + H              7.62911e5
#   27 │ H + DO2 --> HD + O2         754308.0
#   28 │ OD + H2 --> HDO + H              4.26944e5
#   29 │ HCO2pl + E --> CO2 + H           3.91608e5
#   30 │ H + DO2 --> HDO + O1D       349824.0
#   31 │ HCO + O --> CO2 + H              3.41079e5
#   32 │ OD + H --> OH + D                3.14005e5
#   33 │ Opl + H --> Hpl + O              2.97234e5
#   34 │ N2pl + H2 --> N2Hpl + H          2.96692e5
#   35 │ OHpl + O --> O2pl + H            2.76386e5
#   36 │ H + DO2 --> HO2 + D         228670.0
#   37 │ H2pl + CO2 --> HCO2pl + H        1.9573e5
#   38 │ COpl + H2 --> HCOpl + H          1.94077e5
#   39 │ COpl + H2 --> HOCpl + H          1.94077e5
#   40 │ OH + N --> NO + H                1.59357e5
#   41 │ H + H2O2 --> HO2 + H2            1.48487e5
#   42 │ H2O2 + H --> HO2 + H2            1.47959e5
#   43 │ O1D + HD --> H + OD          67540.7
#   44 │ COpl + H --> Hpl + CO        43545.9
#   45 │ H2pl + O --> OHpl + H        40705.8
#   46 │ H3Opl + E --> OH + H + H     37518.2
#   47 │ Hpl + O --> Opl + H          36879.9

# %% [markdown]
# # Dominant reactions for H2O

# %%
print_dominant_reactions(ncur, :H2O, 0.33; use_ion=false, Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
# Out:
# Column rates will be collected for reaction type = krates and species role = both
# The sum of all 57 reactions is: 3.599391832775264e10
# 33.0% of reactions is 18/57
# The column rate of top 33.0% of reactions is 3.59939176113226e10
# Which equates to 99.99999800958031% of the total column rate.
#
# 18×2 DataFrame
#  Row │ Rxn                           Value
#      │ String                        Float64
# ─────┼───────────────────────────────────────────────
#    1 │ HO2 + OH --> H2O + O2              3.06452e10
#    2 │ O1D + H2O --> OH + OH              1.62693e9
#    3 │ OH + H2 --> H2O + H                1.61533e9
#    4 │ OH + H2O2 --> H2O + HO2            1.09603e9
#    5 │ HO2 + H --> H2O + O1D              9.67687e8
#    6 │ OH + OH --> H2O + O                3.56231e7
#    7 │ OH + H + CO2 --> H2O + CO2         3.69939e6
#    8 │ H + H2O2 --> H2O + OH              1.42154e6
#    9 │ H2O2 + H --> H2O + OH              1.42154e6
#   10 │ OH + HD --> H2O + D           300805.0
#   11 │ OH + HDO2 --> H2O + DO2            1.48677e5
#   12 │ HCOpl + H2O --> H3Opl + CO     60708.7
#   13 │ CO2pl + H2O --> H2Opl + CO2    31542.2
#   14 │ CO2pl + H2O --> HCO2pl + OH    23211.5
#   15 │ H3Opl + E --> H2O + H          15611.6
#   16 │ H2Opl + O2 --> O2pl + H2O       4391.36
#   17 │ HOCO + OH --> CO2 + H2O          553.155
#   18 │ HCO2pl + H2O --> H3Opl + CO2     433.383

# %% [markdown]
# # Dominant reactions for OH

# %%
print_dominant_reactions(ncur, :OH, 0.33; use_ion=false, Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
# Out:
# Column rates will be collected for reaction type = krates and species role = both
# The sum of all 102 reactions is: 3.063854424653401e12
# 33.0% of reactions is 33/102
# The column rate of top 33.0% of reactions is 3.063853168714076e12
# Which equates to 99.99995900786557% of the total column rate.
#
# 33×2 DataFrame
#  Row │ Rxn                         Value
#      │ String                      Float64
# ─────┼─────────────────────────────────────────────
#    1 │ CO + OH --> CO2 + H              1.344e12
#    2 │ HO2 + O --> O2 + OH              1.34282e12
#    3 │ OH + O --> O2 + H                2.05675e11
#    4 │ O3 + H --> O2 + OH               8.61523e10
#    5 │ HO2 + H --> OH + OH              4.35459e10
#    6 │ HO2 + OH --> H2O + O2            3.06452e10
#    7 │ CO + OH --> HOCO                 5.95397e9
#    8 │ O1D + H2O --> OH + OH            1.62693e9
#    9 │ OH + H2 --> H2O + H              1.61533e9
#   10 │ OH + H2O2 --> H2O + HO2          1.09603e9
#   11 │ O3 + HO2 --> O2 + O2 + OH        3.59553e8
#   12 │ O1D + H2 --> OH + H              1.32058e8
#   13 │ O3 + OH --> HO2 + O2             6.05858e7
#   14 │ OH + OH --> H2O + O              3.56231e7
#   15 │ OH + D --> OD + H                2.00481e7
#   16 │ O + H --> OH                     1.91269e7
#   17 │ H2 + O --> OH + H                1.87528e7
#   18 │ H + DO2 --> OH + OD              1.57421e7
#   19 │ D + HO2 --> OH + OD              1.33503e7
#   20 │ H2O2 + O --> HO2 + OH            1.07641e7
#   21 │ O + H2O2 --> OH + HO2            1.07641e7
#   22 │ OH + DO2 --> HDO + O2            8.90007e6
#   23 │ OH + H + CO2 --> H2O + CO2       3.69939e6
#   24 │ HCO + O2 --> CO2 + OH            3.25867e6
#   25 │ O1D + HDO --> OD + OH            2.78704e6
#   26 │ HCO2pl + E --> CO + OH           2.11468e6
#   27 │ H + H2O2 --> H2O + OH            1.42154e6
#   28 │ H2O2 + H --> H2O + OH            1.42154e6
#   29 │ HCOpl + E --> OH + C             8.2702e5
#   30 │ OH + HD --> HDO + H              7.62911e5
#   31 │ HCO + O --> CO + OH              3.41079e5
#   32 │ OD + H --> OH + D                3.14005e5
#   33 │ OH + HD --> H2O + D         300805.0

# %% [markdown]
# # Dominant reactions for HCO

# %%
print_dominant_reactions(ncur, :HCO, 0.33; use_ion=true, Tn=vardict["Tn_arr"][2:end-1], Ti=vardict["Ti_arr"][2:end-1], Te=vardict["Te_arr"][2:end-1], 
                                   all_species=vardict["all_species"], ion_species=vardict["ion_species"], reaction_network=reaction_network,
                                   num_layers, dz)
# Out:
# Column rates will be collected for reaction type = krates and species role = both
# The sum of all 31 reactions is: 5.242318647211368e7
# 33.0% of reactions is 10/31
# The column rate of top 33.0% of reactions is 5.242318481440615e7
# Which equates to 99.99999683783524% of the total column rate.
#
# 10×2 DataFrame
#  Row │ Rxn                        Value
#      │ String                     Float64
# ─────┼──────────────────────────────────────────
#    1 │ CO + H --> HCO                 2.61704e7
#    2 │ HCO + O2 --> HO2 + CO          2.22961e7
#    3 │ HCO + O2 --> CO2 + OH          3.25867e6
#    4 │ HCO + O --> CO + OH            3.41079e5
#    5 │ HCO + O --> CO2 + H            3.41079e5
#    6 │ HCO + H --> CO + H2        14080.3
#    7 │ NHpl + CO2 --> NOpl + HCO   1635.31
#    8 │ HCO + OH --> H2O + CO        132.454
#    9 │ HCO + D --> CO + HD            5.67946
#   10 │ O2pl + HCO --> HCOpl + O2      1.60158
