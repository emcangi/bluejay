# %% [markdown]
# This notebook was for troubleshooting problems with the chemistry network that were preventing it from converging.
#
# Date: late NOvember 2020

# %%
using PyPlot
using PyCall
using Photochemistry

include("PARAMETERS.jl");
# Out:
# WARNING: redefining constant alt
# WARNING: redefining constant intaltgrid
# WARNING: redefining constant fullspecieslist
# WARNING: redefining constant Jratelist
# WARNING: redefining constant nochemspecies
# WARNING: redefining constant chemspecies
# WARNING: redefining constant notransportspecies
# WARNING: redefining constant transportspecies
# WARNING: redefining constant activespecies
# WARNING: redefining constant inactivespecies
# WARNING: redefining constant speciesmolmasslist

# %% [markdown]
# # neutral progression

# %%
ncur1 = get_ncurrent("/home/emc/GDrive-CU/Research-Modeling/UpperAtmoDH/Results/ncurrent_1.h5")
plotatm(ncur1, neutrallist, "/home/emc/GDrive-CU/Research-Modeling/UpperAtmoDH/Results/", iter=1, extratag="neutrals")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
ncur3 = get_ncurrent("/home/emc/GDrive-CU/Research-Modeling/UpperAtmoDH/Results/ncurrent_2.h5")
plotatm(ncur3, neutrallist, "/home/emc/GDrive-CU/Research-Modeling/UpperAtmoDH/Results/", iter=3, extratag="neutrals")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # ion progression

# %%
plotatm(ncur1, ionlist, "/home/emc/GDrive-CU/Research-Modeling/UpperAtmoDH/Results/", iter=1, extratag="ions")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plotatm(ncur2, ionlist, "/home/emc/GDrive-CU/Research-Modeling/UpperAtmoDH/Results/", iter=2, extratag="ions")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Aha. It's C+ again.
